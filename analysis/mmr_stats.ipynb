# %%
import json
from datetime import date
from typing import Dict
import math
import csv

STAT_NAMES = [
    "caps", "hold", "earlyhold", "latehold", "ndps", "returns",
    "quick_returns", "nrts", "pups", "handoffs", "prevent", "lateprevent"
]

with open("../data/bulkmaps.json", encoding="utf-8") as f:
    maps = json.load(f)

with open("smurfs.json") as f:
    smurfs = json.load(f)

def desmurf(player):
    player = player.replace("\\'", "'").replace("\\\\", "\\")
    if player in smurfs:
        return smurfs[player]
    return player

def row_to_dict(row):
    return {
        'match_id': int(row[0]),
        'map_name': maps[row[1]]['name'],
        'gamemode': maps[row[1]]['type'],
        'timestamp': int(row[2]),
        'duration': int(row[3]),
        'cap_diff': int(row[4]),
        'players': [
            {
                'name': desmurf(row[j + 5]),
                'stats': {
                    stat_name: int(row[j * len(STAT_NAMES) + 13 + i])
                    for i, stat_name in enumerate(STAT_NAMES)
                }
            }
            for j in range(8)
        ]
    }

with open("matchups_with_stats.csv") as f:
    reader = csv.reader(f)
    next(reader)
    matches = [row_to_dict(row) for row in reader]
    matches = [m for m in matches if m['gamemode'] == "ctf"]

players = {}

# %%
NEW_PLAYER_ELO = 0
STARTING_VARIANCE = 0.65
MAX_VARIANCE_TO_COUNT_AS_KNOWN = 0.35
VARIANCE_TO_ADD_BACK = 0.0004
BASE_VARIANCE = 4.5
RED_ADVANTAGE = {
    'default': 0.1,
    'A Flaccid Type Map': 0,
    'Audacity 2': 0.2,
    'Moon Base 2024': 0.2,
    'Asida': 0.2,
    'Centenaria': 0,
    'Milano 2': 0.2,
    'Combine': 0,
    'Sardonica': 0,
    'OTI MERALD': 0,
    'OTI Jardim': 0.2,
    'Willow 2': 0,
    'Sugar Free Hill': -0.1,
}
DIFF_MAPPING = [0, 0.3, 0.9, 2.0, 3.1, 4.3, -4.3, -3.1, -2.0, -0.9, -0.3]
STAT_SCORE_WEIGHT_BY_CAP_DIFF = 0.2
CAP_TO_WP_EXPONENT = 1.7
PLAYER_STAT_WEIGHTS = {
    "caps": 1.75,
    "hold": 3.0 / 3600,
    "ndps": -0.75,
    "returns": 0.75,
    "nrts": 0.5,
    "pups": 0.6,
}
TEAM_STAT_WEIGHTS = {
    "caps": 0.0,
    "hold": 0.7 / 3600,
    "ndps": 0.0,
    "returns": 0.03,
    "nrts": 0.0,
    "pups": 0.03,
    
}
RELATIVE_ELO_CORRECTION = 2.2

# %%
class Player:
    def __init__(self, name):
        self.name = name
        self.elo = NEW_PLAYER_ELO
        self.variance = STARTING_VARIANCE
        self.lowest_ever_variance = self.variance
        self.stat_farm_amount = 0
        self.high_certainty_play = 0

    def error_bar(self):
        return 1.96 * self.variance ** 0.5
    
    def update_rating(self, p, match, error, stat_score, team_avg_elo, total_variance, record=True):
        if record:
            p['updates'] = {
                'elo_before': self.elo,
                'variance_before': self.variance,
            }
        share_of_variance = self.variance / total_variance

        # Calculate stat score (weighted based on newness)
        newness = self.variance / STARTING_VARIANCE
        stat_score = stat_score * newness

        # Apply a slight correction to stat score based on relative elo
        elo_vs_game_avg = self.elo - team_avg_elo
        stat_score -= elo_vs_game_avg * newness * RELATIVE_ELO_CORRECTION

        # Weight stat score higher in blowouts
        stat_score *= 1 + STAT_SCORE_WEIGHT_BY_CAP_DIFF * (abs(match['cap_diff']) - 1)

        # Apply Bayesian update (error times share of variance, plus stat score)
        update = error + stat_score
        self.elo += update * share_of_variance
        self.variance *= 1 - share_of_variance
        self.lowest_ever_variance = min(self.variance, self.lowest_ever_variance)

        # Track the update that was applied
        if record:
            p['updates']['elo_update'] = self.elo - p['updates']['elo_before']

    def overperformance(self, decay=0.998):
        expected_wins, actual_wins = 0, 0
        expected_cap_diff, actual_cap_diff = 0, 0
        weighted_games_played = 0
        for m in matches:
            names = [p['name'] for p in m['players']]
            if self.name in names:
                is_red = self.name in names[:4]
                weight = decay ** (date.today() - date.fromtimestamp(m['timestamp'])).days
                weighted_games_played += weight
                expected_score = sum(players[p].elo for p in names[:4]) - sum(players[p].elo for p in names[4:]) +\
                    RED_ADVANTAGE[m['map_name'] if m['map_name'] in RED_ADVANTAGE else 'default']
                red_win_prob = 1 / (1 + CAP_TO_WP_EXPONENT ** -expected_score)
                if is_red:
                    expected_cap_diff += expected_score * weight
                    actual_cap_diff += m['cap_diff'] * weight
                    expected_wins += red_win_prob * weight
                    actual_wins += (1 if m['cap_diff'] > 0 else 0.5 if m['cap_diff'] == 0 else 0) * weight
                else:
                    expected_cap_diff += expected_score * weight
                    actual_cap_diff += m['cap_diff'] * weight
                    expected_wins += (1 - red_win_prob) * weight
                    actual_wins += (1 if m['cap_diff'] < 0 else 0.5 if m['cap_diff'] == 0 else 0) * weight

        return (
            (actual_wins - expected_wins) / weighted_games_played,
            (actual_cap_diff - expected_cap_diff) / weighted_games_played
        )

    def __str__(self):
        return f"{self.name} ({self.elo:.2f} ± {self.error_bar():.2f})"
    
    def __repr__(self):
        return f"Player \"{self.name}\" ({self.elo:.2f} ± {self.error_bar():.2f})"

# %%
def normalize_elos():
    known_elos = [p.elo for p in players.values() if p.variance <= MAX_VARIANCE_TO_COUNT_AS_KNOWN]
    avg_elo = sum(known_elos) / max(10, len(known_elos))
    for p in players.values():
        p.elo -= avg_elo
        p.variance = min(p.variance + VARIANCE_TO_ADD_BACK, STARTING_VARIANCE)

def stat_scores(players, scoring_dict: Dict[str, int]):
    return [
        sum([
            p['stats'][stat_name] * scoring_dict[stat_name]
            for stat_name in scoring_dict
        ])
        for p in players
    ]

def judge_player_stats(players):
    player_scores = stat_scores(players, PLAYER_STAT_WEIGHTS)

    red_avg_score = sum(player_scores[:4]) / 4
    blue_avg_score = sum(player_scores[4:]) / 4
    red_scores = [s - red_avg_score for s in player_scores[:4]]
    blue_scores = [s - blue_avg_score for s in player_scores[4:]]
    return red_scores, blue_scores

def update_ratings(match, record=True):
    # Calculate skill for each team and game variance
    red_elo = 0
    blue_elo = 0
    total_variance = BASE_VARIANCE

    for p in match['players']:
        if p['name'] not in players:
            players[p['name']] = Player(p['name'])
        total_variance += players[p['name']].variance
    
    for p in match['players'][:4]:
        red_elo += players[p['name']].elo
    for p in match['players'][4:]:
        blue_elo += players[p['name']].elo
    
    expected_score = red_elo - blue_elo + RED_ADVANTAGE[
        match['map_name'] if match['map_name'] in RED_ADVANTAGE else 'default'
    ]

    # Track predictions
    if record:
        match['red_elo'] = red_elo
        match['blue_elo'] = blue_elo
        match['pred'] = expected_score
        match['sd'] = total_variance ** 0.5
        match['wp'] = 1 / (1 + CAP_TO_WP_EXPONENT ** -expected_score)
        match['residual'] = match['cap_diff'] - min(max(expected_score, -5), 5)
        match['wwp'] = match['wp'] if match['cap_diff'] > 0 else 1 - match['wp']
    
    # Calculate the error used for Bayesian updating
    error = DIFF_MAPPING[match['cap_diff']] - min(max(expected_score, DIFF_MAPPING[-4]), DIFF_MAPPING[4])

    # Incorporate team total stats into the error
    team_scores = stat_scores(match['players'], TEAM_STAT_WEIGHTS)
    error += sum(team_scores[:4]) - sum(team_scores[4:])

    # Update ratings based on this error and the variance
    red_stat_scores, blue_stat_scores = judge_player_stats(match['players'])
    for p, stat_score in zip(match['players'][:4], red_stat_scores):
        players[p['name']].update_rating(p, match, error, stat_score, red_elo / 4, total_variance, record=record)
    for p, stat_score in zip(match['players'][4:], blue_stat_scores):
        players[p['name']].update_rating(p, match, -error, stat_score, blue_elo / 4, total_variance, record=record)

# %%
players = {}
day = date.fromtimestamp(matches[0]['timestamp'])
player_to_track = ""
played_today = 0

for i, match in enumerate(matches):
    if any(p['name'] == player_to_track for p in match['players']):
        played_today += 1
    new_day = date.fromtimestamp(match['timestamp'])
    if new_day != day:
        normalize_elos()
        if played_today > 0:
            print(f"{new_day}: {players[player_to_track].elo:.2f} ± {players[player_to_track].error_bar():.2f} ({played_today} games)")
            played_today = 0
    day = new_day
    update_ratings(match)

print(f"MAE: {sum([abs(m['residual']) for m in matches]) / len(matches):.4f}    RMS: {(sum([m['residual'] ** 2 for m in matches]) / len(matches)) ** 0.5:.4f}")
print(f"COR: {sum([(1 if m['wwp'] > 0.5 else 0.5 if m['wwp'] == 0.5 else 0) for m in matches]) / len(matches):.2%}    WWP: {sum(m['wwp'] for m in matches) / len(matches):.2%}")
print(f"BRI: {1 - (sum([(1 - m['wwp']) ** 2 for m in matches]) / len(matches)) ** 0.5:.2%}    LOG: {2 ** (sum([math.log2(m['wwp']) for m in matches]) / len(matches)):.2%}")

for p in players.values():
    p.elo *= 0.8
    p.variance *= 1.25 ** 2

day = date.fromtimestamp(matches[0]['timestamp'])

for match in matches:
    new_day = date.fromtimestamp(match['timestamp'])
    if new_day != day:
        normalize_elos()
    day = new_day
    update_ratings(match)

print(f"MAE: {sum([abs(m['residual']) for m in matches]) / len(matches):.4f}    RMS: {(sum([m['residual'] ** 2 for m in matches]) / len(matches)) ** 0.5:.4f}")
print(f"COR: {sum([(1 if m['wwp'] > 0.5 else 0.5 if m['wwp'] == 0.5 else 0) for m in matches]) / len(matches):.2%}    WWP: {sum(m['wwp'] for m in matches) / len(matches):.2%}")
print(f"BRI: {1 - (sum([(1 - m['wwp']) ** 2 for m in matches]) / len(matches)) ** 0.5:.2%}    LOG: {2 ** (sum([math.log2(m['wwp']) for m in matches]) / len(matches)):.2%}")
# Out:
# MAE: 2.4124    RMS: 2.9209
# COR: 60.99%    WWP: 53.87%
# BRI: 51.98%    LOG: 52.09%
# MAE: 2.3833    RMS: 2.8833
# COR: 61.90%    WWP: 54.13%
# BRI: 52.32%    LOG: 52.47%

# %% [markdown]
# MAE: 2.4124    RMS: 2.9209
# COR: 60.99%    WWP: 53.87%
# BRI: 51.98%    LOG: 52.09%

# %%
leaderboard = sorted([
    p for p in players.values() if p.variance <= MAX_VARIANCE_TO_COUNT_AS_KNOWN
], key=lambda p: p.elo, reverse=True)
for i, p in enumerate(leaderboard):
    print(f"{i + 1:>3}.  {p.name:<12}  {p.elo:5.2f} ± {1.96 * p.variance ** 0.5:.2f}")
# Out:
#   1.  tng.           3.37 ± 0.30
#   2.  okthen         3.29 ± 0.68
#   3.  crux           3.28 ± 1.02
#   4.  Junoon         3.19 ± 0.39
#   5.  OuchMyBalls    3.15 ± 0.32
#   6.  toasty         3.13 ± 0.74
#   7.  DT             3.11 ± 0.46
#   8.  chizu_mizu     3.10 ± 0.43
#   9.  meowza         3.04 ± 0.38
#  10.  Vorhees        2.96 ± 0.32
#  11.  Alphachurro    2.88 ± 0.32
#  12.  Xx360NoSwagx   2.86 ± 0.74
#  13.  jig            2.83 ± 0.36
#  14.  Mileena        2.80 ± 0.32
#  15.  NEUhusky       2.78 ± 0.64
#  16.  mex            2.74 ± 0.37
#  17.  Jester101      2.72 ± 1.03
#  18.  bright         2.66 ± 0.64
#  19.  bitter heart   2.57 ± 0.91
#  20.  ?              2.57 ± 0.43
#  21.  Galvatron      2.54 ± 0.78
#  22.  BALLDON'TLIE   2.52 ± 0.34
#  23.  Cape           2.48 ± 0.77
#  24.  Ritual         2.48 ± 0.64
#  25.  HvN Piercer    2.46 ± 0.32
#  26.  phreak         2.45 ± 0.45
#  27.  frieren        2.44 ± 0.90
#  28.  Crippy         2.43 ± 0.35
#  29.  Madoka         2.41 ± 0.83
#  30.  ASAP           2.40 ± 0.40
#  31.  fender         2.36 ± 0.42
#  32.  Suchit         2.36 ± 0.36
#  33.  flaccid trip   2.31 ± 0.40
#  34.  2Nutz          2.28 ± 0.40
#  35.  1deag          2.26 ± 0.61
#  36.  HelloI'mGurt   2.25 ± 1.02
#  37.  grunt          2.16 ± 0.43
#  38.  realtea        2.15 ± 0.37
#  39.  Doris          2.15 ± 0.67
#  40.  simp.          2.14 ± 0.39
#  41.  black orchid   2.14 ± 0.33
#  42.  Xylene         2.11 ± 0.44
#  43.  Messi          2.09 ± 0.37
#  44.  Ball-E         2.09 ± 0.82
#  45.  i love HD      2.08 ± 0.95
#  46.  BallSaget      2.06 ± 0.31
#  47.  swerve         2.06 ± 1.02
#  48.  Ty             2.05 ± 0.49
#  49.  eee            2.04 ± 0.67
#  50.  Vader          2.04 ± 0.43
#  51.  Sugar          2.04 ± 0.49
#  52.  bbb            2.03 ± 0.47
#  53.  rina           2.01 ± 0.62
#  54.  Carrrrrl       2.00 ± 0.39
#  55.  yawn           1.98 ± 0.44
#  56.  Curry          1.97 ± 0.39
#  57.  kool aid       1.95 ± 0.63
#  58.  caprae         1.92 ± 0.28
#  59.  Wanye          1.92 ± 0.44
#  60.  MarcusYallow   1.92 ± 0.62
#  61.  popsic         1.89 ± 0.36
#  62.  known          1.89 ± 0.40
#  63.  Cheezedoodle   1.88 ± 0.45
#  64.  Spjork         1.88 ± 0.38
#  65.  tits           1.88 ± 0.55
#  66.  BallsToYou.    1.87 ± 0.38
#  67.  Mr awesome:)   1.87 ± 0.59
#  68.  NameLEss       1.87 ± 0.54
#  69.  First          1.86 ± 0.43
#  70.  Kep            1.86 ± 0.41
#  71.  SakuUta        1.85 ± 0.64
#  72.  Russ           1.83 ± 0.33
#  73.  autumn heart   1.83 ± 0.53
#  74.  Button         1.82 ± 0.47
#  75.  vanitas        1.81 ± 1.01
#  76.  Homie          1.81 ± 0.63
#  77.  Slowpolka      1.80 ± 0.99
#  78.  grumpy         1.80 ± 0.40
#  79.  Nas            1.80 ± 0.39
#  80.  Arbybear       1.79 ± 0.59
#  81.  Thrust         1.78 ± 0.80
#  82.  Cheetosrule    1.77 ± 0.55
#  83.  Abe Lincoln    1.77 ± 0.68
#  84.  ~              1.77 ± 0.67
#  85.  anti-re        1.76 ± 0.47
#  86.  360broscope    1.75 ± 0.68
#  87.  blah-zay       1.74 ± 0.39
#  88.  Bluefoot       1.73 ± 0.32
#  89.  AdmaniaYT      1.73 ± 0.50
#  90.  DAD.           1.73 ± 0.41
#  91.  !              1.72 ± 0.76
#  92.  SleepyBoi      1.70 ± 0.51
#  93.  karma          1.70 ± 0.34
#  94.  jazzz          1.68 ± 0.46
#  95.  ||||||||||||   1.67 ± 0.89
#  96.  churt chimi    1.67 ± 0.68
#  97.  KING KRULE     1.64 ± 0.38
#  98.  DiNgBaT        1.63 ± 0.44
#  99.  dodsfall       1.62 ± 0.43
# 100.  broseph        1.61 ± 0.35
# 101.  keithstoned1   1.61 ± 0.98
# 102.  amadeo         1.58 ± 0.29
# 103.  helen keller   1.57 ± 0.37
# 104.  mactheroni     1.57 ± 0.39
# 105.  tha king       1.54 ± 0.32
# 106.  yep            1.54 ± 0.66
# 107.  zo2            1.52 ± 0.45
# 108.  omar           1.52 ± 0.92
# 109.  Mista Feeneh   1.51 ± 0.40
# 110.  Jinjo          1.51 ± 0.88
# 111.  SoulCake       1.49 ± 0.60
# 112.  Magnolia       1.49 ± 0.39
# 113.  DudeMcGuy      1.48 ± 0.93
# 114.  Boat           1.48 ± 0.87
# 115.  Sadness        1.46 ± 0.33
# 116.  tune           1.46 ± 0.81
# 117.  Niplepotamus   1.45 ± 0.89
# 118.  JKooter        1.45 ± 0.31
# 119.  Jer32          1.44 ± 0.81
# 120.  goji           1.44 ± 0.42
# 121.  kasli          1.44 ± 0.83
# 122.  Frank          1.43 ± 0.96
# 123.  Ball of Fame   1.43 ± 1.00
# 124.  anduin         1.43 ± 0.36
# 125.  DingusDongus   1.42 ± 0.88
# 126.  Irony          1.42 ± 0.57
# 127.  d0pe           1.42 ± 0.44
# 128.  Light          1.42 ± 0.57
# 129.  St. Bernard    1.40 ± 0.79
# 130.  womp womp      1.40 ± 0.45
# 131.  Sphear         1.39 ± 1.03
# 132.  TagTitan       1.38 ± 0.50
# 133.  omni           1.38 ± 0.39
# 134.  Prime          1.38 ± 0.38
# 135.  StaIin         1.37 ± 0.69
# 136.  Butter         1.37 ± 0.70
# 137.  jkxs           1.37 ± 0.40
# 138.  C_T            1.37 ± 0.42
# 139.  Mos Def        1.35 ± 0.61
# 140.  Gamepad God    1.34 ± 0.73
# 141.  snuffed        1.33 ± 0.91
# 142.  Shaolin        1.32 ± 0.85
# 143.  clew3          1.32 ± 0.94
# 144.  Rudey          1.32 ± 0.43
# 145.  JBaay          1.32 ± 0.92
# 146.  Reze20         1.31 ± 0.40
# 147.  Thanos Ball    1.30 ± 0.35
# 148.  Kei Yonagi     1.29 ± 0.76
# 149.  hz             1.28 ± 0.29
# 150.  q42            1.28 ± 0.53
# 151.  DEAD NAN       1.28 ± 0.78
# 152.  MarkBallis     1.28 ± 0.86
# 153.  PTF            1.27 ± 0.47
# 154.  POWER          1.27 ± 0.50
# 155.  Wraith         1.26 ± 0.51
# 156.  Baay           1.26 ± 0.61
# 157.  Chill Will     1.26 ± 0.53
# 158.  Corbeh         1.26 ± 0.57
# 159.  magicmuffin8   1.26 ± 0.61
# 160.  beef           1.24 ± 0.75
# 161.  Stronk         1.22 ± 0.60
# 162.  Bam            1.22 ± 0.39
# 163.  Magikarp       1.22 ± 0.54
# 164.  rake           1.22 ± 0.76
# 165.  Poeticalto     1.22 ± 0.57
# 166.  heribo69       1.22 ± 0.51
# 167.  yiss           1.21 ± 0.49
# 168.  Recap          1.21 ± 0.70
# 169.  Ballzilla      1.20 ± 0.86
# 170.  George         1.19 ± 0.90
# 171.  Tinderfella    1.18 ± 0.48
# 172.  snaxolotl      1.17 ± 0.45
# 173.  arksoldier     1.17 ± 0.64
# 174.  bumballbee     1.17 ± 0.93
# 175.  #SelfySyntax   1.17 ± 0.39
# 176.  Jason Bourne   1.16 ± 0.99
# 177.  Porps          1.16 ± 0.53
# 178.  Gman8181       1.13 ± 0.55
# 179.  RedBull        1.13 ± 0.62
# 180.  Toidi          1.12 ± 0.23
# 181.  Kamikaze       1.12 ± 0.71
# 182.  Rikers Beard   1.12 ± 0.88
# 183.  Borgus         1.11 ± 0.37
# 184.  jjpoole        1.11 ± 0.33
# 185.  aaron          1.10 ± 0.38
# 186.  Snowball       1.10 ± 0.66
# 187.  LewBird        1.10 ± 0.34
# 188.  bleast         1.09 ± 1.04
# 189.  yippie         1.09 ± 0.96
# 190.  Adamn          1.09 ± 0.64
# 191.  EpicBlob       1.08 ± 0.50
# 192.  lizzey         1.07 ± 0.80
# 193.  aardvark       1.06 ± 0.38
# 194.  Able           1.06 ± 0.72
# 195.  BallAnka       1.05 ± 0.59
# 196.  vic            1.05 ± 0.46
# 197.  Niku           1.04 ± 0.65
# 198.  Armbranch      1.04 ± 0.87
# 199.  Squeeb         1.03 ± 0.71
# 200.  P-d0g          1.02 ± 0.88
# 201.  mc             1.02 ± 0.46
# 202.  meaL           1.01 ± 0.75
# 203.  Big D          1.01 ± 0.99
# 204.  D Rek          1.00 ± 0.45
# 205.  ImaNewbie      1.00 ± 0.50
# 206.  BreadBall      0.99 ± 0.90
# 207.  Trapsin        0.99 ± 0.49
# 208.  perl           0.99 ± 0.36
# 209.  niya           0.98 ± 0.52
# 210.  ObliqueOwl     0.98 ± 0.70
# 211.  the buttons    0.98 ± 0.26
# 212.  Dr. Toboggan   0.98 ± 0.35
# 213.  toppy          0.97 ± 0.51
# 214.  Misery         0.97 ± 0.55
# 215.  Pnaoxt         0.96 ± 0.57
# 216.  j0sh           0.95 ± 0.38
# 217.  ALEX JONES     0.95 ± 0.73
# 218.  lmfao          0.95 ± 0.82
# 219.  Sanik          0.94 ± 0.57
# 220.  xcv            0.94 ± 0.35
# 221.  CA$H.          0.93 ± 0.41
# 222.  alchemist      0.93 ± 0.81
# 223.  deku           0.93 ± 0.55
# 224.  RASCAL         0.92 ± 0.99
# 225.  tragic         0.92 ± 0.76
# 226.  poobie         0.92 ± 0.79
# 227.  Raven          0.91 ± 0.95
# 228.  cannibal       0.91 ± 0.77
# 229.  FK             0.91 ± 0.48
# 230.  Ted            0.91 ± 0.67
# 231.  .__.           0.91 ± 0.45
# 232.  wasserstein    0.90 ± 0.68
# 233.  tnevlos        0.90 ± 0.44
# 234.  o o l e r      0.90 ± 0.44
# 235.  Rick G. #853   0.89 ± 0.44
# 236.  JSwan          0.89 ± 0.80
# 237.  Spheroid.      0.89 ± 0.35
# 238.  Threeflower    0.89 ± 0.43
# 239.  sun chips      0.88 ± 0.40
# 240.  MAGNlTUDE      0.87 ± 0.93
# 241.  Tumblewood     0.87 ± 0.44
# 242.  bergieberg     0.87 ± 0.71
# 243.  John Brown     0.86 ± 0.80
# 244.  toogood        0.85 ± 0.72
# 245.  Enthymeme      0.83 ± 0.76
# 246.  knight_        0.82 ± 0.31
# 247.  rebel fox      0.81 ± 0.51
# 248.  white          0.81 ± 0.62
# 249.  gingerdg       0.81 ± 0.60
# 250.  caroline :3    0.80 ± 0.42
# 251.  Batman.        0.80 ± 0.60
# 252.  gghob          0.80 ± 0.78
# 253.  UNlTY          0.80 ± 0.30
# 254.  goosehonk      0.79 ± 1.05
# 255.  Grommit        0.79 ± 0.41
# 256.  K O            0.79 ± 0.34
# 257.  TaylorWhiff    0.79 ± 0.56
# 258.  Airmigo        0.79 ± 0.52
# 259.  jerm           0.79 ± 0.40
# 260.  Kenobi         0.79 ± 0.43
# 261.  MostToxic420   0.78 ± 0.89
# 262.  Nilus          0.78 ± 0.60
# 263.  Quercus        0.78 ± 0.54
# 264.  Jukester       0.77 ± 0.67
# 265.  trippi         0.77 ± 0.37
# 266.  RacgiMan       0.76 ± 0.82
# 267.  Iodized Salt   0.76 ± 0.38
# 268.  firehawkv      0.76 ± 1.06
# 269.  hero-cat       0.76 ± 0.50
# 270.  Gleg           0.76 ± 0.95
# 271.  LogisticMap    0.76 ± 0.39
# 272.  Gato           0.75 ± 0.99
# 273.  CRYCHIC        0.75 ± 0.57
# 274.  Baby_Shark     0.74 ± 0.61
# 275.  Klox           0.71 ± 0.81
# 276.  jmu            0.70 ± 0.65
# 277.  archedrapier   0.70 ± 0.65
# 278.  Serenity       0.70 ± 0.94
# 279.  t h C          0.70 ± 0.40
# 280.  iiiiiiiiii     0.69 ± 0.64
# 281.  o3             0.69 ± 0.84
# 282.  RandyB0Bandy   0.69 ± 0.43
# 283.  F7             0.69 ± 0.52
# 284.  Rick O'Shea    0.69 ± 0.91
# 285.  ez             0.66 ± 0.44
# 286.  Dew1234        0.66 ± 0.84
# 287.  an             0.65 ± 0.92
# 288.  bequerel       0.65 ± 0.86
# 289.  flopphone      0.65 ± 0.79
# 290.  windowlicker   0.65 ± 0.40
# 291.  Booya Ball     0.64 ± 0.45
# 292.  Player X       0.63 ± 0.44
# 293.  Feels Like     0.63 ± 0.46
# 294.  Fingsb         0.62 ± 1.06
# 295.  1tbsp          0.61 ± 0.46
# 296.  JARVISLANDRY   0.61 ± 0.55
# 297.  Optical Juke   0.60 ± 0.83
# 298.  Punster        0.60 ± 0.89
# 299.  boogie         0.60 ± 0.48
# 300.  FortuneCooki   0.60 ± 0.63
# 301.  kmichael       0.59 ± 0.27
# 302.  Diencash       0.58 ± 0.78
# 303.  clamp          0.58 ± 1.07
# 304.  Old Cob        0.57 ± 0.69
# 305.  Roxas          0.57 ± 0.67
# 306.  cowboy         0.57 ± 0.50
# 307.  Eat Tofu       0.56 ± 0.39
# 308.  GillyBall      0.56 ± 0.80
# 309.  ankr           0.56 ± 1.06
# 310.  Billy          0.56 ± 0.83
# 311.  Nevermind      0.55 ± 0.63
# 312.  Kosmo          0.55 ± 0.42
# 313.  Anti_Social    0.54 ± 0.40
# 314.  U Good         0.54 ± 0.62
# 315.  Cel            0.54 ± 0.62
# 316.  MyNameWontFi   0.54 ± 0.74
# 317.  Moto Moto      0.54 ± 0.71
# 318.  OD GOD         0.53 ± 0.51
# 319.  Penis Wings    0.53 ± 0.33
# 320.  RAIN           0.53 ± 0.24
# 321.  narumii        0.53 ± 0.80
# 322.  ffgr           0.51 ± 0.44
# 323.  Oink Oink      0.51 ± 0.37
# 324.  Thermostat     0.51 ± 0.81
# 325.  Ivanchuk       0.50 ± 0.40
# 326.  DibuMartinez   0.50 ± 0.93
# 327.  Barry Lakin    0.50 ± 0.33
# 328.  Chritt         0.50 ± 0.35
# 329.  Bilbo          0.50 ± 0.51
# 330.  KahnMan        0.49 ± 0.47
# 331.  TheNerve       0.49 ± 0.73
# 332.  Gavi           0.49 ± 0.77
# 333.  adawg          0.48 ± 0.67
# 334.  Ball-Is-Life   0.48 ± 0.54
# 335.  might dino     0.48 ± 0.62
# 336.  AtomicStorm    0.46 ± 1.07
# 337.  Bootymine      0.46 ± 0.89
# 338.  Gvendolino     0.46 ± 0.47
# 339.  Champagne      0.45 ± 0.36
# 340.  Rexer          0.45 ± 0.60
# 341.  g r e g        0.45 ± 0.60
# 342.  Bantoxic420    0.44 ± 0.91
# 343.  perpendcular   0.44 ± 0.73
# 344.  TheBob18       0.44 ± 0.81
# 345.  8-)            0.43 ± 0.66
# 346.  blue           0.43 ± 0.41
# 347.  ThePace        0.42 ± 0.57
# 348.  isaballa       0.42 ± 0.33
# 349.  sss            0.42 ± 0.33
# 350.  Fap            0.41 ± 1.00
# 351.  J24gordon      0.41 ± 0.78
# 352.  Phiip          0.40 ± 0.89
# 353.  Green          0.40 ± 0.70
# 354.  BaullGoodman   0.39 ± 0.92
# 355.  timo_tay       0.39 ± 0.50
# 356.  bubblez        0.39 ± 0.57
# 357.  BertAndBort    0.39 ± 0.76
# 358.  protag         0.38 ± 0.69
# 359.  Kemba Walker   0.38 ± 0.88
# 360.  KungFuKenny    0.38 ± 0.93
# 361.  GtR            0.38 ± 0.62
# 362.  cantstop       0.37 ± 0.57
# 363.  LiddiLidd      0.37 ± 0.31
# 364.  skibbity       0.36 ± 0.50
# 365.  Whathisface    0.36 ± 0.95
# 366.  2P1S           0.36 ± 0.65
# 367.  Sambal 1       0.36 ± 0.37
# 368.  kutrebar       0.35 ± 0.29
# 369.  McDavid        0.35 ± 0.88
# 370.  babyTron       0.35 ± 0.37
# 371.  Froce          0.35 ± 0.97
# 372.  N()()B         0.34 ± 0.48
# 373.  KonTiki        0.34 ± 0.84
# 374.  penguinharem   0.34 ± 0.85
# 375.  sieh           0.34 ± 0.53
# 376.  ballinout      0.34 ± 0.84
# 377.  note           0.33 ± 0.76
# 378.  Tyler Durden   0.32 ± 0.58
# 379.  Wilma          0.32 ± 0.35
# 380.  anom           0.32 ± 0.82
# 381.  AlysBrangwin   0.32 ± 0.95
# 382.  pho queue      0.31 ± 0.28
# 383.  Ganbalf        0.30 ± 0.71
# 384.  WhiteBallker   0.30 ± 1.01
# 385.  welp           0.29 ± 0.92
# 386.  doodleball     0.29 ± 0.82
# 387.  gl hf :)       0.28 ± 0.42
# 388.  ocd            0.28 ± 0.46
# 389.  TheProdigy     0.28 ± 0.61
# 390.  El Sacko       0.28 ± 0.56
# 391.  rc             0.28 ± 0.81
# 392.  T.Bomballdil   0.27 ± 0.32
# 393.  CatPuke        0.27 ± 0.76
# 394.  swiss          0.27 ± 0.70
# 395.  Acuraun        0.26 ± 0.83
# 396.  Doku           0.24 ± 0.38
# 397.  Some Ball 64   0.24 ± 0.78
# 398.  cw             0.24 ± 0.72
# 399.  drewfa         0.24 ± 0.50
# 400.  nlfn           0.24 ± 0.54
# 401.  Jed Bartlet    0.22 ± 0.51
# 402.  kink ball      0.22 ± 0.92
# 403.  Bonobo         0.22 ± 0.62
# 404.  phlasid        0.21 ± 0.38
# 405.  T/\GPRO        0.21 ± 0.45
# 406.  rai            0.21 ± 0.33
# 407.  coos :)        0.20 ± 0.72
# 408.  Makhachev      0.20 ± 0.55
# 409.  SmallyBigs     0.20 ± 0.45
# 410.  Zig!           0.20 ± 0.68
# 411.  Dad <|         0.19 ± 0.38
# 412.  RUFUS DU SOL   0.19 ± 0.63
# 413.  solongloser    0.18 ± 0.49
# 414.  Snowflaek      0.18 ± 0.67
# 415.  Guaderno       0.17 ± 0.61
# 416.  razgriz        0.16 ± 1.00
# 417.  Matt           0.16 ± 1.05
# 418.  Some Ball 1    0.15 ± 0.90
# 419.  Karasu         0.15 ± 0.52
# 420.  Subglacious    0.14 ± 1.04
# 421.  Food 4 Thots   0.12 ± 0.60
# 422.  FL             0.12 ± 0.42
# 423.  MaxW           0.11 ± 0.86
# 424.  MrDMoney       0.11 ± 0.40
# 425.  Sir Cle Jerk   0.11 ± 0.35
# 426.  DaBall 07      0.11 ± 0.95
# 427.  Pingu          0.11 ± 0.99
# 428.  KnicksFanTV    0.10 ± 0.50
# 429.  cereballsy     0.10 ± 0.57
# 430.  Waluigi        0.10 ± 0.84
# 431.  kwib           0.09 ± 0.47
# 432.  THESLIGHTEST   0.09 ± 0.40
# 433.  ~zion~         0.09 ± 0.74
# 434.  bronny james   0.08 ± 0.47
# 435.  Pickle Ball    0.08 ± 0.80
# 436.  CappinFalcon   0.08 ± 0.49
# 437.  Wegon Windis   0.08 ± 0.69
# 438.  Pres. TRUMP    0.08 ± 0.75
# 439.  For The Win    0.08 ± 0.87
# 440.  Ralph Wiggum   0.07 ± 0.67
# 441.  2k             0.07 ± 0.56
# 442.  cantab         0.06 ± 0.52
# 443.  laserpig       0.05 ± 0.35
# 444.  tRiP           0.05 ± 1.06
# 445.  pulpo          0.05 ± 0.55
# 446.  LethalSquirt   0.05 ± 0.41
# 447.  ADVICE MAN     0.04 ± 0.84
# 448.  sholmes        0.04 ± 0.45
# 449.  Atticus        0.03 ± 0.57
# 450.  Gyara          0.03 ± 0.48
# 451.  Chucho         0.03 ± 0.66
# 452.  vivvv          0.03 ± 0.54
# 453.  kika           0.02 ± 0.74
# 454.  kyri swirvin   0.02 ± 0.62
# 455.  JuiceWRLD999   0.02 ± 0.41
# 456.  philconnors    0.02 ± 0.48
# 457.  queef lord     0.01 ± 0.48
# 458.  suicidebypop   0.01 ± 0.34
# 459.  Werth          0.00 ± 0.78
# 460.  ROBOPOP_       0.00 ± 0.51
# 461.  G.O.A.T.       0.00 ± 0.44
# 462.  Roll Player   -0.01 ± 0.92
# 463.  Sam-          -0.01 ± 0.60
# 464.  Dragon  Ball  -0.01 ± 0.63
# 465.  ninja         -0.01 ± 0.35
# 466.  BaII          -0.02 ± 0.41
# 467.  poodIe        -0.02 ± 0.92
# 468.  gutenTag      -0.02 ± 0.39
# 469.  The Bhutan    -0.03 ± 0.65
# 470.  Crowman       -0.03 ± 0.78
# 471.  Therapist     -0.03 ± 0.85
# 472.  BalIgod       -0.03 ± 0.42
# 473.  Jackals       -0.03 ± 0.84
# 474.  gamja         -0.04 ± 1.00
# 475.  smalls        -0.04 ± 0.50
# 476.  snackpack     -0.04 ± 0.37
# 477.  Hangman       -0.04 ± 1.05
# 478.  Yo YoYo       -0.04 ± 0.38
# 479.  Pup Daddy     -0.05 ± 0.95
# 480.  #4 Meerkat    -0.05 ± 0.46
# 481.  Funky Spud    -0.05 ± 0.68
# 482.  beez          -0.05 ± 0.85
# 483.  smoji_        -0.05 ± 0.55
# 484.  RAZGRIZ       -0.05 ± 0.47
# 485.  Jelly Rat     -0.05 ± 0.49
# 486.  WRIG          -0.06 ± 0.96
# 487.  Dante Ball    -0.06 ± 0.87
# 488.  SomeKen       -0.06 ± 0.98
# 489.  benks         -0.06 ± 0.95
# 490.  Off Constant  -0.07 ± 0.59
# 491.  imaginary     -0.07 ± 0.38
# 492.  BoJack        -0.07 ± 0.81
# 493.  twelvefive    -0.07 ± 0.42
# 494.  TheYoungWolf  -0.07 ± 0.61
# 495.  Taddy Mason   -0.08 ± 0.38
# 496.  Eballs        -0.08 ± 0.87
# 497.  Shrimpster    -0.08 ± 0.94
# 498.  easily juked  -0.08 ± 0.92
# 499.  wallsquirrel  -0.08 ± 0.41
# 500.  Mystic        -0.09 ± 0.35
# 501.  some ball 1   -0.09 ± 0.72
# 502.  EpicJuker     -0.09 ± 0.83
# 503.  long ball     -0.09 ± 0.49
# 504.  12YrsABall    -0.10 ± 0.31
# 505.  shade         -0.10 ± 1.03
# 506.  SilentOne     -0.10 ± 0.57
# 507.  Mr. Waot      -0.11 ± 0.61
# 508.  Grass1        -0.11 ± 0.82
# 509.  PrettyLights  -0.11 ± 0.43
# 510.  AnthonyDavis  -0.11 ± 0.61
# 511.  thumper.      -0.12 ± 0.54
# 512.  Korgmonkey    -0.13 ± 0.35
# 513.  Euler         -0.13 ± 0.81
# 514.  oldAlt        -0.13 ± 0.56
# 515.  Vancouver     -0.14 ± 0.75
# 516.  BITW          -0.14 ± 0.60
# 517.  gspoon        -0.14 ± 0.34
# 518.  ><><><><><><  -0.14 ± 0.53
# 519.  Pimp          -0.15 ± 0.71
# 520.  praoprao      -0.15 ± 0.59
# 521.  Dirty         -0.15 ± 0.94
# 522.  TriP          -0.15 ± 0.75
# 523.  JukeOfEarl    -0.15 ± 0.57
# 524.  helprefugees  -0.16 ± 0.33
# 525.  lvy           -0.16 ± 0.71
# 526.  cherryrammer  -0.16 ± 0.72
# 527.  Darth         -0.17 ± 0.76
# 528.  C-3P0         -0.17 ± 0.95
# 529.  SumtimesGood  -0.17 ± 0.41
# 530.  Fusion        -0.17 ± 0.96
# 531.  Some Ball     -0.18 ± 0.89
# 532.  GnomeChomsky  -0.18 ± 1.01
# 533.  Trip          -0.18 ± 0.98
# 534.  Osy           -0.18 ± 0.59
# 535.  JGibbs        -0.18 ± 0.75
# 536.  Camel         -0.19 ± 0.82
# 537.  \m\=^_^=/m/   -0.19 ± 0.89
# 538.  Ducky         -0.19 ± 0.56
# 539.  Hjalpa        -0.20 ± 0.37
# 540.  Messy         -0.20 ± 0.32
# 541.  Ivy           -0.21 ± 0.87
# 542.  Oddball       -0.21 ± 0.66
# 543.  Better Mamba  -0.21 ± 0.39
# 544.  Comakip       -0.21 ± 0.99
# 545.  pontoon boat  -0.21 ± 0.55
# 546.  HammerTime    -0.22 ± 0.47
# 547.  CreedBratton  -0.22 ± 0.91
# 548.  my fault      -0.23 ± 0.65
# 549.  tweedle-dee   -0.24 ± 0.31
# 550.  tbiol         -0.24 ± 0.34
# 551.  Schweddys     -0.24 ± 0.43
# 552.  ZipZop        -0.24 ± 0.49
# 553.  No one        -0.24 ± 0.59
# 554.  megapoop22    -0.25 ± 0.37
# 555.  Dogmatic      -0.25 ± 0.52
# 556.  Marijuana     -0.26 ± 0.57
# 557.  Ballrog       -0.26 ± 0.54
# 558.  hihi!         -0.26 ± 0.46
# 559.  Fae           -0.28 ± 0.68
# 560.  TheGovernor   -0.28 ± 0.64
# 561.  I suck at tp  -0.28 ± 0.48
# 562.  TOP CAT       -0.29 ± 1.02
# 563.  choder        -0.29 ± 1.00
# 564.  Ken Blocks    -0.29 ± 0.78
# 565.  Blip          -0.30 ± 0.90
# 566.  Sgt Ducky     -0.30 ± 0.72
# 567.  Remilio       -0.30 ± 0.54
# 568.  LucilleBall   -0.30 ± 0.56
# 569.  I_mess_up     -0.30 ± 0.71
# 570.  NevaPopAgain  -0.31 ± 0.84
# 571.  baked F       -0.31 ± 1.00
# 572.  `ArryKane     -0.32 ± 0.41
# 573.  Skippy        -0.32 ± 0.68
# 574.  Neph          -0.32 ± 0.82
# 575.  KALX          -0.33 ± 0.38
# 576.  Beach         -0.33 ± 0.52
# 577.  whiff         -0.33 ± 0.31
# 578.  Robiny        -0.33 ± 0.44
# 579.  Music         -0.33 ± 0.89
# 580.  Salmond Milk  -0.33 ± 1.00
# 581.  havok         -0.33 ± 0.48
# 582.  PenFifteen    -0.34 ± 0.40
# 583.  Makin Bacon   -0.34 ± 0.52
# 584.  JimBobCooter  -0.35 ± 0.59
# 585.  Sussy Blocka  -0.35 ± 0.79
# 586.  Cupid         -0.35 ± 0.43
# 587.  I <3 Emacs    -0.35 ± 0.72
# 588.  Monte.        -0.35 ± 0.69
# 589.  jl            -0.36 ± 0.89
# 590.  EvTheSmev     -0.36 ± 0.47
# 591.  Zoltan Mesko  -0.36 ± 0.73
# 592.  PBN           -0.37 ± 0.56
# 593.  kick ankles   -0.37 ± 0.66
# 594.  om            -0.38 ± 0.56
# 595.  being         -0.38 ± 0.52
# 596.  DiegoOnMac    -0.38 ± 0.50
# 597.  RoughJustice  -0.38 ± 0.94
# 598.  korso         -0.39 ± 1.05
# 599.  `AppleKane    -0.39 ± 0.42
# 600.  oatz_mgoatz   -0.39 ± 0.31
# 601.  3.1 Thor      -0.39 ± 0.65
# 602.  SpeedyOwnt    -0.39 ± 0.79
# 603.  Some Ball 11  -0.39 ± 0.64
# 604.  MollyScully   -0.39 ± 0.92
# 605.  MickTagger    -0.40 ± 0.97
# 606.  13 volcanos   -0.40 ± 1.05
# 607.  ballparts     -0.41 ± 1.05
# 608.  helpful       -0.41 ± 0.94
# 609.  gc            -0.42 ± 1.04
# 610.  bones         -0.42 ± 0.88
# 611.  Sinatra       -0.42 ± 0.35
# 612.  Cashews       -0.43 ± 0.43
# 613.  Vedic D       -0.43 ± 0.42
# 614.  /~            -0.43 ± 0.96
# 615.  TigertheLion  -0.43 ± 0.61
# 616.  Om Vril       -0.44 ± 0.48
# 617.  S. Strasball  -0.44 ± 0.57
# 618.  NateH         -0.44 ± 0.41
# 619.  Doc Balliday  -0.44 ± 0.62
# 620.  GoodyGood     -0.45 ± 0.56
# 621.  CBad          -0.45 ± 0.34
# 622.  CoolHandJuke  -0.45 ± 0.32
# 623.  JIMBOBCOOTER  -0.45 ± 0.40
# 624.  Mr. Boop      -0.45 ± 1.07
# 625.  t('_'t)       -0.45 ± 0.82
# 626.  thiery        -0.46 ± 1.02
# 627.  Monorchid     -0.46 ± 0.99
# 628.  ish           -0.46 ± 0.46
# 629.  SphinctrSlyr  -0.46 ± 0.90
# 630.  chaotiq       -0.47 ± 1.03
# 631.  VerniSanders  -0.47 ± 0.59
# 632.  NUTSNUTSNUTS  -0.47 ± 0.48
# 633.  gueromoon     -0.47 ± 0.40
# 634.  JukeBerallta  -0.48 ± 0.38
# 635.  skee lo       -0.48 ± 0.53
# 636.  SpiritTagger  -0.48 ± 0.47
# 637.  Splatacus     -0.49 ± 0.77
# 638.  Barbara Bush  -0.50 ± 0.55
# 639.  Dad Jokes!    -0.50 ± 0.45
# 640.  FragrantFowl  -0.50 ± 0.76
# 641.  Palps         -0.51 ± 1.01
# 642.  ScreamCheese  -0.51 ± 0.59
# 643.  MDK           -0.51 ± 0.46
# 644.  KOB           -0.51 ± 1.05
# 645.  sicky         -0.51 ± 0.40
# 646.  Sommeballier  -0.51 ± 0.41
# 647.  Ebhawk        -0.52 ± 0.51
# 648.  Jarek         -0.52 ± 0.51
# 649.  sminitrious   -0.52 ± 0.94
# 650.  Puggins       -0.52 ± 0.71
# 651.  Khepri        -0.52 ± 0.78
# 652.  JimmyRed      -0.53 ± 1.05
# 653.  Chuggles      -0.53 ± 0.61
# 654.  WinCtrlShftB  -0.53 ± 1.03
# 655.  lemonate      -0.54 ± 0.88
# 656.  DF            -0.54 ± 0.32
# 657.  Oscillator    -0.54 ± 0.92
# 658.  Double A      -0.54 ± 0.92
# 659.  fl33t         -0.54 ± 0.30
# 660.  barrel roll   -0.55 ± 0.93
# 661.  Snot Boogie   -0.55 ± 0.34
# 662.  profquibb     -0.55 ± 1.01
# 663.  yumad2.0      -0.55 ± 0.76
# 664.  DuckDuckJuke  -0.55 ± 0.67
# 665.  umad          -0.55 ± 0.81
# 666.  Farva         -0.56 ± 0.46
# 667.  Hurri         -0.56 ± 1.01
# 668.  TeaForYou&Me  -0.56 ± 0.50
# 669.  Larry Fish    -0.56 ± 0.67
# 670.  fronk         -0.56 ± 0.68
# 671.  RageQuit      -0.56 ± 0.68
# 672.  Quickdraw     -0.58 ± 0.67
# 673.  let me cook   -0.58 ± 0.77
# 674.  Tagger Woods  -0.58 ± 0.46
# 675.  Lube          -0.58 ± 0.89
# 676.  BilldaCat     -0.59 ± 0.64
# 677.  Fuck          -0.59 ± 0.88
# 678.  drinks?       -0.59 ± 0.47
# 679.  Smurfish      -0.59 ± 0.67
# 680.  Arctic_Tern   -0.61 ± 0.89
# 681.  timeboy       -0.61 ± 0.43
# 682.  Glimmer       -0.61 ± 0.80
# 683.  wonsu         -0.61 ± 0.56
# 684.  taskforce     -0.61 ± 0.92
# 685.  Poppenheimer  -0.62 ± 0.57
# 686.  NeYo          -0.62 ± 0.60
# 687.  Rayn          -0.63 ± 0.61
# 688.  CoffeeSnoot   -0.63 ± 0.51
# 689.  Nutty18       -0.64 ± 0.89
# 690.  ANDYKANSAS    -0.65 ± 0.56
# 691.  Shit          -0.65 ± 0.61
# 692.  Lysdexic      -0.65 ± 0.91
# 693.  Way Maker     -0.65 ± 0.80
# 694.  State Champ   -0.66 ± 0.60
# 695.  AmishVacuum   -0.66 ± 0.57
# 696.  SaladRT       -0.66 ± 0.91
# 697.  thierryonre   -0.66 ± 0.69
# 698.  Castrator     -0.67 ± 0.41
# 699.  Hockeypuck    -0.67 ± 0.38
# 700.  Headhunter    -0.68 ± 0.84
# 701.  Mystery Box   -0.69 ± 1.01
# 702.  Snekster      -0.69 ± 0.60
# 703.  Phil Ballins  -0.69 ± 0.57
# 704.  TheDr34m      -0.69 ± 0.75
# 705.  B)            -0.69 ± 0.51
# 706.  clovis        -0.69 ± 0.61
# 707.  Battletoad    -0.70 ± 0.69
# 708.  Glizzy        -0.70 ± 0.95
# 709.  Homer Jay     -0.71 ± 0.44
# 710.  Soccertanker  -0.71 ± 0.87
# 711.  spills        -0.72 ± 0.76
# 712.  Black Mamba   -0.72 ± 0.95
# 713.  mrme          -0.72 ± 1.02
# 714.  1 Pixel Juke  -0.72 ± 0.58
# 715.  greenfish     -0.72 ± 0.88
# 716.  GetPupsDeep   -0.72 ± 0.64
# 717.  555555555555  -0.72 ± 0.64
# 718.  MURF          -0.74 ± 0.34
# 719.  name a fish   -0.74 ± 0.67
# 720.  hola          -0.74 ± 1.04
# 721.  draugr        -0.74 ± 0.57
# 722.  MoGGee        -0.75 ± 0.41
# 723.  Secondskin    -0.75 ± 0.85
# 724.  Keyser Soze   -0.75 ± 0.53
# 725.  Howard        -0.76 ± 0.92
# 726.  SWAGSTEIN2.0  -0.76 ± 0.65
# 727.  Flat Earth    -0.76 ± 0.36
# 728.  dyd           -0.77 ± 0.31
# 729.  GeeGee        -0.77 ± 0.88
# 730.  yioSh         -0.77 ± 0.46
# 731.  karthvader    -0.79 ± 0.87
# 732.  bennyclub     -0.79 ± 0.70
# 733.  Squish        -0.79 ± 0.58
# 734.  McQueen       -0.80 ± 0.98
# 735.  Moth-Ball     -0.80 ± 0.64
# 736.  Some Boat 1   -0.81 ± 0.71
# 737.  ICE AGENT     -0.81 ± 1.02
# 738.  hail santa    -0.81 ± 0.46
# 739.  GREENUSER     -0.82 ± 0.82
# 740.  Yandex        -0.82 ± 0.55
# 741.  ChuckNastii   -0.82 ± 0.97
# 742.  Ragnar        -0.83 ± 0.38
# 743.  urkel         -0.83 ± 0.77
# 744.  Imortallix    -0.84 ± 0.83
# 745.  Optimal Taco  -0.85 ± 0.41
# 746.  Bow Down      -0.85 ± 0.43
# 747.  nej           -0.86 ± 0.33
# 748.  Lirath        -0.86 ± 0.76
# 749.  rolf          -0.86 ± 0.91
# 750.  portimao      -0.88 ± 0.58
# 751.  slime666      -0.88 ± 0.76
# 752.  dryfus        -0.90 ± 0.88
# 753.  TheNippIe     -0.90 ± 0.63
# 754.  Inception     -0.90 ± 0.70
# 755.  11th Cmndmnt  -0.90 ± 0.53
# 756.  Locomotive    -0.90 ± 0.62
# 757.  ALCAEUS       -0.92 ± 0.90
# 758.  FlyingV       -0.92 ± 0.35
# 759.  Mueller       -0.92 ± 0.67
# 760.  BadTrash      -0.92 ± 0.72
# 761.  Duckquack     -0.93 ± 0.89
# 762.  PuyoPuyo      -0.93 ± 0.26
# 763.  supergremlin  -0.93 ± 0.59
# 764.  JEERIE        -0.94 ± 0.50
# 765.  TERROR NUGS   -0.94 ± 0.78
# 766.  TheWorst      -0.95 ± 0.50
# 767.  regicide      -0.96 ± 0.89
# 768.  N1GHT5TA1KER  -0.97 ± 0.85
# 769.  Swully        -0.97 ± 0.34
# 770.  A Straw Hat   -0.97 ± 0.43
# 771.  Ace93         -0.98 ± 1.05
# 772.  Horizon       -0.98 ± 0.37
# 773.  speed kerr    -0.99 ± 0.50
# 774.  Sphero Agnew  -0.99 ± 0.47
# 775.  Tunabomber    -1.00 ± 0.95
# 776.  Fenek         -1.00 ± 0.72
# 777.  trash panda   -1.00 ± 0.41
# 778.  SIGKILL       -1.00 ± 0.85
# 779.  Bidet->Wipe   -1.00 ± 0.93
# 780.  Belacqua      -1.01 ± 0.54
# 781.  Gubbles       -1.01 ± 0.42
# 782.  Riley_2025    -1.02 ± 0.76
# 783.  JUKELELE      -1.02 ± 0.74
# 784.  Quacky        -1.03 ± 0.91
# 785.  Ann with a E  -1.03 ± 0.79
# 786.  ktAMroR0      -1.05 ± 0.91
# 787.  tomatoo       -1.05 ± 1.06
# 788.  Chungo        -1.06 ± 0.95
# 789.  Rabz          -1.06 ± 0.59
# 790.  PotatoPotato  -1.06 ± 0.74
# 791.  Crasher       -1.07 ± 0.34
# 792.  Bambi         -1.07 ± 0.60
# 793.  Hairy Nuts    -1.07 ± 0.41
# 794.  nutbutt       -1.08 ± 0.47
# 795.  TicklMeElmo   -1.08 ± 0.91
# 796.  bash#         -1.08 ± 0.46
# 797.  pliny         -1.08 ± 0.72
# 798.  whosagoodboy  -1.09 ± 0.98
# 799.  aeps002       -1.09 ± 0.75
# 800.  BUTT          -1.09 ± 0.43
# 801.  MOOOOOOOOOOO  -1.09 ± 0.68
# 802.  ^_^           -1.09 ± 0.85
# 803.  MacbookProM4  -1.10 ± 0.78
# 804.  coos          -1.11 ± 1.03
# 805.  Sick Fuck     -1.12 ± 0.84
# 806.  brx           -1.13 ± 0.81
# 807.  ARoseOTGrey   -1.14 ± 1.04
# 808.  MyLittlePony  -1.14 ± 0.29
# 809.  KnightKnight  -1.14 ± 1.02
# 810.  Sminitrious   -1.14 ± 0.80
# 811.  Goofy Goober  -1.15 ± 0.63
# 812.  Rat King      -1.15 ± 0.97
# 813.  buttcheeks    -1.15 ± 0.90
# 814.  13.5 inches   -1.15 ± 0.90
# 815.  RoVo          -1.16 ± 0.71
# 816.  Dayman        -1.16 ± 0.29
# 817.  dadman        -1.16 ± 0.64
# 818.  armed walrus  -1.16 ± 0.71
# 819.  GooeyS7       -1.17 ± 0.56
# 820.  DMT           -1.18 ± 0.99
# 821.  KoaIa Beast   -1.20 ± 0.34
# 822.  @pro          -1.20 ± 0.67
# 823.  Glass Marble  -1.21 ± 0.81
# 824.  T_Y           -1.21 ± 0.80
# 825.  OFFENSE OWEN  -1.22 ± 1.03
# 826.  Photonic S    -1.22 ± 0.82
# 827.  d/t           -1.23 ± 0.63
# 828.  BarryBerkman  -1.24 ± 0.73
# 829.  JareksMom     -1.24 ± 0.98
# 830.  Garry Lakin   -1.25 ± 0.41
# 831.  Tiffany       -1.26 ± 0.73
# 832.  bhawks4life1  -1.27 ± 0.58
# 833.  lemming       -1.28 ± 0.42
# 834.  Swift         -1.28 ± 0.79
# 835.  Ibrahimovic   -1.28 ± 1.00
# 836.  SomeBall41    -1.30 ± 0.82
# 837.  fah q         -1.31 ± 0.37
# 838.  itagpro       -1.31 ± 1.04
# 839.  SuperPoopman  -1.31 ± 0.88
# 840.  icancountto3  -1.31 ± 0.40
# 841.  glyyyde       -1.32 ± 0.99
# 842.  Fatback slim  -1.33 ± 0.51
# 843.  Codpeace      -1.35 ± 0.41
# 844.  MRCOW         -1.35 ± 0.47
# 845.  openseance    -1.35 ± 0.91
# 846.  EBITDA        -1.36 ± 0.83
# 847.  Unaballer     -1.36 ± 0.55
# 848.  metalhead     -1.37 ± 0.46
# 849.  BasedBall     -1.40 ± 0.94
# 850.  Valerian      -1.40 ± 0.99
# 851.  Exsufflicate  -1.40 ± 0.78
# 852.  Pythagoras    -1.41 ± 0.44
# 853.  Jurj          -1.41 ± 1.06
# 854.  treyk47       -1.41 ± 0.88
# 855.  ShadoWolves   -1.41 ± 0.91
# 856.  emuwarvet     -1.42 ± 0.76
# 857.  Daniel        -1.43 ± 0.53
# 858.  Sawney        -1.46 ± 0.66
# 859.  kojiro        -1.46 ± 0.91
# 860.  Jessa         -1.47 ± 0.91
# 861.  Ethan         -1.47 ± 1.07
# 862.  Blaatina      -1.47 ± 0.49
# 863.  BOFA          -1.47 ± 0.52
# 864.  Nazar         -1.47 ± 0.50
# 865.  I SHOUT       -1.49 ± 0.48
# 866.  Modric        -1.51 ± 0.62
# 867.  a frog        -1.51 ± 0.48
# 868.  Phenomenal    -1.52 ± 0.75
# 869.  Darth JarJar  -1.52 ± 0.75
# 870.  bryte         -1.52 ± 0.73
# 871.  Gemini        -1.55 ± 0.52
# 872.  LilB:BallGod  -1.55 ± 0.54
# 873.  Hugo Ball     -1.55 ± 0.83
# 874.  Don Garyoni   -1.56 ± 0.60
# 875.  Errmergerd    -1.56 ± 0.89
# 876.  SoulSauce     -1.56 ± 0.52
# 877.  Skrt          -1.57 ± 0.83
# 878.  Sway          -1.58 ± 0.66
# 879.  I_S_Someball  -1.58 ± 0.89
# 880.  UmamiThurman  -1.58 ± 0.94
# 881.  DadFane       -1.58 ± 0.67
# 882.  nightball     -1.59 ± 0.80
# 883.  Yamz          -1.60 ± 0.90
# 884.  Some Ball X   -1.61 ± 0.86
# 885.  notsosober    -1.61 ± 0.54
# 886.  not hamsun    -1.62 ± 0.87
# 887.  Hellball2079  -1.62 ± 0.36
# 888.  Macbuckets    -1.64 ± 1.07
# 889.  Thorfinn      -1.64 ± 0.49
# 890.  lowermywin%   -1.64 ± 0.51
# 891.  Esteban123    -1.66 ± 0.90
# 892.  Random        -1.67 ± 0.90
# 893.  Quaky20       -1.67 ± 0.60
# 894.  Sweg'         -1.67 ± 0.96
# 895.  dewgazi       -1.68 ± 0.89
# 896.  wherdeyatdoe  -1.68 ± 0.73
# 897.  Zeke          -1.68 ± 0.71
# 898.  dabang khan   -1.69 ± 0.58
# 899.  Damian        -1.71 ± 0.39
# 900.  Bread         -1.73 ± 0.74
# 901.  Regicide      -1.73 ± 0.32
# 902.  JJIIZGOD      -1.76 ± 0.96
# 903.  BertaLovejoy  -1.76 ± 0.81
# 904.  prelude:)     -1.77 ± 0.78
# 905.  memnite       -1.78 ± 0.87
# 906.  fone          -1.79 ± 1.03
# 907.  gprimoff      -1.81 ± 0.54
# 908.  free advice   -1.83 ± 0.41
# 909.  ipopu         -1.84 ± 0.74
# 910.  FRIOCK        -1.85 ± 0.75
# 911.  TitMouse      -1.85 ± 0.93
# 912.  SeymourButts  -1.86 ± 1.02
# 913.  `~`           -1.88 ± 0.45
# 914.  Thanksman     -1.89 ± 0.58
# 915.  Pins&Needles  -1.90 ± 1.02
# 916.  twirly        -1.90 ± 0.38
# 917.  chaiwala      -1.92 ± 0.90
# 918.  tman          -1.93 ± 0.81
# 919.  CarryMyBall   -1.94 ± 0.42
# 920.  glizzy23      -2.04 ± 0.58
# 921.  FFFlier       -2.05 ± 1.01
# 922.  Color Blind   -2.07 ± 0.61
# 923.  Notgreat      -2.07 ± 1.00
# 924.  terrrrriball  -2.10 ± 0.62
# 925.  So Cool       -2.10 ± 0.99
# 926.  sbxxvi        -2.11 ± 0.51
# 927.  MOTU          -2.13 ± 0.68
# 928.  Toaster       -2.13 ± 0.95
# 929.  Youareyou     -2.14 ± 0.65
# 930.  Some Baloney  -2.15 ± 0.96
# 931.  rizzmaster    -2.17 ± 0.73
# 932.  Terry         -2.19 ± 0.80
# 933.  chgtus        -2.19 ± 0.49
# 934.  sinagot       -2.20 ± 0.65
# 935.  abby :)       -2.21 ± 0.54
# 936.  Israel Lives  -2.25 ± 0.41
# 937.  Big Bang      -2.28 ± 0.48
# 938.  TrustJesus69  -2.31 ± 0.45
# 939.  Liddi         -2.33 ± 0.44
# 940.  I AM          -2.33 ± 0.79
# 941.  phyllis       -2.35 ± 0.45
# 942.  yeehaa        -2.40 ± 0.84
# 943.  Rascasse      -2.40 ± 0.86
# 944.  stall2hammer  -2.45 ± 0.40
# 945.  elonmusk      -2.45 ± 0.40
# 946.  Doc           -2.46 ± 0.85
# 947.  Avsy26        -2.51 ± 0.66
# 948.  MrBeaver      -2.52 ± 0.95
# 949.  Morphism      -2.52 ± 0.61
# 950.  OlliePoppi    -2.56 ± 0.49
# 951.  JukeofFrance  -2.56 ± 0.88
# 952.  RodandoAndo   -2.61 ± 0.94
# 953.  j             -2.65 ± 0.90
# 954.  Sodyn33       -2.67 ± 0.69
# 955.  rollingstone  -2.69 ± 0.81
# 956.  Marblmadness  -2.71 ± 0.38
# 957.  Skip          -2.71 ± 1.00
# 958.  Orinoco Flow  -2.73 ± 0.72
# 959.  KONY          -2.77 ± 0.75
# 960.  Dxebec        -2.77 ± 0.62
# 961.  AVP           -2.78 ± 0.50
# 962.  I'mBoutDat    -2.80 ± 0.34
# 963.  RoyaltyKeyz   -2.85 ± 0.90
# 964.  tutorial_wiz  -2.87 ± 0.61
# 965.  Rizz          -2.92 ± 0.92
# 966.  Relax         -3.01 ± 0.97
# 967.  Argo4444      -3.01 ± 0.99
# 968.  EZDtingCoach  -3.24 ± 0.75
# 969.  BobTheBob     -3.29 ± 0.84
# 970.  Floyd         -3.36 ± 0.85
# 971.  G lander!     -3.52 ± 0.84
# 972.  darfo38       -4.74 ± 0.71

# %%
for m in matches:
    for p in m['players']:
        p['updates']['final_elo'] = players[p['name']].elo
        p['updates']['final_var'] = players[p['name']].variance
    red_elo = sum(players[p['name']].elo for p in m['players'][:4])
    blue_elo = sum(players[p['name']].elo for p in m['players'][4:])
    retro_pred = red_elo - blue_elo #+ RED_ADVANTAGE[
    #     match['map_name'] if match['map_name'] in RED_ADVANTAGE else 'default'
    # ]
    retro_var = BASE_VARIANCE + sum(players[p['name']].variance for p in m['players'])
    retro_wp = 1 / (1 + CAP_TO_WP_EXPONENT ** -retro_pred)
    m['retro_red_elo'] = red_elo
    m['retro_blue_elo'] = blue_elo
    m['retro_pred'] = retro_pred
    m['retro_residual'] = m['cap_diff'] - m['retro_pred']
    m['retro_sd'] = retro_var ** 0.5
    m['retro_wp'] = retro_wp
    m['retro_wwp'] = retro_wp if m['cap_diff'] > 0 else 1 - retro_wp

print(f"MAE: {sum([abs(m['retro_residual']) for m in matches]) / len(matches):.4f}    RMS: {(sum([m['retro_residual'] ** 2 for m in matches]) / len(matches)) ** 0.5:.4f}")
print(f"COR: {sum([(1 if m['retro_wwp'] > 0.5 else 0.5 if m['retro_wwp'] == 0.5 else 0) for m in matches]) / len(matches):.2%}    WWP: {sum(m['retro_wwp'] for m in matches) / len(matches):.2%}")
print(f"BRI: {1 - (sum([(1 - m['retro_wwp']) ** 2 for m in matches]) / len(matches)) ** 0.5:.2%}    LOG: {2 ** (sum([math.log2(m['retro_wwp']) for m in matches]) / len(matches)):.2%}")
# Out:
# MAE: 2.3781    RMS: 2.8913
# COR: 61.76%    WWP: 54.96%
# BRI: 52.33%    LOG: 52.49%

# %% [markdown]
# ### Forensics

# %%
def player_stat_averages(player_name):
    total_caps = 0
    total_returns = 0
    total_hold = 0
    total_prevent = 0
    player_pups = 0
    total_games = 0
    pups_spawned = 0
    for m in matches:
        player_in_game = False
        pups_in_game = 0
        for p in m['players']:
            pups_in_game += p['stats']['pups']
            if p['name'] == player_name:
                player_in_game = True
                player_pups += p['stats']['pups']
                total_caps += p['stats']['caps']
                total_returns += p['stats']['returns']
                total_hold += p['stats']['hold']
                total_prevent += p['stats']['prevent']
                total_games += 1
        if player_in_game:
            pups_spawned += pups_in_game
    if pups_spawned == 0:
        return {
            'cpg': 0,
            'hpg': 0,
            'rpg': 0,
            'ppg': 0,
            'pup%': 0,
        }
    return {
        'cpg': total_caps / total_games,
        'hpg': total_hold / total_games / 60,
        'rpg': total_returns / total_games,
        'ppg': total_prevent / total_games / 60,
        'pup%': player_pups / pups_spawned,
    }

# %%
s0_only_leaderboard = sorted([
    p for p in players.values()
    if p.variance <= MAX_VARIANCE_TO_COUNT_AS_KNOWN and
    p.elo > 1 and
    all(m['match_id'] < 4148840 for m in matches if any(pl['name'] == p.name for pl in m['players']))
], key=lambda p: p.elo, reverse=True)

# %%
for i, p in enumerate(s0_only_leaderboard):
    player_stats = player_stat_averages(p.name)
    print(f"{i + 1:>3}.  {p.name:<12}  {p.elo:5.2f} ± {1.96 * p.variance ** 0.5:.2f}  {player_stats['cpg']:>4.2f} cpg  {player_stats['rpg']:>4.1f} rpg  {player_stats['hpg']:>3.0f} hpg  {player_stats['ppg']:>3.0f} ppg  {player_stats['pup%']:>5.1%} pup%")
# Out:
#   1.  okthen         3.29 ± 0.68  1.23 cpg   8.9 rpg   79 hpg   44 ppg  15.0% pup%
#   2.  Xx360NoSwagx   2.86 ± 0.74  0.88 cpg  12.8 rpg   47 hpg   84 ppg  16.3% pup%
#   3.  Jester101      2.72 ± 1.03  1.64 cpg  10.2 rpg   98 hpg   19 ppg  16.7% pup%
#   4.  bright         2.66 ± 0.64  1.07 cpg   9.2 rpg   74 hpg   45 ppg  20.8% pup%
#   5.  bitter heart   2.57 ± 0.91  0.71 cpg  13.9 rpg   45 hpg   85 ppg  15.0% pup%
#   6.  Ritual         2.48 ± 0.64  0.92 cpg  10.9 rpg   59 hpg   70 ppg  14.2% pup%
#   7.  frieren        2.44 ± 0.90  1.09 cpg  10.8 rpg   66 hpg   52 ppg  17.9% pup%
#   8.  Madoka         2.41 ± 0.83  0.85 cpg  10.6 rpg   60 hpg   58 ppg  16.9% pup%
#   9.  1deag          2.26 ± 0.61  0.82 cpg  10.7 rpg   52 hpg   62 ppg  19.9% pup%
#  10.  HelloI'mGurt   2.25 ± 1.02  0.55 cpg  17.3 rpg   43 hpg   84 ppg  22.5% pup%
#  11.  Doris          2.15 ± 0.67  0.97 cpg   9.6 rpg   65 hpg   58 ppg  15.2% pup%
#  12.  Ball-E         2.09 ± 0.82  1.25 cpg   8.0 rpg   79 hpg   43 ppg  10.8% pup%
#  13.  i love HD      2.08 ± 0.95  0.70 cpg  13.9 rpg   32 hpg   72 ppg  20.9% pup%
#  14.  swerve         2.06 ± 1.02  1.50 cpg   8.1 rpg   86 hpg   27 ppg  17.2% pup%
#  15.  eee            2.04 ± 0.67  1.04 cpg   8.3 rpg   80 hpg   34 ppg  13.9% pup%
#  16.  SakuUta        1.85 ± 0.64  0.76 cpg  10.4 rpg   61 hpg   62 ppg  11.8% pup%
#  17.  vanitas        1.81 ± 1.01  1.43 cpg   8.6 rpg  105 hpg   13 ppg  11.6% pup%
#  18.  Homie          1.81 ± 0.63  1.14 cpg   8.0 rpg   86 hpg   43 ppg  13.7% pup%
#  19.  ||||||||||||   1.67 ± 0.89  1.40 cpg   7.9 rpg   94 hpg   13 ppg  10.2% pup%
#  20.  keithstoned1   1.61 ± 0.98  0.80 cpg  10.7 rpg   68 hpg   67 ppg  13.5% pup%
#  21.  yep            1.54 ± 0.66  1.01 cpg  11.3 rpg   63 hpg   61 ppg  17.4% pup%
#  22.  Jinjo          1.51 ± 0.88  1.22 cpg   8.5 rpg   76 hpg   43 ppg  10.1% pup%
#  23.  DudeMcGuy      1.48 ± 0.93  0.73 cpg   9.8 rpg   51 hpg   70 ppg  12.3% pup%
#  24.  Boat           1.48 ± 0.87  1.06 cpg   9.6 rpg   72 hpg   53 ppg  12.1% pup%
#  25.  tune           1.46 ± 0.81  1.31 cpg   8.1 rpg   92 hpg   17 ppg  11.1% pup%
#  26.  Niplepotamus   1.45 ± 0.89  0.76 cpg   9.1 rpg   56 hpg   65 ppg  16.3% pup%
#  27.  Jer32          1.44 ± 0.81  0.99 cpg   7.7 rpg   71 hpg   48 ppg  15.9% pup%
#  28.  kasli          1.44 ± 0.83  0.64 cpg  10.4 rpg   48 hpg   75 ppg  19.4% pup%
#  29.  Frank          1.43 ± 0.96  0.98 cpg   9.5 rpg   69 hpg   67 ppg  11.9% pup%
#  30.  Ball of Fame   1.43 ± 1.00  0.45 cpg  11.7 rpg   39 hpg   87 ppg  10.4% pup%
#  31.  DingusDongus   1.42 ± 0.88  0.80 cpg   8.7 rpg   59 hpg   51 ppg  15.2% pup%
#  32.  Irony          1.42 ± 0.57  0.95 cpg   8.9 rpg   67 hpg   57 ppg  14.5% pup%
#  33.  Light          1.42 ± 0.57  0.99 cpg   7.7 rpg   73 hpg   31 ppg  11.9% pup%
#  34.  St. Bernard    1.40 ± 0.79  0.56 cpg  13.0 rpg   64 hpg   72 ppg  18.4% pup%
#  35.  Sphear         1.39 ± 1.03  0.67 cpg  11.9 rpg   55 hpg   73 ppg  11.2% pup%
#  36.  StaIin         1.37 ± 0.69  0.63 cpg  10.6 rpg   54 hpg   64 ppg   7.8% pup%
#  37.  Mos Def        1.35 ± 0.61  0.66 cpg  12.0 rpg   47 hpg   81 ppg  10.0% pup%
#  38.  Gamepad God    1.34 ± 0.73  1.03 cpg   9.7 rpg   77 hpg   42 ppg  12.8% pup%
#  39.  snuffed        1.33 ± 0.91  0.61 cpg  13.4 rpg   41 hpg  111 ppg  13.3% pup%
#  40.  Shaolin        1.32 ± 0.85  1.07 cpg  10.6 rpg   64 hpg   60 ppg   8.7% pup%
#  41.  clew3          1.32 ± 0.94  0.48 cpg  11.1 rpg   39 hpg   86 ppg  17.5% pup%
#  42.  JBaay          1.32 ± 0.92  1.15 cpg   9.0 rpg   71 hpg   25 ppg  18.2% pup%
#  43.  Kei Yonagi     1.29 ± 0.76  1.00 cpg   7.1 rpg   73 hpg   28 ppg  12.2% pup%
#  44.  DEAD NAN       1.28 ± 0.78  1.17 cpg   7.9 rpg   89 hpg   43 ppg  16.2% pup%
#  45.  MarkBallis     1.28 ± 0.86  1.21 cpg   8.4 rpg   62 hpg   45 ppg  13.0% pup%
#  46.  Ballzilla      1.20 ± 0.86  0.82 cpg   9.7 rpg   57 hpg   58 ppg  12.0% pup%
#  47.  George         1.19 ± 0.90  0.95 cpg   7.5 rpg   68 hpg   29 ppg  14.8% pup%
#  48.  Jason Bourne   1.16 ± 0.99  1.15 cpg   8.8 rpg  103 hpg   28 ppg  16.9% pup%
#  49.  Kamikaze       1.12 ± 0.71  1.08 cpg   9.8 rpg   82 hpg   36 ppg  13.9% pup%
#  50.  bleast         1.09 ± 1.04  1.49 cpg   6.7 rpg   85 hpg   25 ppg  12.2% pup%
#  51.  yippie         1.09 ± 0.96  1.25 cpg   7.9 rpg   85 hpg   29 ppg  10.0% pup%
#  52.  lizzey         1.07 ± 0.80  0.65 cpg  10.9 rpg   51 hpg   67 ppg  12.9% pup%
#  53.  Armbranch      1.04 ± 0.87  0.57 cpg  10.2 rpg   46 hpg   74 ppg  16.9% pup%
#  54.  P-d0g          1.02 ± 0.88  0.56 cpg  10.5 rpg   49 hpg   93 ppg   9.7% pup%
#  55.  Big D          1.01 ± 0.99  0.89 cpg   9.0 rpg   74 hpg   45 ppg  12.9% pup%

# %%
s1_only_leaderboard = sorted([
    p for p in players.values()
    if p.variance <= MAX_VARIANCE_TO_COUNT_AS_KNOWN and
    p.elo > 0.5 and
    all(m['match_id'] >= 4148840 for m in matches if any(pl['name'] == p.name for pl in m['players']))
], key=lambda p: p.elo, reverse=True)

# %%
for i, p in enumerate(s1_only_leaderboard):
    player_stats = player_stat_averages(p.name)
    print(f"{i + 1:>3}.  {p.name:<12}  {p.elo:5.2f} ± {1.96 * p.variance ** 0.5:.2f}  {player_stats['cpg']:>4.2f} cpg  {player_stats['rpg']:>4.1f} rpg  {player_stats['hpg']:>3.0f} hpg  {player_stats['ppg']:>3.0f} ppg  {player_stats['pup%']:>5.1%} pup%")
# Out:
#   1.  Cape           2.48 ± 0.77  1.19 cpg  11.7 rpg   73 hpg   49 ppg  19.5% pup%
#   2.  HvN Piercer    2.46 ± 0.32  0.80 cpg  11.5 rpg   58 hpg   59 ppg  17.9% pup%
#   3.  Xylene         2.11 ± 0.44  0.97 cpg  10.6 rpg   58 hpg   59 ppg  13.9% pup%
#   4.  known          1.89 ± 0.40  0.94 cpg  10.0 rpg   64 hpg   64 ppg  14.2% pup%
#   5.  Nas            1.80 ± 0.39  0.70 cpg  12.0 rpg   48 hpg   82 ppg   8.5% pup%
#   6.  Thrust         1.78 ± 0.80  0.93 cpg  10.8 rpg   60 hpg   61 ppg  16.7% pup%
#   7.  blah-zay       1.74 ± 0.39  1.11 cpg   8.8 rpg   76 hpg   31 ppg  12.5% pup%
#   8.  churt chimi    1.67 ± 0.68  1.26 cpg  10.1 rpg   98 hpg   39 ppg  15.7% pup%
#   9.  amadeo         1.58 ± 0.29  0.93 cpg   8.6 rpg   72 hpg   55 ppg  15.1% pup%
#  10.  goji           1.44 ± 0.42  0.74 cpg  10.9 rpg   54 hpg   70 ppg  14.6% pup%
#  11.  Reze20         1.31 ± 0.40  0.98 cpg   8.3 rpg   77 hpg   55 ppg  13.4% pup%
#  12.  POWER          1.27 ± 0.50  1.32 cpg   7.6 rpg  106 hpg   20 ppg  12.9% pup%
#  13.  magicmuffin8   1.26 ± 0.61  1.10 cpg   8.1 rpg   81 hpg   30 ppg  15.6% pup%
#  14.  Rikers Beard   1.12 ± 0.88  1.11 cpg  11.9 rpg   62 hpg   59 ppg  11.3% pup%
#  15.  ImaNewbie      1.00 ± 0.50  1.31 cpg   6.9 rpg   94 hpg   28 ppg  15.9% pup%
#  16.  niya           0.98 ± 0.52  0.77 cpg  10.6 rpg   61 hpg   62 ppg  13.8% pup%
#  17.  wasserstein    0.90 ± 0.68  1.04 cpg   8.4 rpg   63 hpg   50 ppg  12.0% pup%
#  18.  Quercus        0.78 ± 0.54  0.94 cpg   9.7 rpg   71 hpg   51 ppg  12.9% pup%
#  19.  bequerel       0.65 ± 0.86  0.44 cpg  12.3 rpg   43 hpg   67 ppg  12.3% pup%
#  20.  windowlicker   0.65 ± 0.40  0.99 cpg   7.2 rpg   74 hpg   48 ppg  14.6% pup%
#  21.  1tbsp          0.61 ± 0.46  0.90 cpg   9.1 rpg   69 hpg   49 ppg  15.4% pup%
#  22.  MyNameWontFi   0.54 ± 0.74  1.17 cpg   7.0 rpg  123 hpg   17 ppg  13.2% pup%
#  23.  narumii        0.53 ± 0.80  1.35 cpg   6.4 rpg  105 hpg   16 ppg  10.5% pup%

# %% [markdown]
# ### Records

# %%
def pretty_print_match(m, player=None):
    player_names = sorted([p['name'] for p in m['players'][:4]], key=lambda p: players[p].elo, reverse=True) + sorted([p['name'] for p in m['players'][4:]], key=lambda p: players[p].elo, reverse=True)
    player_caps = [p['stats']['caps'] for p in m['players']]
    minutes = int(m['duration'] / 3600)
    seconds = int(m['duration'] / 60) - 60 * minutes
    result = f"""Match {m['match_id']}: {', '.join(player_names[:4])} vs. {', '.join(player_names[4:])}
Expected: {m['retro_pred']:+.1f} ({m['retro_wp']:.0%}). Actual: {sum(player_caps[:4])}-{sum(player_caps[4:])} in {minutes}:{seconds:02}."""
    for p in m['players']:
        if p['name'] == player:
            result += f" Update: {p['updates']['elo_update']:+.2f}."
    return result + f" Map: {m['map_name']}\n"

def unfairness(m):
    return abs(m['retro_pred'])

def carry_required(m):
    return max(
        m['retro_blue_elo'] - m['retro_red_elo'] + max(players[p['name']].elo for p in m['players'][:4]),
        m['retro_red_elo'] - m['retro_blue_elo'] + max(players[p['name']].elo for p in m['players'][4:]),
    )

def matches_with_player(name):
    return [m for m in matches if name in [p['name'] for p in m['players']]]

# Biggest carries
for m in sorted([m for m in matches if m['retro_wwp'] < 0.5], key=unfairness, reverse=True)[:10]:
    print(pretty_print_match(m))
# Out:
# Match 3978429: karma, Anti_Social, Gvendolino, G.O.A.T. vs. okthen, MarcusYallow, Kep, broseph
# Expected: -5.9 (4%). Actual: 3-2 in 9:27. Map: Combine
#
# Match 4128373: `ArryKane, nej, Toaster, sinagot vs. Alisa, kika, DiegoOnMac, S. Strasball
# Expected: -5.9 (4%). Actual: 4-3 in 8:03. Map: Basenji
#
# Match 3941266: phreak, 1deag, NameLEss, Messy vs. helen keller, tnevlos, MoGGee, Keyser Soze
# Expected: +5.5 (95%). Actual: 3-5 in 8:00. Map: Combine
#
# Match 3943911: Vorhees, Toidi, JSwan, Valerian vs. Messy, HammerTime, DuckDuckJuke, spills
# Expected: +5.4 (94%). Actual: 2-3 in 8:10. Map: Moon Base 2024
#
# Match 4151120: Vorhees, caprae, PenFifteen, MURF vs. Karasu, MrDMoney, TigertheLion, Garry Lakin
# Expected: +5.3 (94%). Actual: 3-8 in 7:40. Map: Asida
#
# Match 3935900: Anti_Social, Chucho, Jarek, Bambi vs. Sugar, KING KRULE, Old Cob, helprefugees
# Expected: -5.0 (7%). Actual: 8-3 in 7:30. Map: Asida
#
# Match 3934918: meowza, grumpy, Borgus, Euler vs. KING KRULE, Vancouver, hihi!, TheGovernor
# Expected: +5.0 (93%). Actual: 1-2 in 8:00. Map: Oak
#
# Match 4151893: ?, Curry, Robiny, fl33t vs. o o l e r, KahnMan, DiegoOnMac, chgtus
# Expected: +4.9 (93%). Actual: 1-6 in 3:21. Map: Basenji
#
# Match 3981927: BUTT, Wonk, Terry, EyeInTheSky vs. Messy, BadTrash, supergremlin, Kohnago
# Expected: -4.8 (7%). Actual: 4-3 in 9:34. Map: Centenaria
#
# Match 4159522: AdmaniaYT, Doku, Mystic, Sinatra vs. LethalSquirt, `AppleKane, Squish, sbxxvi
# Expected: +4.8 (93%). Actual: 1-2 in 8:01. Map: Asida

# %%
player_recent_matches = matches_with_player("Tumblewood")
player_recent_matches.reverse()
for m in player_recent_matches[:10]:
    print(pretty_print_match(m, player="Tumblewood"))
# Out:
# Match 4234405: First, Tumblewood, kmichael, megapoop22 vs. BallsToYou., aaron, babyTron, `ArryKane
# Expected: +0.2 (52%). Actual: 0-4 in 8:00. Update: -0.03. Map: Thicket 2
#
# Match 4234362: Tumblewood, gspoon, helprefugees, CBad vs. aaron, kutrebar, PrettyLights, PuyoPuyo
# Expected: -0.2 (47%). Actual: 3-4 in 8:30. Update: -0.00. Map: Moon Base 2024
#
# Match 4234338: caroline :3, gspoon, helprefugees, `ArryKane vs. aaron, Tumblewood, laserpig, CBad
# Expected: -1.3 (33%). Actual: 1-5 in 8:00. Update: +0.03. Map: Audacity 2
#
# Match 4234328: Tumblewood, laserpig, gspoon, helprefugees vs. Guaderno, `ArryKane, NateH, CBad
# Expected: +1.8 (72%). Actual: 4-2 in 8:00. Update: -0.00. Map: Centenaria
#
# Match 4232788: phreak, Messi, Magnolia, Tumblewood vs. Vorhees, caprae, aaron, pho queue
# Expected: +0.7 (59%). Actual: 4-2 in 8:00. Update: +0.01. Map: Audacity 2
#
# Match 4232772: Vorhees, phreak, Tumblewood, Penis Wings vs. Messi, caprae, aaron, pho queue
# Expected: +1.5 (69%). Actual: 3-4 in 8:00. Update: -0.02. Map: OTI MERALD
#
# Match 4232655: LewBird, Tumblewood, LogisticMap, oatz_mgoatz vs. churt chimi, aaron, pho queue, NUTSNUTSNUTS
# Expected: -0.2 (48%). Actual: 4-5 in 9:57. Update: -0.00. Map: Asida
#
# Match 4228742: tng., aaron, SumtimesGood, megapoop22 vs. DiNgBaT, Reze20, Tumblewood, BaII
# Expected: +0.4 (55%). Actual: 1-5 in 8:00. Update: +0.03. Map: A Flaccid Type Map
#
# Match 4228732: tng., Bam, Tumblewood, BaII vs. DiNgBaT, Reze20, aaron, pho queue
# Expected: +1.2 (65%). Actual: 6-1 in 6:24. Update: +0.04. Map: Willow 2
#
# Match 4227307: BALLDON'TLIE, Sadness, Tumblewood, kmichael vs. Bam, jjpoole, laserpig, Gyara
# Expected: +3.1 (84%). Actual: 4-3 in 8:02. Update: -0.02. Map: Milano 2

# %% [markdown]
# ### Analysis

# %%
def player_results_by_map(player):
    map_results = {}
    baseline = [0, 0]
    for m in matches_with_player(player):
        player_names = [p['name'] for p in m['players']]
        map_name = m['map_name']
        if map_name not in map_results:
            map_results[map_name] = [0, 0]
        map_results[map_name][0] += 1
        map_results[map_name][1] += m['retro_residual'] if player in player_names[:4] else -m['retro_residual']
        baseline[0] += 1
        baseline[1] += m['retro_residual'] if player in player_names[:4] else -m['retro_residual']
    for map_name, [gp, avg_resid] in sorted(map_results.items(), key=lambda x: x[1][0], reverse=True):
        print(f"{map_name:>28}: {avg_resid / gp - baseline[1] / baseline[0]:+.2f} ({gp:>2} games)")

player_results_by_map("Tumblewood")
# Out:
#           A Flaccid Type Map: +0.44 (65 games)
#                   Audacity 2: -0.32 (60 games)
#                        Asida: -0.14 (54 games)
#               Moon Base 2024: -0.45 (50 games)
#                   Centenaria: +0.14 (44 games)
#                     Milano 2: -0.03 (41 games)
#                    Sardonica: +0.72 (34 games)
#                      Combine: -0.70 (32 games)
#                   OTI Jardim: -0.52 (30 games)
#                     Willow 2: +0.43 (27 games)
#                    Thicket 2: -0.56 (26 games)
#                   OTI MERALD: -0.38 (24 games)
#                          Oak: -0.05 (19 games)
#              Sugar Free Hill: +0.64 (10 games)
#               Transilio 2024: -1.49 ( 8 games)
#                      Basenji: +1.33 ( 8 games)
#                Professor Oak: +1.07 ( 8 games)
#                     Catch-24: +0.65 ( 7 games)
#              Apparition 2023: +0.04 ( 7 games)
#                      Pilot 3: +0.55 ( 7 games)
#                Crawfish Boil: +0.02 ( 7 games)
#                          GFY: +1.02 ( 6 games)
#                         Nuke: -1.59 ( 6 games)
#                        PRush: +1.87 ( 6 games)
#                        Haste: -1.31 ( 5 games)
#                    Pukebox 2: +0.42 ( 4 games)
#                         Pine: +1.19 ( 3 games)
#                    Pretzel 2: +1.00 ( 3 games)
#  Waterbed [MM23 West Winner]: +0.04 ( 3 games)
#              Tetanic 3.1 4x4: +5.96 ( 1 games)
#                        Flume: +4.32 ( 1 games)

# %%
for i in range(0, 16):
    i *= 0.4
    total = [m for m in matches if i < abs(m['retro_pred']) < i + 0.4]
    wins = [m for m in total if m['retro_wwp'] > 0.5]
    print(f"{i:.1f}-{i + 0.4:.1f}: "
          f"{len(wins):>5} / "
          f"{len(total):>5} "
          f"({len(wins) / len(total):.1%})"
          f"  {1 / (1 + 1.7 ** -(i + 0.1)):.1%}")
# Out:
# 0.0-0.4:  7091 / 13714 (51.7%)  51.3%
# 0.4-0.8:  6916 / 12178 (56.8%)  56.6%
# 0.8-1.2:  5881 /  9673 (60.8%)  61.7%
# 1.2-1.6:  4590 /  7029 (65.3%)  66.6%
# 1.6-2.0:  3323 /  4730 (70.3%)  71.1%
# 2.0-2.4:  2256 /  3028 (74.5%)  75.3%
# 2.4-2.8:  1505 /  1937 (77.7%)  79.0%
# 2.8-3.2:   890 /  1119 (79.5%)  82.3%
# 3.2-3.6:   561 /   636 (88.2%)  85.2%
# 3.6-4.0:   392 /   440 (89.1%)  87.7%
# 4.0-4.4:   219 /   244 (89.8%)  89.8%
# 4.4-4.8:   169 /   176 (96.0%)  91.6%
# 4.8-5.2:   108 /   114 (94.7%)  93.1%
# 5.2-5.6:    66 /    69 (95.7%)  94.3%
# 5.6-6.0:    40 /    42 (95.2%)  95.4%
# 6.0-6.4:    26 /    26 (100.0%)  96.2%

# %%
maps = {}
for m in matches:
    if m['map_name'] not in maps:
        maps[m['map_name']] = [0, 0, 0, 0, 0, 0]
    maps[m['map_name']][0] += 1
    maps[m['map_name']][3] += m['retro_residual']
    maps[m['map_name']][1] += math.log2(0.5 + abs(m['retro_wp'] - 0.5))
    maps[m['map_name']][2] += math.log2(m['retro_wwp'])
    maps[m['map_name']][4] += abs(m['retro_residual'])
    maps[m['map_name']][5] += m['retro_residual'] ** 2
for m in maps.values():
    if m[0] == 0:
        continue
    m[1] /= m[0]
    m[2] /= m[0]
    m[3] /= m[0]
    m[4] /= m[0]
    m[5] /= m[0]

for m, p in sorted(maps.items(), key=lambda x: x[1][0], reverse=True):
    print(f"{m:>27}  {p[0]:>4}  {2 ** p[1]:.1%}  {2 ** p[2]:.1%}  {p[3] + RED_ADVANTAGE[m if m in RED_ADVANTAGE else 'default']:+.2f}  {p[4]:.2f}  {p[5]:.2f}")
# Out:
#          A Flaccid Type Map  6000  61.5%  52.1%  +0.02  2.28  7.79
#                  Audacity 2  5558  62.6%  52.3%  +0.43  2.29  7.90
#                       Asida  5316  63.2%  52.8%  +0.41  2.56  9.54
#              Moon Base 2024  5011  62.6%  52.7%  +0.43  2.41  8.51
#                  Centenaria  4185  62.5%  52.5%  +0.04  2.42  8.63
#                    Milano 2  4025  62.2%  52.0%  +0.46  2.47  8.95
#                     Combine  3830  62.7%  53.0%  +0.05  2.38  8.28
#                   Sardonica  3033  62.2%  52.3%  -0.07  2.53  9.28
#                   Thicket 2  2262  62.1%  52.0%  +0.11  2.32  7.93
#                  OTI Jardim  2249  62.2%  52.9%  +0.39  2.47  8.78
#                  OTI MERALD  2199  63.6%  53.3%  -0.02  2.38  8.32
#                    Willow 2  1968  62.4%  51.9%  +0.01  2.36  8.17
#                         Oak  1727  63.0%  52.7%  +0.20  2.22  7.47
#             Sugar Free Hill  1235  61.8%  51.9%  -0.21  2.29  7.96
#                     Pilot 3   947  61.7%  51.2%  +0.25  2.22  7.34
#             Apparition 2023   912  61.1%  51.3%  +0.16  2.29  7.67
#                     Basenji   909  63.1%  53.2%  +0.31  2.33  7.97
#              Transilio 2024   798  61.1%  52.6%  +0.31  2.23  7.50
#               Professor Oak   498  64.3%  54.6%  +0.19  2.20  7.20
#                        Nuke   340  62.0%  52.1%  +0.25  2.40  8.82
#                    Catch-24   316  64.6%  53.2%  +0.31  2.16  7.09
#                        Pine   314  65.4%  54.0%  -0.29  2.33  8.40
#               Crawfish Boil   294  64.3%  54.1%  +0.15  2.29  7.68
#                       Haste   290  61.5%  51.0%  +0.33  2.30  8.09
#                       PRush   245  64.8%  54.4%  -0.03  2.41  8.42
#                       Flume   165  66.9%  58.0%  +0.20  2.17  7.28
#                   Pukebox 2   157  61.7%  51.5%  +0.13  2.50  8.75
#                   Pretzel 2   135  61.4%  52.5%  +0.37  2.04  6.22
#                         GFY   131  64.6%  56.3%  +0.19  2.14  6.68
# Waterbed [MM23 West Winner]   106  63.2%  51.6%  +0.18  2.05  6.26
#             Tetanic 3.1 4x4    69  61.1%  50.9%  +0.17  2.43  8.86
#                     Tetanic     6  60.1%  47.4%  +1.16  2.29  9.51

# %% [markdown]
# ### Results

# %% [markdown]
# Guessing 0:
#
# ```
# MAE: 2.6057    RMS: 3.0680
# COR: 50.00%    WWP: 50.00%
# BRI: 50.00%    LOG: 50.00%
# ```
#
# Current system:
#
# ```
# MAE: 2.4039    RMS: 2.9133
# COR: 60.56%    WWP: 53.64%
# BRI: 51.86%    LOG: 51.97%
# ```
#
# With hindsight:
#
# ```
# MAE: 2.3589    RMS: 2.8734
# COR: 62.05%    WWP: 54.93%
# BRI: 52.36%    LOG: 52.51%
# ```
