# %%
import json
from datetime import date
from typing import Dict
import math
import csv

STAT_NAMES = [
    "caps", "garbage_time_caps", "hold", "ndps", "returns", "quick_returns", "nrts", "pups", 
    "keypops", "handoffs", "goodprevent", "resets", "badflaccids", "sparkedouts"
]

with open("../data/bulkmaps.json", encoding="utf-8") as f:
    maps = json.load(f)

with open("smurfs.json") as f:
    smurfs = json.load(f)

def desmurf(player):
    player = player.replace("\\'", "'").replace("\\\\", "\\")
    if player in smurfs:
        return smurfs[player]
    return player

def row_to_dict(row):
    return {
        'match_id': int(row[0]),
        'map_name': maps[row[1]]['name'],
        'gamemode': maps[row[1]]['type'],
        'timestamp': int(row[2]),
        'duration': int(row[3]),
        'cap_diff': int(row[4]),
        'garbage_time_cap_diff': int(row[5]),
        'players': [
            {
                'name': desmurf(row[j + 6]),
                'stats': {
                    stat_name: int(row[j * len(STAT_NAMES) + 14 + i])
                    for i, stat_name in enumerate(STAT_NAMES)
                }
            }
            for j in range(8)
        ]
    }

with open("matchups_with_stats.csv") as f:
    reader = csv.reader(f)
    next(reader)
    matches = [row_to_dict(row) for row in reader]
    matches = [m for m in matches if m['gamemode'] == "ctf"]

players = {}

# %%
NEW_PLAYER_ELO = -0.8
STARTING_VARIANCE = 0.65
MAX_VARIANCE_TO_COUNT_AS_KNOWN = 0.3
VARIANCE_TO_ADD_BACK = 0.0005
BASE_VARIANCE = 4.5
RED_ADVANTAGE = {
    'default': 0.1,
    'Audacity 2': 0.2,
    'Moon Base 2024': 0.2,
    'Asida': 0.2,
    'Centenaria': 0,
    'Milano 2': 0.2,
    'Combine': 0,
    'Sardonica': 0,
    'OTI MERALD': 0,
    'OTI Jardim': 0.2,
    'Willow 2': 0,
    'Sugar Free Hill': -0.1,
}
DIFF_MAPPING = [0, 0.2, 1.0, 2.1, 3.2, 4.4, -4.4, -3.2, -2.1, -1.0, -0.2]
STAT_SCORE_WEIGHT_BY_CAP_DIFF = 0.2
CAP_TO_WP_EXPONENT = 1.75
PLAYER_STAT_WEIGHTS = {
    "caps": 2.0,
    "hold": 3.0 / 3600,
    "ndps": -0.75,
    "returns": 0.75,
    "nrts": 0.5,
    "pups": 0.5,
}
TEAM_STAT_WEIGHTS = {
    "caps": 0.0,
    "hold": 0.7 / 3600,
    "ndps": 0.0,
    "returns": 0.03,
    "nrts": 0.0,
    "pups": 0.03,
    
}
RELATIVE_ELO_CORRECTION = 1.8

# %%
class Player:
    def __init__(self, name):
        self.name = name
        self.elo = NEW_PLAYER_ELO
        self.variance = STARTING_VARIANCE
        self.lowest_ever_variance = self.variance
        self.stat_farm_amount = 0
        self.high_certainty_play = 0

    def error_bar(self):
        return 1.96 * self.variance ** 0.5
    
    def update_rating(self, p, match, error, stat_score, team_avg_elo, total_variance):
        p['updates'] = {
            'elo_before': self.elo,
            'variance_before': self.variance,
        }
        share_of_variance = self.variance / total_variance

        # Calculate stat score (weighted based on newness)
        newness = self.variance / STARTING_VARIANCE
        stat_score = stat_score * newness

        # Apply a slight correction to stat score based on relative elo
        elo_vs_game_avg = self.elo - team_avg_elo
        stat_score -= elo_vs_game_avg * newness * RELATIVE_ELO_CORRECTION

        # Weight stat score higher in blowouts
        stat_score *= 1 + STAT_SCORE_WEIGHT_BY_CAP_DIFF * (abs(match['cap_diff']) - 1)

        # Apply Bayesian update (error times share of variance, plus stat score)
        update = error + stat_score
        self.elo += update * share_of_variance
        self.variance *= 1 - share_of_variance
        self.lowest_ever_variance = min(self.variance, self.lowest_ever_variance)

        # Track the update that was applied
        p['updates']['elo_update'] = self.elo - p['updates']['elo_before']

    def overperformance(self, decay=0.998):
        expected_wins, actual_wins = 0, 0
        expected_cap_diff, actual_cap_diff = 0, 0
        weighted_games_played = 0
        for m in matches:
            names = [p['name'] for p in m['players']]
            if self.name in names:
                is_red = self.name in names[:4]
                weight = decay ** (date.today() - date.fromtimestamp(m['timestamp'])).days
                weighted_games_played += weight
                expected_score = sum(players[p].elo for p in names[:4]) - sum(players[p].elo for p in names[4:]) +\
                    RED_ADVANTAGE[m['map_name'] if m['map_name'] in RED_ADVANTAGE else 'default']
                red_win_prob = 1 / (1 + CAP_TO_WP_EXPONENT ** -expected_score)
                if is_red:
                    expected_cap_diff += expected_score * weight
                    actual_cap_diff += m['cap_diff'] * weight
                    expected_wins += red_win_prob * weight
                    actual_wins += (1 if m['cap_diff'] > 0 else 0.5 if m['cap_diff'] == 0 else 0) * weight
                else:
                    expected_cap_diff += expected_score * weight
                    actual_cap_diff += m['cap_diff'] * weight
                    expected_wins += (1 - red_win_prob) * weight
                    actual_wins += (1 if m['cap_diff'] < 0 else 0.5 if m['cap_diff'] == 0 else 0) * weight

        return (
            (actual_wins - expected_wins) / weighted_games_played,
            (actual_cap_diff - expected_cap_diff) / weighted_games_played
        )

    def __str__(self):
        return f"{self.name} ({self.elo:.2f} ± {self.error_bar():.2f})"
    
    def __repr__(self):
        return f"Player \"{self.name}\" ({self.elo:.2f} ± {self.error_bar():.2f})"

# %%
def normalize_elos():
    known_elos = [p.elo for p in players.values() if p.variance <= MAX_VARIANCE_TO_COUNT_AS_KNOWN]
    avg_elo = sum(known_elos) / max(10, len(known_elos))
    for p in players.values():
        p.elo -= avg_elo
        p.variance = min(p.variance + VARIANCE_TO_ADD_BACK, STARTING_VARIANCE)

def stat_scores(players, scoring_dict: Dict[str, int]):
    return [
        sum([
            p['stats'][stat_name] * scoring_dict[stat_name]
            for stat_name in scoring_dict
        ])
        for p in players
    ]

def judge_player_stats(players):
    player_scores = stat_scores(players, PLAYER_STAT_WEIGHTS)

    red_avg_score = sum(player_scores[:4]) / 4
    blue_avg_score = sum(player_scores[4:]) / 4
    red_scores = [s - red_avg_score for s in player_scores[:4]]
    blue_scores = [s - blue_avg_score for s in player_scores[4:]]
    return red_scores, blue_scores

def update_ratings(match):
    # Calculate skill for each team and game variance
    red_elo = 0
    blue_elo = 0
    total_variance = BASE_VARIANCE

    for p in match['players']:
        if p['name'] not in players:
            players[p['name']] = Player(p['name'])
        total_variance += players[p['name']].variance
    
    for p in match['players'][:4]:
        red_elo += players[p['name']].elo
    for p in match['players'][4:]:
        blue_elo += players[p['name']].elo
    
    expected_score = red_elo - blue_elo + RED_ADVANTAGE[
        match['map_name'] if match['map_name'] in RED_ADVANTAGE else 'default'
    ]

    # Track predictions
    match['red_elo'] = red_elo
    match['blue_elo'] = blue_elo
    match['pred'] = expected_score
    match['sd'] = total_variance ** 0.5
    match['wp'] = 1 / (1 + CAP_TO_WP_EXPONENT ** -expected_score)
    match['residual'] = match['cap_diff'] - min(max(expected_score, -5), 5)
    match['wwp'] = match['wp'] if match['cap_diff'] > 0 else 1 - match['wp']
    
    # Calculate the error used for Bayesian updating
    error = DIFF_MAPPING[match['cap_diff']] - min(max(expected_score, DIFF_MAPPING[-4]), DIFF_MAPPING[4])

    # Incorporate team total stats into the error
    team_scores = stat_scores(match['players'], TEAM_STAT_WEIGHTS)
    error += sum(team_scores[:4]) - sum(team_scores[4:])

    # Update ratings based on this error and the variance
    red_stat_scores, blue_stat_scores = judge_player_stats(match['players'])
    for p, stat_score in zip(match['players'][:4], red_stat_scores):
        players[p['name']].update_rating(p, match, error, stat_score, red_elo / 4, total_variance)
    for p, stat_score in zip(match['players'][4:], blue_stat_scores):
        players[p['name']].update_rating(p, match, -error, stat_score, blue_elo / 4, total_variance)

# %%
players = {}
day = date.fromtimestamp(matches[0]['timestamp'])
player_to_track = "Tumblewood"
played_today = 0

for match in matches:
    if any(p['name'] == player_to_track for p in match['players']):
        played_today += 1
    new_day = date.fromtimestamp(match['timestamp'])
    if new_day != day:
        normalize_elos()
        if played_today > 0:
            print(f"{new_day}: {players[player_to_track].elo:.2f} ± {players[player_to_track].error_bar():.2f} ({played_today} games)")
            played_today = 0
    day = new_day
    update_ratings(match)

print(f"MAE: {sum([abs(m['residual']) for m in matches]) / len(matches):.4f}    RMS: {(sum([m['residual'] ** 2 for m in matches]) / len(matches)) ** 0.5:.4f}")
print(f"COR: {sum([(1 if m['wwp'] > 0.5 else 0.5 if m['wwp'] == 0.5 else 0) for m in matches]) / len(matches):.2%}    WWP: {sum(m['wwp'] for m in matches) / len(matches):.2%}")
print(f"BRI: {1 - (sum([(1 - m['wwp']) ** 2 for m in matches]) / len(matches)) ** 0.5:.2%}    LOG: {2 ** (sum([math.log2(m['wwp']) for m in matches]) / len(matches)):.2%}")
# Out:
# 2025-03-28: -0.79 ± 1.01 (18 games)
# 2025-04-06: -0.19 ± 0.86 (10 games)
# 2025-04-11: 0.11 ± 0.68 (16 games)
# 2025-04-12: 0.13 ± 0.61 (10 games)
# 2025-04-14: 0.29 ± 0.60 (3 games)
# 2025-04-15: 0.25 ± 0.56 (8 games)
# 2025-04-17: 0.26 ± 0.53 (8 games)
# 2025-04-19: 0.20 ± 0.49 (11 games)
# 2025-05-02: 0.23 ± 0.47 (13 games)
# 2025-05-07: 0.23 ± 0.47 (3 games)
# 2025-05-14: 0.32 ± 0.44 (16 games)
# 2025-05-15: 0.26 ± 0.42 (11 games)
# 2025-05-17: 0.26 ± 0.42 (4 games)
# 2025-05-18: 0.27 ± 0.41 (4 games)
# 2025-05-22: 0.29 ± 0.41 (4 games)
# 2025-05-23: 0.28 ± 0.41 (1 games)
# 2025-05-30: 0.25 ± 0.42 (6 games)
# 2025-05-31: 0.26 ± 0.42 (3 games)
# 2025-06-01: 0.29 ± 0.41 (4 games)
# 2025-06-03: 0.32 ± 0.40 (6 games)
# 2025-06-04: 0.32 ± 0.40 (1 games)
# 2025-06-05: 0.29 ± 0.40 (2 games)
# 2025-06-06: 0.32 ± 0.40 (1 games)
# 2025-06-08: 0.34 ± 0.41 (1 games)
# 2025-06-09: 0.35 ± 0.41 (1 games)
# 2025-06-14: 0.27 ± 0.41 (5 games)
# 2025-06-15: 0.32 ± 0.39 (12 games)
# 2025-06-18: 0.38 ± 0.39 (3 games)
# 2025-06-19: 0.37 ± 0.39 (2 games)
# 2025-06-21: 0.31 ± 0.39 (4 games)
# 2025-06-22: 0.44 ± 0.38 (11 games)
# 2025-06-27: 0.36 ± 0.38 (4 games)
# 2025-06-29: 0.29 ± 0.36 (20 games)
# 2025-07-01: 0.32 ± 0.36 (5 games)
# 2025-07-06: 0.27 ± 0.36 (6 games)
# 2025-07-09: 0.28 ± 0.37 (2 games)
# 2025-07-10: 0.28 ± 0.37 (4 games)
# 2025-07-11: 0.30 ± 0.36 (8 games)
# 2025-07-12: 0.27 ± 0.36 (4 games)
# 2025-07-13: 0.33 ± 0.35 (4 games)
# 2025-07-14: 0.33 ± 0.35 (5 games)
# 2025-07-18: 0.36 ± 0.35 (6 games)
# 2025-07-19: 0.27 ± 0.35 (9 games)
# 2025-07-20: 0.26 ± 0.35 (1 games)
# 2025-07-24: 0.29 ± 0.35 (5 games)
# 2025-08-12: 0.33 ± 0.39 (6 games)
# 2025-08-20: 0.38 ± 0.41 (2 games)
# 2025-08-24: 0.34 ± 0.41 (4 games)
# 2025-08-25: 0.29 ± 0.40 (8 games)
# 2025-08-30: 0.17 ± 0.39 (8 games)
# 2025-09-01: 0.14 ± 0.39 (6 games)
# 2025-09-04: 0.09 ± 0.39 (4 games)
# 2025-09-07: 0.12 ± 0.39 (4 games)
# 2025-09-10: 0.11 ± 0.40 (1 games)
# 2025-09-14: 0.13 ± 0.40 (1 games)
# 2025-09-17: 0.09 ± 0.40 (4 games)
# 2025-09-21: 0.15 ± 0.40 (8 games)
# 2025-09-23: 0.12 ± 0.40 (1 games)
# 2025-09-24: 0.01 ± 0.40 (5 games)
# 2025-09-25: 0.05 ± 0.39 (6 games)
# 2025-09-26: 0.08 ± 0.38 (5 games)
# 2025-09-27: 0.06 ± 0.38 (1 games)
# 2025-09-28: 0.08 ± 0.38 (3 games)
# 2025-10-05: 0.09 ± 0.40 (1 games)
# 2025-10-06: 0.08 ± 0.39 (6 games)
# 2025-10-19: 0.16 ± 0.41 (6 games)
# 2025-10-20: 0.24 ± 0.41 (3 games)
# 2025-10-26: 0.24 ± 0.42 (1 games)
# 2025-11-06: 0.25 ± 0.44 (1 games)
# 2025-11-10: 0.26 ± 0.44 (5 games)
# 2025-11-15: 0.21 ± 0.43 (8 games)
# 2025-11-16: 0.21 ± 0.42 (4 games)
# 2025-11-22: 0.27 ± 0.43 (2 games)
# 2025-11-25: 0.33 ± 0.43 (4 games)
# 2025-11-27: 0.37 ± 0.42 (8 games)
# 2025-11-29: 0.35 ± 0.41 (8 games)
# 2025-12-01: 0.39 ± 0.40 (7 games)
# 2025-12-07: 0.41 ± 0.40 (6 games)
# 2025-12-08: 0.41 ± 0.40 (3 games)
# 2025-12-15: 0.40 ± 0.40 (2 games)
# 2025-12-17: 0.45 ± 0.40 (6 games)
# 2025-12-20: 0.54 ± 0.39 (10 games)
# 2025-12-22: 0.64 ± 0.38 (7 games)
# 2025-12-25: 0.72 ± 0.38 (5 games)
# 2025-12-27: 0.75 ± 0.39 (2 games)
# 2025-12-28: 0.80 ± 0.37 (10 games)
# 2025-12-29: 0.80 ± 0.37 (2 games)
# MAE: 2.4039    RMS: 2.9122
# COR: 60.51%    WWP: 53.74%
# BRI: 51.84%    LOG: 51.95%

# %%
leaderboard = sorted([
    p for p in players.values() if p.variance <= MAX_VARIANCE_TO_COUNT_AS_KNOWN
], key=lambda p: p.elo, reverse=True)
for i, p in enumerate(leaderboard):
    print(f"{i + 1:>3}.  {p.name:<12}  {p.elo:5.2f} ± {1.96 * p.variance ** 0.5:.2f}")
# Out:
#   1.  okthen         3.56 ± 0.48
#   2.  tng.           3.56 ± 0.29
#   3.  DT             3.50 ± 0.39
#   4.  SluffAndRuff   3.48 ± 0.48
#   5.  Vorhees        3.45 ± 0.26
#   6.  chizu_mizu     3.44 ± 0.42
#   7.  toasty         3.23 ± 0.60
#   8.  Alphachurro    3.01 ± 0.38
#   9.  Xx360NoSwagx   2.89 ± 0.56
#  10.  danp           2.80 ± 0.32
#  11.  Suchit         2.78 ± 0.29
#  12.  mex            2.78 ± 0.28
#  13.  BALLDON'TLIE   2.77 ± 0.32
#  14.  phreak         2.76 ± 0.37
#  15.  Helen Keller   2.74 ± 0.77
#  16.  ?              2.70 ± 0.36
#  17.  frieren        2.69 ± 0.73
#  18.  meowza         2.69 ± 0.35
#  19.  Madoka         2.66 ± 0.64
#  20.  OuchMyBalls    2.66 ± 0.30
#  21.  bright         2.65 ± 0.46
#  22.  Ritual         2.65 ± 0.44
#  23.  simp.          2.64 ± 0.47
#  24.  Mileena        2.58 ± 0.28
#  25.  Galvatron      2.55 ± 0.77
#  26.  jig            2.54 ± 0.32
#  27.  fender         2.54 ± 0.34
#  28.  Jester101      2.53 ± 0.88
#  29.  realtea        2.52 ± 0.27
#  30.  Crippy         2.45 ± 0.38
#  31.  HelloI'mGurt   2.38 ± 0.89
#  32.  Sugar          2.37 ± 0.62
#  33.  Arbybear       2.37 ± 0.68
#  34.  Maelstrom      2.36 ± 0.31
#  35.  1deag          2.34 ± 0.40
#  36.  2Nutz          2.33 ± 0.30
#  37.  i love HD      2.32 ± 0.79
#  38.  flaccid trip   2.31 ± 0.38
#  39.  Doris          2.30 ± 0.47
#  40.  Messi          2.27 ± 0.27
#  41.  Ty             2.25 ± 0.49
#  42.  Ball-E         2.24 ± 0.64
#  43.  eee            2.21 ± 0.47
#  44.  grunt          2.19 ± 0.39
#  45.  bbb            2.18 ± 0.34
#  46.  kool aid       2.18 ± 0.51
#  47.  rina           2.16 ± 0.45
#  48.  ASAP           2.15 ± 0.50
#  49.  joy.           2.15 ± 0.34
#  50.  jazzz          2.13 ± 0.46
#  51.  BallsToYou.    2.13 ± 0.34
#  52.  kcx            2.11 ± 0.52
#  53.  Vader          2.10 ± 0.52
#  54.  Mr awesome:)   2.10 ± 0.57
#  55.  SleepyBoi      2.09 ± 0.38
#  56.  Cape           2.08 ± 0.93
#  57.  First          2.05 ± 1.04
#  58.  Button         2.05 ± 0.34
#  59.  vanitas        2.01 ± 0.85
#  60.  kelvin         2.00 ± 0.97
#  61.  tits           1.98 ± 0.56
#  62.  SakuUta        1.98 ± 0.44
#  63.  swerve         1.98 ± 0.88
#  64.  NEUhusky       1.97 ± 0.79
#  65.  NameLEss       1.97 ± 0.37
#  66.  karma          1.96 ± 0.29
#  67.  Homie          1.94 ± 0.42
#  68.  BallSaget      1.92 ± 0.29
#  69.  Abe Lincoln    1.91 ± 0.58
#  70.  Carrrrrl       1.91 ± 0.35
#  71.  Taurus         1.87 ± 0.34
#  72.  tears          1.85 ± 0.41
#  73.  ||||||||||||   1.84 ± 0.71
#  74.  Cheetosrule    1.84 ± 0.89
#  75.  yawn           1.82 ± 0.35
#  76.  dodsfall       1.82 ± 0.44
#  77.  popsic         1.80 ± 0.36
#  78.  Russ           1.80 ± 0.31
#  79.  tha king       1.79 ± 0.33
#  80.  ~              1.78 ± 0.64
#  81.  fm             1.78 ± 0.42
#  82.  MarcusYallow   1.77 ± 0.55
#  83.  helen keller   1.77 ± 0.39
#  84.  Cheezedoodle   1.77 ± 0.40
#  85.  Nas            1.76 ± 0.60
#  86.  zo2            1.76 ± 0.30
#  87.  DAD.           1.75 ± 0.33
#  88.  DiNgBaT        1.74 ± 0.44
#  89.  grumpy         1.73 ± 0.55
#  90.  womp womp      1.72 ± 0.26
#  91.  Stronk         1.69 ± 0.64
#  92.  Curry          1.68 ± 0.44
#  93.  360broscope    1.67 ± 0.53
#  94.  Mista Feeneh   1.66 ± 0.72
#  95.  Boat           1.66 ± 0.69
#  96.  Wanye          1.66 ± 0.41
#  97.  AJ.            1.64 ± 0.32
#  98.  DudeMcGuy      1.64 ± 0.76
#  99.  Kep            1.64 ± 0.33
# 100.  Ball of Fame   1.63 ± 0.84
# 101.  caprae         1.63 ± 0.52
# 102.  Jer32          1.62 ± 0.63
# 103.  SoulCake       1.62 ± 0.65
# 104.  keithstoned1   1.61 ± 0.83
# 105.  Niplepotamus   1.60 ± 0.72
# 106.  known          1.60 ± 0.55
# 107.  DingusDongus   1.58 ± 0.71
# 108.  Jinjo          1.58 ± 0.72
# 109.  anduin         1.58 ± 0.38
# 110.  aaron          1.57 ± 0.43
# 111.  kasli          1.57 ± 0.65
# 112.  Irony          1.56 ± 0.35
# 113.  Bomberguy      1.56 ± 1.03
# 114.  d0pe           1.55 ± 0.37
# 115.  Frank          1.55 ± 0.80
# 116.  Sphear         1.54 ± 0.88
# 117.  JKooter        1.54 ± 0.29
# 118.  goji           1.53 ± 0.89
# 119.  tune           1.53 ± 0.63
# 120.  StaIin         1.52 ± 0.49
# 121.  Butter         1.52 ± 0.53
# 122.  Wraith         1.52 ± 0.42
# 123.  TheG           1.52 ± 0.34
# 124.  yep            1.52 ± 0.47
# 125.  anti-re        1.51 ± 0.34
# 126.  Thanos Ball    1.51 ± 0.30
# 127.  omni           1.50 ± 0.34
# 128.  JBaay          1.50 ± 0.75
# 129.  Spjork         1.49 ± 0.39
# 130.  meaL           1.48 ± 1.07
# 131.  hz             1.48 ± 0.27
# 132.  Light          1.47 ± 0.35
# 133.  Mos Def        1.45 ± 0.39
# 134.  snuffed        1.45 ± 0.75
# 135.  magicmuffin8   1.45 ± 0.55
# 136.  Magnolia       1.44 ± 0.38
# 137.  AdmaniaYT      1.44 ± 0.45
# 138.  Kei Yonagi     1.44 ± 0.58
# 139.  Recap          1.43 ± 0.56
# 140.  mactheroni     1.41 ± 0.33
# 141.  Bam            1.41 ± 0.39
# 142.  omar           1.40 ± 0.80
# 143.  DEAD NAN       1.40 ± 0.60
# 144.  clew3          1.39 ± 0.77
# 145.  LewBird        1.39 ± 0.33
# 146.  Niku           1.38 ± 0.55
# 147.  St. Bernard    1.38 ± 0.65
# 148.  Shaolin        1.37 ± 0.68
# 149.  a virgin dad   1.37 ± 1.02
# 150.  rake           1.37 ± 0.78
# 151.  q42            1.35 ± 0.63
# 152.  MarkBallis     1.35 ± 0.69
# 153.  Ballzilla      1.34 ± 0.69
# 154.  Sadness        1.34 ± 0.33
# 155.  Corbeh         1.32 ± 0.43
# 156.  Ball-Is-Life   1.30 ± 0.80
# 157.  Snowball       1.30 ± 0.50
# 158.  Poeticalto     1.30 ± 0.55
# 159.  arksoldier     1.29 ± 0.75
# 160.  broseph        1.28 ± 0.29
# 161.  TNT            1.28 ± 1.02
# 162.  jkxs           1.27 ± 0.35
# 163.  Squeeb         1.27 ± 0.65
# 164.  Toidi          1.26 ± 0.21
# 165.  Prime          1.25 ± 0.34
# 166.  Gamepad God    1.25 ± 0.55
# 167.  jjpoole        1.25 ± 0.32
# 168.  George         1.24 ± 0.73
# 169.  CA$H.          1.24 ± 0.33
# 170.  Adamn          1.22 ± 0.59
# 171.  RedBull        1.21 ± 0.43
# 172.  EpicBlob       1.21 ± 0.40
# 173.  not lazy       1.20 ± 1.03
# 174.  Kenobi         1.20 ± 0.61
# 175.  Borgus         1.20 ± 0.36
# 176.  Porps          1.20 ± 0.34
# 177.  ObliqueOwl     1.19 ± 0.68
# 178.  vic            1.19 ± 0.48
# 179.  Threeflower    1.18 ± 0.39
# 180.  yiss           1.17 ± 0.38
# 181.  BallAnka       1.16 ± 0.46
# 182.  tnevlos        1.16 ± 0.38
# 183.  Baay           1.16 ± 0.53
# 184.  P-d0g          1.16 ± 0.71
# 185.  beef           1.15 ± 0.62
# 186.  Jump Ball      1.15 ± 0.97
# 187.  Tinderfella    1.15 ± 0.40
# 188.  Xylene         1.15 ± 0.94
# 189.  Armbranch      1.14 ± 0.70
# 190.  Chill Will     1.14 ± 0.89
# 191.  mc             1.13 ± 0.32
# 192.  lizzey         1.13 ± 0.62
# 193.  Kamikaze       1.13 ± 0.53
# 194.  trippi         1.13 ± 0.48
# 195.  yippie         1.12 ± 0.80
# 196.  Magikarp       1.12 ± 0.34
# 197.  heribo69       1.11 ± 0.39
# 198.  bleast         1.10 ± 0.90
# 199.  Big D          1.10 ± 0.83
# 200.  #SelfySyntax   1.08 ± 0.31
# 201.  bumballbee     1.08 ± 0.83
# 202.  D Rek          1.08 ± 0.46
# 203.  Chalksy        1.06 ± 1.05
# 204.  Jason Bourne   1.06 ± 0.86
# 205.  LogisticMap    1.06 ± 0.33
# 206.  JSwan          1.06 ± 0.63
# 207.  Rudey          1.06 ± 0.39
# 208.  rebel fox      1.05 ± 0.52
# 209.  Reze20         1.04 ± 0.70
# 210.  snaxolotl      1.04 ± 0.33
# 211.  alchemist      1.04 ± 0.63
# 212.  PTF            1.02 ± 0.39
# 213.  .__.           1.01 ± 0.40
# 214.  miata*man      1.01 ± 1.00
# 215.  Trapsin        1.00 ± 0.37
# 216.  lmfao          1.00 ± 0.65
# 217.  tragic         0.99 ± 0.58
# 218.  deku           0.98 ± 0.32
# 219.  Dr. Toboggan   0.98 ± 0.33
# 220.  J24gordon      0.97 ± 0.78
# 221.  Rick G. #853   0.97 ± 0.43
# 222.  t h C          0.97 ± 0.42
# 223.  C_T            0.96 ± 0.26
# 224.  aardvark       0.96 ± 0.35
# 225.  ALEX JONES     0.95 ± 0.56
# 226.  RASCAL         0.95 ± 0.83
# 227.  Misery         0.94 ± 0.47
# 228.  MAGNlTUDE      0.94 ± 0.77
# 229.  Grommit        0.94 ± 0.49
# 230.  cudi           0.93 ± 1.06
# 231.  caroline :3    0.93 ± 0.45
# 232.  Balled Eagle   0.92 ± 1.02
# 233.  poobie         0.91 ± 0.61
# 234.  white          0.90 ± 0.41
# 235.  BreadBall      0.90 ± 0.75
# 236.  Pnaoxt         0.90 ± 0.37
# 237.  j0sh           0.90 ± 0.33
# 238.  K O            0.88 ± 0.40
# 239.  Batman.        0.88 ± 0.38
# 240.  Enthymeme      0.88 ± 0.59
# 241.  iiiiiiiiii     0.88 ± 0.70
# 242.  blah-zay       0.87 ± 0.70
# 243.  bequerel       0.86 ± 0.77
# 244.  John Brown     0.86 ± 0.75
# 245.  Booya Ball     0.85 ± 0.49
# 246.  Tumblewood     0.85 ± 0.36
# 247.  TaylorWhiff    0.84 ± 0.32
# 248.  toppy          0.84 ± 0.37
# 249.  rain           0.84 ± 0.29
# 250.  Ted            0.83 ± 0.85
# 251.  firehawkv      0.83 ± 0.92
# 252.  bergieberg     0.83 ± 0.56
# 253.  Baby_Shark     0.82 ± 0.43
# 254.  MostToxic420   0.81 ± 0.78
# 255.  CRYCHIC        0.81 ± 0.35
# 256.  Spheroid.      0.80 ± 0.41
# 257.  RacgiMan       0.80 ± 0.91
# 258.  Anti_Social    0.79 ± 0.38
# 259.  sun chips      0.79 ± 0.38
# 260.  Flail          0.78 ± 0.98
# 261.  Sanik          0.77 ± 0.42
# 262.  goosehonk      0.76 ± 0.92
# 263.  Able           0.76 ± 0.66
# 264.  xcv            0.76 ± 0.25
# 265.  toogood        0.75 ± 0.70
# 266.  an             0.75 ± 0.75
# 267.  Iodized Salt   0.75 ± 0.29
# 268.  adawg          0.74 ± 0.66
# 269.  sss            0.74 ± 0.47
# 270.  Gato           0.74 ± 0.83
# 271.  Jukester       0.74 ± 0.47
# 272.  RandyB0Bandy   0.73 ± 0.37
# 273.  perl           0.73 ± 0.45
# 274.  cannibal       0.73 ± 0.63
# 275.  knight_        0.73 ± 0.39
# 276.  gingerdg       0.72 ± 0.41
# 277.  12384          0.70 ± 0.95
# 278.  Crees          0.70 ± 1.06
# 279.  archedrapier   0.70 ± 0.45
# 280.  o3             0.69 ± 0.66
# 281.  Witcher        0.69 ± 0.37
# 282.  Diencash       0.68 ± 0.61
# 283.  Gleg           0.68 ± 0.85
# 284.  ocd            0.67 ± 0.98
# 285.  FK             0.67 ± 0.49
# 286.  Dew1234        0.67 ± 0.66
# 287.  Cel            0.67 ± 0.45
# 288.  Roxas          0.66 ± 0.47
# 289.  windowlicker   0.66 ± 0.69
# 290.  Klox           0.66 ± 0.63
# 291.  jmu            0.66 ± 0.44
# 292.  flopphone      0.66 ± 0.61
# 293.  the buttons    0.65 ± 0.24
# 294.  clamp          0.65 ± 0.95
# 295.  Rick O'Shea    0.65 ± 0.79
# 296.  Serenity       0.64 ± 0.79
# 297.  Gavi           0.64 ± 0.59
# 298.  bubblez        0.63 ± 0.37
# 299.  Player X       0.62 ± 0.58
# 300.  JARVISLANDRY   0.62 ± 0.53
# 301.  Airmigo        0.61 ± 0.34
# 302.  ankr           0.60 ± 0.95
# 303.  GillyBall      0.60 ± 0.62
# 304.  autumn heart   0.59 ± 1.04
# 305.  Pouya          0.58 ± 1.07
# 306.  hero-cat       0.58 ± 0.32
# 307.  Optical Juke   0.58 ± 0.65
# 308.  KnicksFanTV    0.58 ± 0.51
# 309.  DibuMartinez   0.57 ± 0.76
# 310.  Old Cob        0.57 ± 0.49
# 311.  AtomicStorm    0.57 ± 0.94
# 312.  Phiip          0.57 ± 0.72
# 313.  boogie         0.57 ± 0.54
# 314.  cowboy         0.56 ± 0.29
# 315.  Nevermind      0.56 ± 0.43
# 316.  Eat Tofu       0.55 ± 0.37
# 317.  Bluefoot       0.55 ± 0.99
# 318.  Punster        0.55 ± 0.76
# 319.  snakes         0.54 ± 0.32
# 320.  g r e g        0.53 ± 0.68
# 321.  pho queue      0.53 ± 0.70
# 322.  OD GOD         0.52 ± 0.43
# 323.  Nilus          0.52 ± 0.53
# 324.  Billy          0.51 ± 0.66
# 325.  FortuneCooki   0.51 ± 0.43
# 326.  o o l e r      0.51 ± 0.32
# 327.  CatPro         0.50 ± 1.02
# 328.  Dabo           0.50 ± 1.05
# 329.  Gvendolino     0.50 ± 0.42
# 330.  Gman8181       0.49 ± 0.56
# 331.  Catalyst       0.49 ± 0.98
# 332.  Fap            0.48 ± 0.84
# 333.  Moto Moto      0.48 ± 0.52
# 334.  anom           0.48 ± 0.64
# 335.  kmichael       0.48 ± 0.28
# 336.  Thermostat     0.47 ± 0.65
# 337.  might dino     0.47 ± 0.44
# 338.  TheBob18       0.47 ± 0.64
# 339.  Bootymine      0.46 ± 0.72
# 340.  Barry Lakin    0.46 ± 0.65
# 341.  nlfn           0.46 ± 0.60
# 342.  KungFuKenny    0.45 ± 0.77
# 343.  garet          0.45 ± 0.42
# 344.  cantstop       0.44 ± 0.35
# 345.  8-)            0.44 ± 0.47
# 346.  ez             0.44 ± 0.33
# 347.  isaballa       0.44 ± 0.27
# 348.  kutrebar       0.44 ± 0.36
# 349.  Green          0.43 ± 0.51
# 350.  perpendcular   0.43 ± 0.59
# 351.  timo_tay       0.42 ± 0.34
# 352.  Some Ball 64   0.42 ± 0.70
# 353.  McDavid        0.41 ± 0.71
# 354.  BertAndBort    0.41 ± 0.65
# 355.  TheNerve       0.41 ± 0.54
# 356.  Feels Like     0.41 ± 0.47
# 357.  2P1S           0.41 ± 0.54
# 358.  U Good         0.40 ± 0.43
# 359.  jerm           0.40 ± 0.42
# 360.  Penis Wings    0.40 ± 0.54
# 361.  Wilma          0.39 ± 0.43
# 362.  Champagne      0.39 ± 0.36
# 363.  Ivanchuk       0.39 ± 0.41
# 364.  DaBall 07      0.38 ± 0.93
# 365.  protag         0.37 ± 0.49
# 366.  Sambal 1       0.36 ± 0.32
# 367.  Chritt         0.36 ± 0.30
# 368.  rc             0.36 ± 0.63
# 369.  For The Win    0.35 ± 1.03
# 370.  SmallyBigs     0.34 ± 0.42
# 371.  VapingPigeon   0.34 ± 1.01
# 372.  T.Bomballdil   0.34 ± 0.31
# 373.  gghob          0.33 ± 1.01
# 374.  KonTiki        0.33 ± 0.68
# 375.  UNlTY          0.32 ± 0.28
# 376.  penguinharem   0.32 ± 0.67
# 377.  cw             0.32 ± 0.53
# 378.  GtR            0.32 ± 0.42
# 379.  Guaderno       0.31 ± 0.62
# 380.  Kemba Walker   0.31 ± 0.71
# 381.  Makhachev      0.30 ± 0.68
# 382.  note           0.30 ± 0.58
# 383.  skibbity       0.30 ± 0.28
# 384.  box            0.29 ± 1.02
# 385.  sieh           0.29 ± 0.29
# 386.  first slime    0.29 ± 0.95
# 387.  crees          0.29 ± 1.03
# 388.  Tyler Durden   0.28 ± 0.36
# 389.  Trans Rights   0.28 ± 1.01
# 390.  coos :)        0.28 ± 0.61
# 391.  Jackals        0.27 ± 0.70
# 392.  F7             0.27 ± 0.54
# 393.  CatPuke        0.27 ± 0.67
# 394.  AlysBrangwin   0.26 ± 0.79
# 395.  doodleball     0.25 ± 0.64
# 396.  N()()B         0.25 ± 0.35
# 397.  Zig!           0.25 ± 0.49
# 398.  T/\GPRO        0.25 ± 0.46
# 399.  Fingsb         0.24 ± 0.94
# 400.  1tbsp          0.24 ± 0.76
# 401.  ROBOPOP_       0.24 ± 0.42
# 402.  Ganbalf        0.24 ± 0.54
# 403.  Rexer          0.23 ± 0.41
# 404.  Food 4 Thots   0.23 ± 0.59
# 405.  Jed Bartlet    0.23 ± 0.32
# 406.  LiddiLidd      0.23 ± 0.58
# 407.  Acuraun        0.22 ± 0.65
# 408.  smalls         0.21 ± 0.86
# 409.  WhiteBallker   0.21 ± 0.90
# 410.  Grandiosity    0.21 ± 0.96
# 411.  kwib           0.20 ± 0.33
# 412.  philconnors    0.19 ± 0.79
# 413.  KahnMan        0.19 ± 0.32
# 414.  welp           0.18 ± 0.76
# 415.  Dad <|         0.17 ± 0.64
# 416.  BaullGoodman   0.17 ± 0.80
# 417.  RUFUS DU SOL   0.17 ± 0.43
# 418.  Doku           0.16 ± 0.30
# 419.  Matt           0.16 ± 0.91
# 420.  MrDMoney       0.16 ± 0.32
# 421.  gl hf :)       0.15 ± 0.42
# 422.  babyTron       0.15 ± 0.26
# 423.  CappinFalcon   0.14 ± 0.38
# 424.  JuiceWRLD999   0.14 ± 0.90
# 425.  ThePace        0.14 ± 0.60
# 426.  Kosmo          0.14 ± 0.72
# 427.  FL             0.13 ± 0.36
# 428.  Oink Oink      0.13 ± 0.56
# 429.  Pingu          0.13 ± 0.84
# 430.  ~zion~         0.12 ± 0.59
# 431.  Werth          0.12 ± 0.63
# 432.  Subglacious    0.10 ± 0.90
# 433.  MaxW           0.10 ± 0.77
# 434.  AgnusFortis    0.09 ± 0.99
# 435.  Sir Cle Jerk   0.09 ± 0.35
# 436.  Some Ball 1    0.09 ± 0.73
# 437.  Snowflaek      0.08 ± 0.53
# 438.  Waluigi        0.08 ± 0.69
# 439.  Korgmonkey     0.08 ± 0.29
# 440.  smoji_         0.07 ± 0.38
# 441.  drewfa         0.07 ± 0.38
# 442.  Ball&Oates     0.07 ± 1.01
# 443.  cantab         0.06 ± 0.48
# 444.  Crowman        0.06 ± 0.67
# 445.  GOBLlN         0.06 ± 1.03
# 446.  cereballsy     0.06 ± 0.34
# 447.  SomeKen        0.06 ± 0.88
# 448.  Wegon Windis   0.05 ± 0.59
# 449.  solongloser    0.05 ± 0.38
# 450.  Chucho         0.05 ± 0.53
# 451.  ffgr           0.05 ± 0.42
# 452.  swiss          0.05 ± 0.57
# 453.  2k             0.04 ± 0.38
# 454.  pulpo          0.04 ± 0.62
# 455.  Karasu         0.04 ± 0.41
# 456.  LethalSquirt   0.04 ± 0.37
# 457.  Dragon  Ball   0.04 ± 0.57
# 458.  sholmes        0.03 ± 0.40
# 459.  razgriz        0.03 ± 0.97
# 460.  BaII           0.02 ± 0.32
# 461.  tRiP           0.02 ± 0.92
# 462.  Pickle Ball    0.01 ± 0.61
# 463.  kyri swirvin   0.00 ± 0.42
# 464.  poodIe        -0.00 ± 0.77
# 465.  W.E.B DuBall  -0.00 ± 0.97
# 466.  SWAGSTEIN2.0  -0.00 ± 0.66
# 467.  Gyara         -0.01 ± 0.73
# 468.  Yo YoYo       -0.01 ± 0.37
# 469.  suicidebypop  -0.02 ± 0.32
# 470.  Roll Player   -0.02 ± 0.76
# 471.  gamja         -0.03 ± 0.99
# 472.  Better Mamba  -0.03 ± 0.37
# 473.  Some Ball     -0.03 ± 0.80
# 474.  snackpack     -0.03 ± 0.32
# 475.  Ralph Wiggum  -0.04 ± 0.49
# 476.  bronny james  -0.04 ± 0.37
# 477.  ADVICE MAN    -0.04 ± 0.67
# 478.  Euler         -0.04 ± 0.80
# 479.  praoprao      -0.06 ± 0.50
# 480.  TheYoungWolf  -0.06 ± 0.39
# 481.  kink ball     -0.06 ± 0.81
# 482.  Atticus       -0.07 ± 0.39
# 483.  long ball     -0.08 ± 0.45
# 484.  ToucanSam     -0.08 ± 1.01
# 485.  Jelly Rat     -0.09 ± 0.52
# 486.  Therapist     -0.09 ± 0.67
# 487.  Sam-          -0.09 ± 0.39
# 488.  NevaPopAgain  -0.10 ± 0.92
# 489.  Funky Spud    -0.10 ± 0.49
# 490.  Messy         -0.10 ± 0.31
# 491.  Nawse         -0.10 ± 1.06
# 492.  PrettyLights  -0.11 ± 0.60
# 493.  BoJack        -0.12 ± 0.64
# 494.  WRIG          -0.12 ± 0.81
# 495.  Pup Daddy     -0.12 ± 0.82
# 496.  EpicJuker     -0.12 ± 0.66
# 497.  Sloppy        -0.13 ± 0.98
# 498.  beez          -0.13 ± 0.67
# 499.  phlasid       -0.13 ± 0.34
# 500.  The Bhutan    -0.14 ± 0.45
# 501.  SilentOne     -0.14 ± 0.40
# 502.  G.O.A.T.      -0.14 ± 0.43
# 503.  easily juked  -0.14 ± 0.76
# 504.  `AppleKane    -0.15 ± 0.76
# 505.  marbleous     -0.15 ± 0.95
# 506.  Eballs        -0.15 ± 0.70
# 507.  Hangman       -0.15 ± 0.91
# 508.  oldAlt        -0.16 ± 0.33
# 509.  \m\=^_^=/m/   -0.16 ± 0.72
# 510.  Comakip       -0.18 ± 0.97
# 511.  No one        -0.18 ± 0.40
# 512.  laserpig      -0.18 ± 0.32
# 513.  helprefugees  -0.18 ± 0.33
# 514.  Grass1        -0.18 ± 0.65
# 515.  kika          -0.18 ± 0.66
# 516.  some ball 1   -0.19 ± 0.54
# 517.  benks         -0.19 ± 0.81
# 518.  Oddball       -0.19 ± 0.49
# 519.  Taddy Mason   -0.19 ± 0.34
# 520.  Darth         -0.19 ± 0.59
# 521.  Trip          -0.20 ± 0.82
# 522.  Shrimpster    -0.20 ± 0.83
# 523.  SumtimesGood  -0.20 ± 0.46
# 524.  AnthonyDavis  -0.20 ± 0.40
# 525.  Dante Ball    -0.20 ± 0.97
# 526.  CreedBratton  -0.20 ± 0.74
# 527.  Fusion        -0.21 ± 0.80
# 528.  JukeBerallta  -0.21 ± 0.32
# 529.  Sussy Blocka  -0.21 ± 0.67
# 530.  rai           -0.21 ± 0.31
# 531.  Hjalpa        -0.22 ± 0.29
# 532.  JukeOfEarl    -0.22 ± 0.35
# 533.  HammerTime    -0.22 ± 0.36
# 534.  BalIgod       -0.22 ± 0.99
# 535.  Some Boat 1   -0.22 ± 1.00
# 536.  cherryrammer  -0.22 ± 0.53
# 537.  TheGovernor   -0.22 ± 0.50
# 538.  Osy           -0.22 ± 0.37
# 539.  Pimp          -0.22 ± 0.55
# 540.  ninja         -0.22 ± 0.50
# 541.  wallsquirrel  -0.22 ± 0.37
# 542.  C-3P0         -0.23 ± 0.79
# 543.  let me cook   -0.23 ± 0.79
# 544.  lvy           -0.24 ± 0.52
# 545.  @//|@         -0.24 ± 0.98
# 546.  TriP          -0.25 ± 0.57
# 547.  Off Constant  -0.25 ± 0.53
# 548.  Vedic D       -0.25 ± 0.68
# 549.  Ducky         -0.26 ± 0.50
# 550.  GnomeChomsky  -0.26 ± 0.87
# 551.  GregPopabish  -0.27 ± 0.99
# 552.  Vancouver     -0.27 ± 0.57
# 553.  choder        -0.27 ± 0.85
# 554.  bennyclub     -0.29 ± 0.77
# 555.  twelvefive    -0.29 ± 0.42
# 556.  Marijuana     -0.29 ± 0.34
# 557.  Mystic        -0.30 ± 0.32
# 558.  Dogmatic      -0.30 ± 0.33
# 559.  I_mess_up     -0.31 ± 0.52
# 560.  gc            -0.31 ± 0.90
# 561.  dyd           -0.31 ± 0.60
# 562.  Wavy~Gravy    -0.31 ± 1.01
# 563.  Jarek         -0.32 ± 0.35
# 564.  pontoon boat  -0.32 ± 0.56
# 565.  Tagger Woods  -0.32 ± 0.41
# 566.  `ArryKane     -0.33 ± 0.37
# 567.  baked F       -0.33 ± 0.85
# 568.  JGibbs        -0.33 ± 0.81
# 569.  MickTagger    -0.34 ± 0.82
# 570.  skee lo       -0.34 ± 0.48
# 571.  Cupid         -0.34 ± 0.61
# 572.  PenFifteen    -0.34 ± 0.31
# 573.  1 Pixel Juke  -0.34 ± 0.74
# 574.  Jamyr Gibbs   -0.34 ± 1.00
# 575.  Sgt Ducky     -0.35 ± 0.54
# 576.  Schweddys     -0.36 ± 0.38
# 577.  megapoop22    -0.36 ± 0.33
# 578.  gspoon        -0.36 ± 0.31
# 579.  my fault      -0.37 ± 0.45
# 580.  CoolHandJuke  -0.37 ± 0.29
# 581.  KALX          -0.37 ± 0.35
# 582.  Cashews       -0.37 ± 0.50
# 583.  Beach         -0.37 ± 0.47
# 584.  JimBobCooter  -0.37 ± 0.37
# 585.  DuckDuckJuke  -0.37 ± 0.54
# 586.  TOP CAT       -0.38 ± 0.89
# 587.  tweedle-dee   -0.38 ± 0.58
# 588.  hihi!         -0.39 ± 0.39
# 589.  guts.         -0.39 ± 1.07
# 590.  SpiritTagger  -0.39 ± 0.46
# 591.  bones         -0.40 ± 0.71
# 592.  Arctic_Tern   -0.40 ± 0.81
# 593.  blue          -0.40 ± 0.87
# 594.  kick ankles   -0.40 ± 0.74
# 595.  ish           -0.40 ± 0.28
# 596.  FragrantFowl  -0.40 ± 0.69
# 597.  Belacqua      -0.40 ± 0.49
# 598.  Salmond Milk  -0.41 ± 0.86
# 599.  Zoltan Mesko  -0.41 ± 0.55
# 600.  Monte.        -0.42 ± 0.50
# 601.  Keyser Soze   -0.43 ± 0.50
# 602.  CBad          -0.43 ± 0.32
# 603.  lemonate      -0.43 ± 0.72
# 604.  VerniSanders  -0.43 ± 0.43
# 605.  Neph          -0.43 ± 0.67
# 606.  /~            -0.44 ± 0.80
# 607.  karthvader    -0.44 ± 1.06
# 608.  TigertheLion  -0.44 ± 0.46
# 609.  Lube          -0.44 ± 0.74
# 610.  I <3 Emacs    -0.44 ± 0.54
# 611.  SpeedyOwnt    -0.45 ± 0.72
# 612.  #4 Meerkat    -0.45 ± 0.51
# 613.  Snekster      -0.45 ± 0.47
# 614.  Bow Down      -0.45 ± 0.56
# 615.  WinCtrlShftB  -0.45 ± 0.89
# 616.  Camel         -0.45 ± 0.75
# 617.  Mr. Boop      -0.46 ± 0.94
# 618.  om            -0.46 ± 0.33
# 619.  jl            -0.47 ± 0.76
# 620.  Soccertanker  -0.47 ± 0.76
# 621.  Battletoad    -0.47 ± 0.72
# 622.  Hurri         -0.47 ± 0.87
# 623.  ZipZop        -0.47 ± 0.44
# 624.  drinks?       -0.47 ± 0.38
# 625.  THESLIGHTEST  -0.48 ± 0.43
# 626.  name a fish   -0.49 ± 0.59
# 627.  ballparts     -0.49 ± 0.92
# 628.  Ken Blocks    -0.49 ± 0.84
# 629.  Singularity   -0.49 ± 1.01
# 630.  timeboy       -0.50 ± 0.30
# 631.  Anvil         -0.50 ± 1.04
# 632.  MollyScully   -0.50 ± 0.76
# 633.  oatz_mgoatz   -0.51 ± 0.31
# 634.  NUTSNUTSNUTS  -0.51 ± 0.59
# 635.  Crumble2      -0.51 ± 0.95
# 636.  Homer Jay     -0.52 ± 0.36
# 637.  Makin Bacon   -0.52 ± 0.59
# 638.  13 volcanos   -0.52 ± 0.95
# 639.  Larry Fish    -0.52 ± 0.48
# 640.  astor         -0.53 ± 0.97
# 641.  gueromoon     -0.53 ± 0.31
# 642.  profquibb     -0.53 ± 0.87
# 643.  RoughJustice  -0.53 ± 0.93
# 644.  Om Vril       -0.54 ± 0.64
# 645.  I suck at tp  -0.54 ± 0.56
# 646.  ><><><><><><  -0.54 ± 0.44
# 647.  tbiol         -0.54 ± 0.35
# 648.  Glizzy        -0.55 ± 0.83
# 649.  urkel         -0.55 ± 0.78
# 650.  Snot Boogie   -0.56 ± 0.31
# 651.  Oscillator    -0.56 ± 0.75
# 652.  Barbara Bush  -0.58 ± 0.31
# 653.  mrme          -0.58 ± 1.05
# 654.  PBN           -0.58 ± 0.40
# 655.  EvTheSmev     -0.58 ± 0.44
# 656.  whiff         -0.59 ± 0.28
# 657.  fronk         -0.59 ± 0.59
# 658.  Fenek         -0.59 ± 0.84
# 659.  yumad2.0      -0.59 ± 0.74
# 660.  Castrator     -0.60 ± 0.38
# 661.  havok         -0.60 ± 0.38
# 662.  Vini Jr       -0.60 ± 1.05
# 663.  thiery        -0.61 ± 0.90
# 664.  Mystery Box   -0.61 ± 0.86
# 665.  Puggins       -0.61 ± 0.54
# 666.  umad          -0.61 ± 0.63
# 667.  Palps         -0.61 ± 0.87
# 668.  Solo Dolo     -0.61 ± 0.96
# 669.  Rayn          -0.61 ± 0.55
# 670.  S. Strasball  -0.61 ± 0.51
# 671.  Blip          -0.61 ± 1.07
# 672.  SphinctrSlyr  -0.63 ± 0.73
# 673.  jacenj1       -0.63 ± 0.96
# 674.  barrel roll   -0.63 ± 0.79
# 675.  Robiny        -0.63 ± 0.46
# 676.  sicky         -0.63 ± 0.44
# 677.  CoffeeSnoot   -0.64 ± 0.39
# 678.  MDK           -0.64 ± 0.38
# 679.  KOB           -0.64 ± 0.92
# 680.  wonsu         -0.64 ± 0.36
# 681.  ANDYKANSAS    -0.64 ± 0.41
# 682.  JimmyRed      -0.65 ± 0.91
# 683.  ScreamCheese  -0.65 ± 0.42
# 684.  DiegoOnMac    -0.66 ± 0.43
# 685.  thierryonre   -0.66 ± 0.73
# 686.  NateH         -0.67 ± 0.41
# 687.  Headhunter    -0.67 ± 0.70
# 688.  Glimmer       -0.68 ± 0.62
# 689.  sminitrious   -0.68 ± 0.84
# 690.  Secondskin    -0.68 ± 0.99
# 691.  Mueller       -0.68 ± 0.50
# 692.  B)            -0.68 ± 0.56
# 693.  Splatacus     -0.69 ± 0.87
# 694.  Sommeballier  -0.69 ± 0.39
# 695.  Ebhawk        -0.69 ± 0.45
# 696.  Fuck          -0.69 ± 0.70
# 697.  Lysdexic      -0.71 ± 0.76
# 698.  Phil Ballins  -0.71 ± 0.54
# 699.  State Champ   -0.73 ± 0.39
# 700.  yioSh         -0.73 ± 0.33
# 701.  Quacky        -0.74 ± 0.79
# 702.  SaladRT       -0.74 ± 0.89
# 703.  Quickdraw     -0.75 ± 0.48
# 704.  hola          -0.75 ± 0.89
# 705.  TeaForYou&Me  -0.75 ± 0.54
# 706.  Garry Lakin   -0.76 ± 0.65
# 707.  what!?!?      -0.76 ± 1.02
# 708.  Squish        -0.77 ± 0.45
# 709.  Black Mamba   -0.77 ± 0.83
# 710.  RageQuit      -0.78 ± 0.53
# 711.  RUMPSKl       -0.78 ± 0.98
# 712.  Way Maker     -0.78 ± 0.67
# 713.  spills        -0.79 ± 0.58
# 714.  Poppenheimer  -0.79 ± 0.41
# 715.  Dad Jokes!    -0.80 ± 0.40
# 716.  fl33t         -0.80 ± 0.31
# 717.  Moth-Ball     -0.81 ± 0.54
# 718.  ATXcloud      -0.81 ± 0.99
# 719.  Sinatra       -0.81 ± 0.32
# 720.  JIMBOBCOOTER  -0.81 ± 1.00
# 721.  greenfish     -0.81 ± 0.71
# 722.  ALLCAP        -0.81 ± 0.98
# 723.  BarryBerkman  -0.82 ± 0.68
# 724.  AmishVacuum   -0.83 ± 0.37
# 725.  MoGGee        -0.83 ± 0.43
# 726.  Gubbles       -0.84 ± 0.62
# 727.  Howard        -0.84 ± 0.74
# 728.  Double A      -0.84 ± 0.79
# 729.  taskforce     -0.84 ± 0.80
# 730.  bash#         -0.85 ± 0.57
# 731.  TheDr34m      -0.85 ± 0.57
# 732.  555555555555  -0.86 ± 0.46
# 733.  Hockeypuck    -0.87 ± 0.37
# 734.  Ragnar        -0.88 ± 0.39
# 735.  I'mFromKY     -0.88 ± 1.06
# 736.  SomeBall41    -0.88 ± 0.74
# 737.  McQueen       -0.89 ± 0.83
# 738.  KoaIa Beast   -0.89 ± 0.37
# 739.  ChuckNastii   -0.90 ± 0.84
# 740.  Swully        -0.90 ± 0.32
# 741.  trash panda   -0.91 ± 0.33
# 742.  GeeGee        -0.92 ± 0.72
# 743.  Optimal Taco  -0.92 ± 0.66
# 744.  Yandex        -0.92 ± 0.32
# 745.  gregster1     -0.92 ± 1.01
# 746.  dryfus        -0.93 ± 0.71
# 747.  nej           -0.94 ± 0.31
# 748.  FlyingV       -0.95 ± 0.33
# 749.  nutbutt       -0.95 ± 0.78
# 750.  Sphero Agnew  -0.96 ± 0.39
# 751.  ALCAEUS       -0.97 ± 0.73
# 752.  Flat Earth    -0.99 ± 0.33
# 753.  Umpaqua       -0.99 ± 0.96
# 754.  MURF          -0.99 ± 0.36
# 755.  rolf          -1.00 ± 0.74
# 756.  MyLittlePony  -1.02 ± 0.30
# 757.  Duckquack     -1.02 ± 0.72
# 758.  Locomotive    -1.02 ± 0.41
# 759.  Ace93         -1.03 ± 0.92
# 760.  TheWorst      -1.04 ± 0.39
# 761.  N1GHT5TA1KER  -1.05 ± 0.93
# 762.  GetPupsDeep   -1.05 ± 0.61
# 763.  TheNippIe     -1.05 ± 0.42
# 764.  11th Cmndmnt  -1.05 ± 0.43
# 765.  Princess*     -1.06 ± 1.03
# 766.  bryte         -1.06 ± 0.85
# 767.  Glass Marble  -1.06 ± 0.86
# 768.  Riley_2025    -1.08 ± 0.94
# 769.  Ann with a E  -1.08 ± 0.60
# 770.  Lirath        -1.08 ± 0.60
# 771.  TERROR NUGS   -1.09 ± 0.60
# 772.  Bambi         -1.09 ± 0.39
# 773.  Tunabomber    -1.10 ± 0.83
# 774.  DF            -1.11 ± 0.53
# 775.  TicklMeElmo   -1.11 ± 0.75
# 776.  DMT           -1.11 ± 0.94
# 777.  Bidet->Wipe   -1.11 ± 0.77
# 778.  RoVo          -1.11 ± 0.58
# 779.  dadman        -1.11 ± 0.52
# 780.  JUKELELE      -1.12 ± 0.56
# 781.  pliny         -1.12 ± 0.53
# 782.  A Straw Hat   -1.13 ± 0.43
# 783.  regicide      -1.13 ± 0.76
# 784.  NeYo          -1.14 ± 0.68
# 785.  PuyoPuyo      -1.14 ± 0.25
# 786.  fah q         -1.16 ± 0.46
# 787.  alan ball     -1.17 ± 1.04
# 788.  Hodor2        -1.17 ± 0.97
# 789.  Rabz          -1.17 ± 0.40
# 790.  Goofy Goober  -1.18 ± 0.50
# 791.  ColtCobra     -1.18 ± 1.03
# 792.  armed walrus  -1.18 ± 0.55
# 793.  Dayman        -1.18 ± 0.27
# 794.  BUTT          -1.18 ± 0.40
# 795.  MOOOOOOOOOOO  -1.18 ± 0.50
# 796.  Ifrit         -1.19 ± 1.03
# 797.  Sawney        -1.20 ± 0.70
# 798.  13.5 inches   -1.20 ± 0.73
# 799.  hail santa    -1.20 ± 0.38
# 800.  MacbookProM4  -1.21 ± 0.61
# 801.  portimao      -1.21 ± 0.85
# 802.  JJIIZGOD      -1.22 ± 0.97
# 803.  icancountto3  -1.22 ± 0.42
# 804.  SuperPoopman  -1.22 ± 0.72
# 805.  slime666      -1.23 ± 0.64
# 806.  PotatoPotato  -1.23 ± 0.56
# 807.  whosagoodboy  -1.23 ± 0.83
# 808.  Horizon       -1.23 ± 0.32
# 809.  Sick Fuck     -1.24 ± 0.68
# 810.  coos          -1.24 ± 0.91
# 811.  BadTrash      -1.24 ± 0.57
# 812.  KnightKnight  -1.25 ± 1.01
# 813.  ARoseOTGrey   -1.25 ± 0.94
# 814.  Hairy Nuts    -1.25 ± 0.35
# 815.  tomatoo       -1.25 ± 0.94
# 816.  swaglord      -1.26 ± 0.97
# 817.  Rat King      -1.26 ± 0.84
# 818.  buttcheeks    -1.26 ± 1.04
# 819.  supergremlin  -1.27 ± 0.45
# 820.  SIGKILL       -1.28 ± 0.74
# 821.  Jurj          -1.29 ± 0.99
# 822.  bhawks4life1  -1.30 ± 0.87
# 823.  Tiffany       -1.32 ± 0.59
# 824.  PairOfDice    -1.32 ± 1.05
# 825.  @pro          -1.33 ± 0.48
# 826.  Photonic S    -1.33 ± 0.66
# 827.  LilB:BallGod  -1.34 ± 0.45
# 828.  notsosober    -1.34 ± 0.96
# 829.  !__!          -1.34 ± 1.02
# 830.  Darth JarJar  -1.35 ± 0.63
# 831.  OFFENSE OWEN  -1.35 ± 0.90
# 832.  TestTickle    -1.35 ± 0.97
# 833.  aeps002       -1.37 ± 0.59
# 834.  brx           -1.37 ± 0.68
# 835.  Modric        -1.37 ± 0.52
# 836.  Crasher       -1.38 ± 0.43
# 837.  Chungo        -1.39 ± 1.05
# 838.  ShadoWolves   -1.39 ± 0.87
# 839.  Phire0901     -1.39 ± 1.06
# 840.  JareksMom     -1.40 ± 0.84
# 841.  Swift         -1.41 ± 0.61
# 842.  Sminitrious   -1.41 ± 0.66
# 843.  lowermywin%   -1.41 ± 0.73
# 844.  Fatback slim  -1.43 ± 0.38
# 845.  treyk47       -1.45 ± 0.79
# 846.  EBITDA        -1.45 ± 0.66
# 847.  T_Y           -1.46 ± 0.87
# 848.  Ibrahimovic   -1.46 ± 0.88
# 849.  Valerian      -1.46 ± 0.85
# 850.  metalhead     -1.46 ± 0.28
# 851.  BOFA          -1.47 ± 0.55
# 852.  Unaballer     -1.48 ± 0.64
# 853.  Ethan         -1.52 ± 0.97
# 854.  Exsufflicate  -1.53 ± 0.59
# 855.  emuwarvet     -1.54 ± 0.63
# 856.  Dank Blocks   -1.55 ± 0.97
# 857.  SoulSauce     -1.55 ± 0.42
# 858.  itagpro       -1.55 ± 0.90
# 859.  Umph          -1.56 ± 1.01
# 860.  Jessa         -1.58 ± 0.83
# 861.  Hugo Ball     -1.58 ± 0.66
# 862.  Zeke          -1.58 ± 0.59
# 863.  Blaatina      -1.59 ± 0.44
# 864.  gprimoff      -1.59 ± 0.57
# 865.  openseance    -1.59 ± 0.77
# 866.  Daniel        -1.61 ± 0.60
# 867.  Shit          -1.61 ± 0.71
# 868.  BasedBall     -1.62 ± 0.80
# 869.  Phenomenal    -1.63 ± 0.59
# 870.  UmamiThurman  -1.63 ± 0.78
# 871.  kojiro        -1.64 ± 0.75
# 872.  Thorfinn      -1.65 ± 0.49
# 873.  dabang khan   -1.66 ± 0.46
# 874.  Pythagoras    -1.67 ± 0.63
# 875.  DadFane       -1.67 ± 0.58
# 876.  Sway          -1.68 ± 0.52
# 877.  nightball     -1.69 ± 0.63
# 878.  *ball pun*    -1.69 ± 1.03
# 879.  drk35         -1.70 ± 0.99
# 880.  GooeyS7       -1.71 ± 0.56
# 881.  Don Garyoni   -1.72 ± 0.39
# 882.  Soupy         -1.72 ± 1.05
# 883.  MRCOW         -1.73 ± 0.59
# 884.  Some Ball X   -1.74 ± 0.71
# 885.  SunBall       -1.74 ± 0.95
# 886.  Regicide      -1.74 ± 0.37
# 887.  Fej           -1.76 ± 1.02
# 888.  Hellball2079  -1.77 ± 0.40
# 889.  Rasta Mon     -1.77 ± 1.05
# 890.  dewgazi       -1.78 ± 0.73
# 891.  Macbuckets    -1.78 ± 0.94
# 892.  ^_^           -1.80 ± 0.89
# 893.  Sweg'         -1.83 ± 0.85
# 894.  I SHOUT       -1.85 ± 0.88
# 895.  ipopu         -1.88 ± 0.56
# 896.  wherdeyatdoe  -1.90 ± 0.58
# 897.  SeymourButts  -1.91 ± 0.89
# 898.  memnite       -1.92 ± 0.70
# 899.  chaiwala      -1.93 ± 0.75
# 900.  Color Blind   -1.95 ± 0.43
# 901.  fone          -1.97 ± 0.89
# 902.  TitMouse      -2.00 ± 0.83
# 903.  BertaLovejoy  -2.00 ± 0.64
# 904.  `~`           -2.01 ± 0.40
# 905.  Damian        -2.02 ± 0.40
# 906.  Wonk          -2.03 ± 0.94
# 907.  eikoflier     -2.04 ± 0.99
# 908.  Liddi         -2.04 ± 0.86
# 909.  McPenis       -2.10 ± 0.98
# 910.  Pins&Needles  -2.10 ± 0.92
# 911.  Gemini        -2.12 ± 0.67
# 912.  Quaky20       -2.12 ± 0.51
# 913.  SphereTrauma  -2.12 ± 1.04
# 914.  Thanksman     -2.13 ± 0.37
# 915.  MOTU          -2.17 ± 0.67
# 916.  free advice   -2.21 ± 0.45
# 917.  Some Baloney  -2.23 ± 0.83
# 918.  FFFlier       -2.24 ± 0.86
# 919.  Israel Lives  -2.24 ± 0.57
# 920.  glizzy23      -2.24 ± 0.37
# 921.  Notgreat      -2.27 ± 0.88
# 922.  a frog        -2.29 ± 0.86
# 923.  So Cool       -2.29 ± 0.88
# 924.  twirly        -2.32 ± 0.42
# 925.  Toaster       -2.33 ± 0.84
# 926.  phyllis       -2.36 ± 0.39
# 927.  Youareyou     -2.37 ± 0.47
# 928.  Terry         -2.38 ± 0.63
# 929.  sinagot       -2.42 ± 0.45
# 930.  RoyaltyKeyz   -2.43 ± 1.00
# 931.  rizzmaster    -2.51 ± 0.55
# 932.  TrustJesus69  -2.51 ± 0.52
# 933.  Rascasse      -2.52 ± 0.68
# 934.  Orinoco Flow  -2.66 ± 0.64
# 935.  stall2hammer  -2.66 ± 0.35
# 936.  Avsy26        -2.68 ± 0.62
# 937.  Marblmadness  -2.68 ± 0.46
# 938.  JukeofFrance  -2.69 ± 0.75
# 939.  Sodyn33       -2.71 ± 0.77
# 940.  RodandoAndo   -2.75 ± 0.78
# 941.  sbxxvi        -2.76 ± 0.91
# 942.  MrBeaver      -2.76 ± 0.84
# 943.  OlliePoppi    -2.77 ± 0.99
# 944.  Skip          -2.86 ± 0.85
# 945.  TheBadBall    -2.88 ± 1.02
# 946.  erl           -2.92 ± 1.03
# 947.  rollingstone  -2.92 ± 0.64
# 948.  AVP           -2.99 ± 0.39
# 949.  8ananaman     -3.00 ± 1.04
# 950.  I'mBoutDat    -3.07 ± 0.44
# 951.  Rizz          -3.10 ± 0.75
# 952.  chgtus        -3.19 ± 0.54
# 953.  Argo4444      -3.21 ± 0.86
# 954.  Relax         -3.21 ± 0.84
# 955.  uglander      -3.21 ± 1.02
# 956.  BobTheBob     -3.32 ± 0.75
# 957.  whateveritis  -3.32 ± 0.99
# 958.  tutorial_wiz  -3.36 ± 0.68
# 959.  Dxebec        -3.46 ± 0.79
# 960.  G lander!     -3.54 ± 0.92

# %%
for m in matches:
    for p in m['players']:
        p['updates']['final_elo'] = players[p['name']].elo
        p['updates']['final_var'] = players[p['name']].variance
    red_elo = sum(players[p['name']].elo for p in m['players'][:4])
    blue_elo = sum(players[p['name']].elo for p in m['players'][4:])
    retro_pred = red_elo - blue_elo + RED_ADVANTAGE[
        match['map_name'] if match['map_name'] in RED_ADVANTAGE else 'default'
    ]
    retro_var = BASE_VARIANCE + sum(players[p['name']].variance for p in m['players'])
    retro_wp = 1 / (1 + CAP_TO_WP_EXPONENT ** -retro_pred)
    m['retro_red_elo'] = red_elo
    m['retro_blue_elo'] = blue_elo
    m['retro_pred'] = retro_pred
    m['retro_residual'] = m['cap_diff'] - m['retro_pred']
    m['retro_sd'] = retro_var ** 0.5
    m['retro_wp'] = retro_wp
    m['retro_wwp'] = retro_wp if m['cap_diff'] > 0 else 1 - retro_wp

print(f"MAE: {sum([abs(m['retro_residual']) for m in matches]) / len(matches):.4f}    RMS: {(sum([m['retro_residual'] ** 2 for m in matches]) / len(matches)) ** 0.5:.4f}")
print(f"COR: {sum([(1 if m['retro_wwp'] > 0.5 else 0.5 if m['retro_wwp'] == 0.5 else 0) for m in matches]) / len(matches):.2%}    WWP: {sum(m['retro_wwp'] for m in matches) / len(matches):.2%}")
print(f"BRI: {1 - (sum([(1 - m['retro_wwp']) ** 2 for m in matches]) / len(matches)) ** 0.5:.2%}    LOG: {2 ** (sum([math.log2(m['retro_wwp']) for m in matches]) / len(matches)):.2%}")
# Out:
# MAE: 2.3601    RMS: 2.8736
# COR: 61.97%    WWP: 55.06%
# BRI: 52.31%    LOG: 52.46%

# %% [markdown]
# ### Records

# %%
def pretty_print_match(m, player=None):
    player_names = sorted([p['name'] for p in m['players'][:4]], key=lambda p: players[p].elo, reverse=True) + sorted([p['name'] for p in m['players'][4:]], key=lambda p: players[p].elo, reverse=True)
    player_caps = [p['stats']['caps'] for p in m['players']]
    player_pregt_caps = [p['stats']['caps'] - p['stats']['garbage_time_caps'] for p in m['players']]
    minutes = int(m['duration'] / 3600)
    seconds = int(m['duration'] / 60) - 60 * minutes
    result = f"""Match {m['match_id']}: {', '.join(player_names[:4])} vs. {', '.join(player_names[4:])}
Expected: {m['retro_pred']:+.1f} ({m['retro_wp']:.0%}). Actual: {sum(player_caps[:4])}-{sum(player_caps[4:])} in {minutes}:{seconds:02}."""
    for p in m['players']:
        if p['name'] == player:
            result += f" Update: {p['updates']['elo_update']:+.2f}."
    return result + f" Map: {m['map_name']}\n"

def unfairness(m):
    return abs(m['retro_pred'])

def carry_required(m):
    return max(
        m['retro_blue_elo'] - m['retro_red_elo'] + max(players[p['name']].elo for p in m['players'][:4]),
        m['retro_red_elo'] - m['retro_blue_elo'] + max(players[p['name']].elo for p in m['players'][4:]),
    )

def matches_with_player(name):
    return [m for m in matches if name in [p['name'] for p in m['players']]]

# Biggest carries
for m in sorted([m for m in matches if m['retro_wwp'] < 0.5], key=unfairness, reverse=True)[:10]:
    print(pretty_print_match(m))
# Out:
# Match 4151893: ?, Curry, Robiny, fl33t vs. o o l e r, KahnMan, DiegoOnMac, chgtus
# Expected: +6.3 (97%). Actual: 1-6 in 3:21. Map: Basenji
#
# Match 3943911: danp, Toidi, JSwan, Valerian vs. Messy, HammerTime, DuckDuckJuke, spills
# Expected: +5.3 (95%). Actual: 2-3 in 8:10. Map: Moon Base 2024
#
# Match 4052597: Vorhees, State Champ, TheNippIe, Marblmadness vs. PuyoPuyo, Crasher, Hooblagoo, `~`
# Expected: +5.2 (95%). Actual: 3-4 in 8:00. Map: Combine
#
# Match 4151120: Vorhees, caprae, PenFifteen, MURF vs. MrDMoney, Karasu, TigertheLion, Garry Lakin
# Expected: +5.0 (94%). Actual: 3-8 in 7:40. Map: Asida
#
# Match 3978429: karma, Anti_Social, Gvendolino, G.O.A.T. vs. okthen, MarcusYallow, Kep, broseph
# Expected: -5.0 (6%). Actual: 3-2 in 9:27. Map: Combine
#
# Match 3934918: meowza, grumpy, Borgus, Euler vs. womp womp, TheGovernor, Vancouver, hihi!
# Expected: +4.9 (94%). Actual: 1-2 in 8:00. Map: Oak
#
# Match 3957199: chizu_mizu, Able, Korgmonkey, LilB:BallGod vs. cantab, No one, yioSh, Ragnar
# Expected: +4.9 (94%). Actual: 4-5 in 8:38. Map: Sardonica
#
# Match 3935900: Anti_Social, Chucho, Jarek, Bambi vs. Sugar, womp womp, Old Cob, helprefugees
# Expected: -4.8 (6%). Actual: 8-3 in 7:30. Map: Asida
#
# Match 3946469: SluffAndRuff, Arbybear, eee, Button vs. Homie, helen keller, rebel fox, Anti_Social
# Expected: +4.7 (93%). Actual: 3-5 in 8:00. Map: Asida
#
# Match 3981927: BUTT, Wonk, Terry, EyeInTheSky vs. Messy, BadTrash, supergremlin, Kohnago
# Expected: -4.7 (7%). Actual: 4-3 in 9:34. Map: Centenaria

# %%
player_recent_matches = matches_with_player("Tumblewood")
player_recent_matches.reverse()
for m in player_recent_matches[:15]:
    print(pretty_print_match(m, player="Tumblewood"))
# Out:
# Match 4160444: Sadness, cowboy, kmichael, KahnMan vs. Xylene, C_T, j0sh, Tumblewood
# Expected: -1.1 (35%). Actual: 2-7 in 6:55. Update: +0.02. Map: Moon Base 2024
#
# Match 4160440: realtea, Sadness, j0sh, Tumblewood vs. NameLEss, Toidi, C_T, cowboy
# Expected: +1.0 (64%). Actual: 5-3 in 8:00. Update: -0.00. Map: Audacity 2
#
# Match 4160435: realtea, Toidi, N()()B, Snot Boogie vs. NameLEss, j0sh, Tumblewood, kmichael
# Expected: -0.5 (43%). Actual: 1-4 in 8:00. Update: +0.01. Map: Thicket 2
#
# Match 4160429: realtea, Xylene, j0sh, Karasu vs. NameLEss, C_T, Tumblewood, tbiol
# Expected: +1.6 (71%). Actual: 5-3 in 8:00. Update: -0.00. Map: Basenji
#
# Match 4160424: realtea, Xylene, Doku, tbiol vs. NameLEss, j0sh, Tumblewood, Karasu
# Expected: -0.3 (46%). Actual: 4-5 in 8:00. Update: +0.00. Map: PRush
#
# Match 4160417: NameLEss, j0sh, Karasu, Hjalpa vs. Porps, Xylene, Tumblewood, whiff
# Expected: +0.3 (54%). Actual: 7-5 in 8:00. Update: -0.01. Map: OTI Jardim
#
# Match 4160412: j0sh, Tumblewood, Hjalpa, whiff vs. pho queue, N()()B, Karasu, SumtimesGood
# Expected: +0.5 (57%). Actual: 4-2 in 8:00. Update: +0.00. Map: PRush
#
# Match 4160399: Porps, Tumblewood, N()()B, ish vs. Airmigo, Chritt, T.Bomballdil, Karasu
# Expected: +0.8 (60%). Actual: 5-1 in 8:00. Update: +0.02. Map: Basenji
#
# Match 4159611: Nas, Wanye, goji, UNlTY vs. Cheezedoodle, j0sh, Tumblewood, cowboy
# Expected: +1.4 (69%). Actual: 3-1 in 8:00. Update: +0.00. Map: OTI MERALD
#
# Match 4159583: Bam, windowlicker, pho queue, Doku vs. goji, Tumblewood, Airmigo, Squish
# Expected: +0.7 (60%). Actual: 4-2 in 8:00. Update: -0.01. Map: Sardonica
#
# Match 4158956: OuchMyBalls, realtea, .__., xcv vs. jig, hz, Tinderfella, Tumblewood
# Expected: +1.1 (65%). Actual: 4-5 in 9:19. Update: +0.01. Map: Thicket 2
#
# Match 4158941: jig, realtea, mc, Tumblewood vs. BALLDON'TLIE, grunt, hz, xcv
# Expected: +0.0 (51%). Actual: 3-4 in 8:00. Update: -0.00. Map: Willow 2
#
# Match 4158936: realtea, yawn, Tumblewood, xcv vs. BALLDON'TLIE, hz, Doku, babyTron
# Expected: +1.6 (71%). Actual: 5-4 in 8:00. Update: -0.01. Map: Professor Oak
#
# Match 4158927: realtea, hz, xcv, babyTron vs. BALLDON'TLIE, Tumblewood, sss, Doku
# Expected: +0.6 (58%). Actual: 2-0 in 8:00. Update: +0.00. Map: OTI Jardim
#
# Match 4158918: BALLDON'TLIE, hz, Tumblewood, babyTron vs. realtea, yawn, xcv, sss
# Expected: -0.4 (45%). Actual: 5-0 in 7:09. Update: +0.05. Map: Asida

# %% [markdown]
# ### Analysis

# %%
def player_results_by_map(player):
    map_results = {}
    baseline = [0, 0]
    for m in matches_with_player(player):
        player_names = [p['name'] for p in m['players']]
        map_name = m['map_name']
        if map_name not in map_results:
            map_results[map_name] = [0, 0]
        map_results[map_name][0] += 1
        map_results[map_name][1] += m['retro_residual'] if player in player_names[:4] else -m['retro_residual']
        baseline[0] += 1
        baseline[1] += m['retro_residual'] if player in player_names[:4] else -m['retro_residual']
    for map_name, [gp, avg_resid] in sorted(map_results.items(), key=lambda x: x[1][0], reverse=True):
        print(f"{map_name:>28}: {avg_resid / gp - baseline[1] / baseline[0]:+.2f} ({gp:>2} games)")

player_results_by_map("Tumblewood")
# Out:
#           A Flaccid Type Map: +0.55 (59 games)
#                   Audacity 2: -0.44 (51 games)
#                        Asida: -0.24 (42 games)
#                     Milano 2: +0.12 (37 games)
#                   Centenaria: +0.37 (34 games)
#               Moon Base 2024: -0.56 (33 games)
#                      Combine: -0.76 (25 games)
#                   OTI Jardim: -0.63 (24 games)
#                    Sardonica: +0.23 (21 games)
#                     Willow 2: +0.55 (20 games)
#                   OTI MERALD: -0.27 (19 games)
#                          Oak: -0.13 (19 games)
#                    Thicket 2: -0.54 (16 games)
#              Sugar Free Hill: +0.89 ( 9 games)
#               Transilio 2024: -1.59 ( 8 games)
#                     Catch-24: +0.72 ( 7 games)
#              Apparition 2023: +0.08 ( 7 games)
#                      Pilot 3: +0.54 ( 7 games)
#                          GFY: +1.22 ( 6 games)
#                         Nuke: -1.65 ( 6 games)
#                        Haste: -1.04 ( 5 games)
#                    Pukebox 2: +0.48 ( 4 games)
#                        PRush: +2.20 ( 4 games)
#                         Pine: +0.82 ( 3 games)
#                    Pretzel 2: +1.24 ( 3 games)
#  Waterbed [MM23 West Winner]: +0.49 ( 3 games)
#                      Basenji: +2.15 ( 3 games)
#              Tetanic 3.1 4x4: +5.73 ( 1 games)
#                        Flume: +4.54 ( 1 games)
#                Crawfish Boil: +4.65 ( 1 games)
#                Professor Oak: -0.18 ( 1 games)

# %%
for i in range(0, 20):
    i *= 0.4
    total = [m for m in matches if i < abs(m['retro_pred']) < i + 0.4]
    wins = [m for m in total if m['retro_wwp'] > 0.5]
    print(f"{i:.1f}-{i + 0.4:.1f}: "
          f"{len(wins):>5} / "
          f"{len(total):>5} "
          f"({len(wins) / len(total):.1%})"
          f"  {1 / (1 + 1.7 ** -(i + 0.2)):.1%}")
# Out:
# 0.0-0.4:  6391 / 12147 (52.6%)  52.7%
# 0.4-0.8:  5862 / 10320 (56.8%)  57.9%
# 0.8-1.2:  5061 /  8129 (62.3%)  63.0%
# 1.2-1.6:  3825 /  5778 (66.2%)  67.8%
# 1.6-2.0:  2527 /  3662 (69.0%)  72.2%
# 2.0-2.4:  1711 /  2293 (74.6%)  76.3%
# 2.4-2.8:  1114 /  1410 (79.0%)  79.9%
# 2.8-3.2:   673 /   836 (80.5%)  83.1%
# 3.2-3.6:   436 /   505 (86.3%)  85.9%
# 3.6-4.0:   289 /   325 (88.9%)  88.3%
# 4.0-4.4:   198 /   222 (89.2%)  90.3%
# 4.4-4.8:   145 /   152 (95.4%)  92.0%
# 4.8-5.2:    79 /    85 (92.9%)  93.4%
# 5.2-5.6:    62 /    64 (96.9%)  94.6%
# 5.6-6.0:    44 /    44 (100.0%)  95.6%
# 6.0-6.4:    24 /    25 (96.0%)  96.4%
# 6.4-6.8:    16 /    16 (100.0%)  97.1%
# 6.8-7.2:    15 /    15 (100.0%)  97.6%
# 7.2-7.6:    13 /    13 (100.0%)  98.1%
# 7.6-8.0:     8 /     8 (100.0%)  98.4%

# %%
resids = {}
for m in matches:
    for i, p in enumerate(m['players']):
        if p['name'] not in resids:
            resids[p['name']] = [0, 0, 0]
        resids[p['name']][0] += 1
        resids[p['name']][1] += m['retro_residual'] * (1 if i < 4 else -1)
        resids[p['name']][2] += (1 - m['retro_wp']) if ((m['cap_diff'] > 0) == (i < 4)) else m['retro_wp']

for p in resids:
    resids[p][1] /= resids[p][0]
    resids[p][2] /= resids[p][0]

for m, p in sorted(resids.items(), key=lambda x: x[1][0], reverse=True)[:500]:
    if abs(p[1]) > 0.25:
        print(f"{m:>12}  {p[0]:>4}  {p[1]:+.2f}  {p[2]:.1%}")
# Out:
#        Toidi  4383  -0.30  50.0%
#  BallsToYou.  2473  -0.52  50.6%
#       Suchit  1733  -0.31  49.8%
#      CRYCHIC  1728  +0.29  49.8%
#        Irony  1691  -0.27  50.2%
#          AJ.  1689  -0.43  49.5%
#      broseph  1675  -0.40  50.2%
#    BallSaget  1649  -0.43  50.1%
#         Russ  1612  -0.28  50.1%
#         danp  1566  -0.41  50.2%
#  OuchMyBalls  1547  +0.27  50.2%
# helprefugees  1456  +0.25  50.0%
#    womp womp  1440  +0.33  50.4%
#        Porps  1259  -0.38  50.5%
#      Mileena  1243  -0.35  50.1%
#        Roxas  1201  +0.31  50.6%
#         DAD.  1178  +0.28  50.9%
#     Magnolia  1065  +0.33  50.0%
#           ez  1064  +0.43  50.4%
#         j0sh  1058  -0.33  49.9%
#       lizzey   997  -0.48  49.2%
#        Prime   978  +0.35  50.7%
# wallsquirrel   939  +0.41  50.1%
#  State Champ   908  -0.33  50.3%
#          K O   906  -0.32  50.4%
#       popsic   899  +0.42  49.4%
#      Yo YoYo   868  -0.27  49.7%
#        Doris   832  +0.34  49.4%
# SluffAndRuff   784  -0.44  49.3%
# THESLIGHTEST   784  +0.28  50.1%
# helen keller   777  +0.39  50.0%
#        CA$H.   758  -0.35  50.1%
#        Curry   747  +0.29  51.1%
#      anti-re   738  +0.42  49.6%
#      DiNgBaT   726  +0.27  49.7%
#          PBN   709  +0.27  49.4%
#     G.O.A.T.   674  +0.57  50.1%
# cherryrammer   665  -0.49  50.1%
#     heribo69   655  -0.35  48.3%
#      timeboy   632  +0.28  49.1%
#        Nilus   611  +0.32  50.8%
#          AVP   583  +0.36  49.7%
# #SelfySyntax   567  +0.30  48.8%
#           Ty   559  +0.38  49.6%
#       Ritual   500  +0.26  50.0%
#         Sam-   484  +0.32  51.4%
#       Robiny   476  +0.61  49.7%
# Better Mamba   470  -0.28  49.4%
#    TheNippIe   461  +0.26  50.1%
#      sinagot   452  +0.45  51.1%
#        Bambi   427  +0.38  49.6%
#         Zig!   405  +0.34  50.6%
#       MoGGee   372  +0.51  50.4%
#      Cashews   371  +0.37  49.1%
#   DiegoOnMac   357  -0.27  47.7%
# pontoon boat   356  +0.33  50.6%
#       grumpy   347  +0.52  51.0%
#      frieren   342  -0.29  52.1%
#        sicky   312  +0.35  50.2%
#   chizu_mizu   293  -0.51  49.9%
#       toasty   279  -0.35  50.4%
#     ROBOPOP_   272  -0.32  50.6%
#    EvTheSmev   259  +0.30  52.3%
#      skee lo   247  +0.28  49.4%
#     lemonate   243  -0.26  52.5%
#   might dino   238  +0.40  51.6%
# Helen Keller   235  -0.34  49.3%
#    Jelly Rat   234  +0.45  49.7%
# BertaLovejoy   227  -0.47  50.3%
#        Phiip   202  +0.36  52.0%
#  \m\=^_^=/m/   200  -0.35  50.9%

# %%
maps = {}
for m in matches:
    if m['map_name'] not in maps:
        maps[m['map_name']] = [0, 0, 0, 0, 0, 0]
    maps[m['map_name']][0] += 1
    maps[m['map_name']][3] += m['retro_residual']
    maps[m['map_name']][1] += math.log2(0.5 + abs(m['retro_wp'] - 0.5))
    maps[m['map_name']][2] += math.log2(m['retro_wwp'])
    maps[m['map_name']][4] += abs(m['retro_residual'])
    maps[m['map_name']][5] += m['retro_residual'] ** 2
for m in maps.values():
    if m[0] == 0:
        continue
    m[1] /= m[0]
    m[2] /= m[0]
    m[3] /= m[0]
    m[4] /= m[0]
    m[5] /= m[0]

for m, p in sorted(maps.items(), key=lambda x: x[1][0], reverse=True):
    print(f"{m:>27}  {p[0]:>4}  {2 ** p[1]:.1%}  {2 ** p[2]:.1%}  {p[3] + RED_ADVANTAGE[m if m in RED_ADVANTAGE else 'default']:+.2f}  {p[4]:.2f}  {p[5]:.2f}")
# Out:
#          A Flaccid Type Map  5379  61.6%  52.0%  -0.00  2.27  7.71
#                  Audacity 2  4839  62.8%  52.4%  +0.32  2.28  7.84
#                       Asida  4449  63.3%  52.8%  +0.29  2.55  9.42
#              Moon Base 2024  4141  62.8%  52.5%  +0.34  2.39  8.40
#                  Centenaria  3463  62.8%  52.7%  -0.07  2.42  8.61
#                    Milano 2  3422  62.5%  52.2%  +0.37  2.44  8.80
#                     Combine  3240  63.0%  52.8%  -0.06  2.39  8.35
#                   Sardonica  2373  62.0%  52.2%  -0.11  2.52  9.19
#                  OTI MERALD  1843  63.8%  53.3%  -0.11  2.35  8.27
#                   Thicket 2  1739  61.8%  51.7%  +0.01  2.29  7.79
#                         Oak  1727  63.5%  53.1%  +0.10  2.19  7.26
#                  OTI Jardim  1707  61.9%  52.4%  +0.25  2.45  8.69
#                    Willow 2  1573  62.9%  51.8%  -0.11  2.34  8.06
#             Sugar Free Hill   988  61.7%  52.0%  -0.30  2.26  7.69
#                     Pilot 3   947  61.7%  51.8%  +0.13  2.17  7.02
#             Apparition 2023   912  61.1%  51.5%  +0.06  2.27  7.54
#              Transilio 2024   798  61.4%  53.0%  +0.22  2.20  7.37
#                     Basenji   434  62.2%  53.1%  +0.25  2.33  8.17
#                        Nuke   340  62.7%  52.3%  +0.12  2.38  8.72
#                    Catch-24   316  65.0%  53.7%  +0.20  2.14  7.06
#                        Pine   314  67.1%  53.7%  -0.35  2.35  8.46
#                       Haste   290  61.3%  51.6%  +0.24  2.24  7.73
#                   Pukebox 2   157  62.4%  51.6%  +0.01  2.48  8.46
#                   Pretzel 2   135  62.1%  53.0%  +0.30  2.00  6.09
#                         GFY   131  65.6%  55.8%  +0.09  2.15  6.68
# Waterbed [MM23 West Winner]   106  63.9%  52.1%  +0.07  1.96  5.93
#               Professor Oak    79  67.0%  58.9%  -0.03  1.91  5.49
#             Tetanic 3.1 4x4    69  61.8%  50.6%  +0.04  2.47  8.90
#                       PRush    55  67.4%  53.8%  -0.26  2.62  9.40
#                       Flume    51  71.6%  65.3%  +0.05  2.15  6.36
#               Crawfish Boil    44  63.5%  53.8%  -0.09  2.31  8.43
#                     Tetanic     6  58.1%  46.4%  +1.35  2.33  8.50

# %% [markdown]
# ### Results

# %% [markdown]
# Guessing 0:
#
# ```
# MAE: 2.6057    RMS: 3.0680
# COR: 50.00%    WWP: 50.00%
# BRI: 50.00%    LOG: 50.00%
# ```
#
# Current system:
#
# ```
# MAE: 2.4051    RMS: 2.9134
# COR: 60.39%    WWP: 53.66%
# BRI: 51.79%    LOG: 51.89%
# ```
#
# With hindsight:
#
# ```
# MAE: 2.3632    RMS: 2.8768
# COR: 61.78%    WWP: 54.97%
# BRI: 52.24%    LOG: 52.39%
# ```
