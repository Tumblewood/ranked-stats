# %%
import json
from datetime import date
from typing import Dict
import math
import csv

STAT_NAMES = [
    "caps", "hold", "earlyhold", "latehold", "ndps", "returns",
    "quick_returns", "nrts", "pups", "handoffs", "prevent", "lateprevent"
]

with open("../data/bulkmaps.json", encoding="utf-8") as f:
    maps = json.load(f)

with open("smurfs.json") as f:
    smurfs = json.load(f)

def desmurf(player):
    player = player.replace("\\'", "'").replace("\\\\", "\\")
    if player in smurfs:
        return smurfs[player]
    return player

def row_to_dict(row):
    return {
        'match_id': int(row[0]),
        'map_name': maps[row[1]]['name'],
        'gamemode': maps[row[1]]['type'],
        'timestamp': int(row[2]),
        'duration': int(row[3]),
        'cap_diff': int(row[4]),
        'players': [
            {
                'name': desmurf(row[j + 5]),
                'stats': {
                    stat_name: int(row[j * len(STAT_NAMES) + 13 + i])
                    for i, stat_name in enumerate(STAT_NAMES)
                }
            }
            for j in range(8)
        ]
    }

with open("matchups_with_stats.csv") as f:
    reader = csv.reader(f)
    next(reader)
    matches = [row_to_dict(row) for row in reader]
    matches = [m for m in matches if m['gamemode'] == "ctf"]

players = {}

# %%
NEW_PLAYER_ELO = 0
STARTING_VARIANCE = 0.65
MAX_VARIANCE_TO_COUNT_AS_KNOWN = 0.3
VARIANCE_TO_ADD_BACK = 0.0005
BASE_VARIANCE = 5
RED_ADVANTAGE = {
    'default': 0.1,
    'A Flaccid Type Map': 0,
    'Audacity 2': 0.2,
    'Moon Base 2024': 0.2,
    'Asida': 0.2,
    'Centenaria': 0,
    'Milano 2': 0.2,
    'Combine': 0,
    'Sardonica': 0,
    'OTI MERALD': 0,
    'OTI Jardim': 0.2,
    'Willow 2': 0,
    'Sugar Free Hill': -0.1,
}
DIFF_MAPPING = [0, 0.2, 0.9, 2.0, 3.1, 4.3, -4.3, -3.1, -2.0, -0.9, -0.2]
STAT_SCORE_WEIGHT_BY_CAP_DIFF = 0.2
CAP_TO_WP_EXPONENT = 1.7
PLAYER_STAT_WEIGHTS = {
    "caps": 1.75,
    "hold": 3.0 / 3600,
    "ndps": -0.75,
    "returns": 0.75,
    "nrts": 0.5,
    "pups": 0.6,
}
TEAM_STAT_WEIGHTS = {
    "caps": 0.0,
    "hold": 0.7 / 3600,
    "ndps": 0.0,
    "returns": 0.03,
    "nrts": 0.0,
    "pups": 0.03,
    
}
RELATIVE_ELO_CORRECTION = 2.2

# %%
class Player:
    def __init__(self, name):
        self.name = name
        self.elo = NEW_PLAYER_ELO
        self.variance = STARTING_VARIANCE
        self.lowest_ever_variance = self.variance
        self.stat_farm_amount = 0
        self.high_certainty_play = 0

    def error_bar(self):
        return 1.96 * self.variance ** 0.5
    
    def update_rating(self, p, match, error, stat_score, team_avg_elo, total_variance):
        p['updates'] = {
            'elo_before': self.elo,
            'variance_before': self.variance,
        }
        share_of_variance = self.variance / total_variance

        # Calculate stat score (weighted based on newness)
        newness = self.variance / STARTING_VARIANCE
        stat_score = stat_score * newness

        # Apply a slight correction to stat score based on relative elo
        elo_vs_game_avg = self.elo - team_avg_elo
        stat_score -= elo_vs_game_avg * newness * RELATIVE_ELO_CORRECTION

        # Weight stat score higher in blowouts
        stat_score *= 1 + STAT_SCORE_WEIGHT_BY_CAP_DIFF * (abs(match['cap_diff']) - 1)

        # Apply Bayesian update (error times share of variance, plus stat score)
        update = error + stat_score
        self.elo += update * share_of_variance
        self.variance *= 1 - share_of_variance
        self.lowest_ever_variance = min(self.variance, self.lowest_ever_variance)

        # Track the update that was applied
        p['updates']['elo_update'] = self.elo - p['updates']['elo_before']

    def overperformance(self, decay=0.998):
        expected_wins, actual_wins = 0, 0
        expected_cap_diff, actual_cap_diff = 0, 0
        weighted_games_played = 0
        for m in matches:
            names = [p['name'] for p in m['players']]
            if self.name in names:
                is_red = self.name in names[:4]
                weight = decay ** (date.today() - date.fromtimestamp(m['timestamp'])).days
                weighted_games_played += weight
                expected_score = sum(players[p].elo for p in names[:4]) - sum(players[p].elo for p in names[4:]) +\
                    RED_ADVANTAGE[m['map_name'] if m['map_name'] in RED_ADVANTAGE else 'default']
                red_win_prob = 1 / (1 + CAP_TO_WP_EXPONENT ** -expected_score)
                if is_red:
                    expected_cap_diff += expected_score * weight
                    actual_cap_diff += m['cap_diff'] * weight
                    expected_wins += red_win_prob * weight
                    actual_wins += (1 if m['cap_diff'] > 0 else 0.5 if m['cap_diff'] == 0 else 0) * weight
                else:
                    expected_cap_diff += expected_score * weight
                    actual_cap_diff += m['cap_diff'] * weight
                    expected_wins += (1 - red_win_prob) * weight
                    actual_wins += (1 if m['cap_diff'] < 0 else 0.5 if m['cap_diff'] == 0 else 0) * weight

        return (
            (actual_wins - expected_wins) / weighted_games_played,
            (actual_cap_diff - expected_cap_diff) / weighted_games_played
        )

    def __str__(self):
        return f"{self.name} ({self.elo:.2f} ± {self.error_bar():.2f})"
    
    def __repr__(self):
        return f"Player \"{self.name}\" ({self.elo:.2f} ± {self.error_bar():.2f})"

# %%
def normalize_elos():
    known_elos = [p.elo for p in players.values() if p.variance <= MAX_VARIANCE_TO_COUNT_AS_KNOWN]
    avg_elo = sum(known_elos) / max(10, len(known_elos))
    for p in players.values():
        p.elo -= avg_elo
        p.variance = min(p.variance + VARIANCE_TO_ADD_BACK, STARTING_VARIANCE)

def stat_scores(players, scoring_dict: Dict[str, int]):
    return [
        sum([
            p['stats'][stat_name] * scoring_dict[stat_name]
            for stat_name in scoring_dict
        ])
        for p in players
    ]

def judge_player_stats(players):
    player_scores = stat_scores(players, PLAYER_STAT_WEIGHTS)

    red_avg_score = sum(player_scores[:4]) / 4
    blue_avg_score = sum(player_scores[4:]) / 4
    red_scores = [s - red_avg_score for s in player_scores[:4]]
    blue_scores = [s - blue_avg_score for s in player_scores[4:]]
    return red_scores, blue_scores

def update_ratings(match):
    # Calculate skill for each team and game variance
    red_elo = 0
    blue_elo = 0
    total_variance = BASE_VARIANCE

    for p in match['players']:
        if p['name'] not in players:
            players[p['name']] = Player(p['name'])
        total_variance += players[p['name']].variance
    
    for p in match['players'][:4]:
        red_elo += players[p['name']].elo
    for p in match['players'][4:]:
        blue_elo += players[p['name']].elo
    
    expected_score = red_elo - blue_elo + RED_ADVANTAGE[
        match['map_name'] if match['map_name'] in RED_ADVANTAGE else 'default'
    ]

    # Track predictions
    match['red_elo'] = red_elo
    match['blue_elo'] = blue_elo
    match['pred'] = expected_score
    match['sd'] = total_variance ** 0.5
    match['wp'] = 1 / (1 + CAP_TO_WP_EXPONENT ** -expected_score)
    match['residual'] = match['cap_diff'] - min(max(expected_score, -5), 5)
    match['wwp'] = match['wp'] if match['cap_diff'] > 0 else 1 - match['wp']
    
    # Calculate the error used for Bayesian updating
    error = DIFF_MAPPING[match['cap_diff']] - min(max(expected_score, DIFF_MAPPING[-4]), DIFF_MAPPING[4])

    # Incorporate team total stats into the error
    team_scores = stat_scores(match['players'], TEAM_STAT_WEIGHTS)
    error += sum(team_scores[:4]) - sum(team_scores[4:])

    # Update ratings based on this error and the variance
    red_stat_scores, blue_stat_scores = judge_player_stats(match['players'])
    for p, stat_score in zip(match['players'][:4], red_stat_scores):
        players[p['name']].update_rating(p, match, error, stat_score, red_elo / 4, total_variance)
    for p, stat_score in zip(match['players'][4:], blue_stat_scores):
        players[p['name']].update_rating(p, match, -error, stat_score, blue_elo / 4, total_variance)

# %%
players = {}
day = date.fromtimestamp(matches[0]['timestamp'])
player_to_track = "Tumblewood"
played_today = 0

for match in matches:
    if any(p['name'] == player_to_track for p in match['players']):
        played_today += 1
    new_day = date.fromtimestamp(match['timestamp'])
    if new_day != day:
        normalize_elos()
        if played_today > 0:
            print(f"{new_day}: {players[player_to_track].elo:.2f} ± {players[player_to_track].error_bar():.2f} ({played_today} games)")
            played_today = 0
    day = new_day
    update_ratings(match)

print(f"MAE: {sum([abs(m['residual']) for m in matches]) / len(matches):.4f}    RMS: {(sum([m['residual'] ** 2 for m in matches]) / len(matches)) ** 0.5:.4f}")
print(f"COR: {sum([(1 if m['wwp'] > 0.5 else 0.5 if m['wwp'] == 0.5 else 0) for m in matches]) / len(matches):.2%}    WWP: {sum(m['wwp'] for m in matches) / len(matches):.2%}")
print(f"BRI: {1 - (sum([(1 - m['wwp']) ** 2 for m in matches]) / len(matches)) ** 0.5:.2%}    LOG: {2 ** (sum([math.log2(m['wwp']) for m in matches]) / len(matches)):.2%}")

for p in players.values():
    p.elo *= 0.8
    p.variance *= 1.25 ** 2

day = date.fromtimestamp(matches[0]['timestamp'])

for match in matches:
    new_day = date.fromtimestamp(match['timestamp'])
    if new_day != day:
        normalize_elos()
    day = new_day
    update_ratings(match)

print(f"MAE: {sum([abs(m['residual']) for m in matches]) / len(matches):.4f}    RMS: {(sum([m['residual'] ** 2 for m in matches]) / len(matches)) ** 0.5:.4f}")
print(f"COR: {sum([(1 if m['wwp'] > 0.5 else 0.5 if m['wwp'] == 0.5 else 0) for m in matches]) / len(matches):.2%}    WWP: {sum(m['wwp'] for m in matches) / len(matches):.2%}")
print(f"BRI: {1 - (sum([(1 - m['wwp']) ** 2 for m in matches]) / len(matches)) ** 0.5:.2%}    LOG: {2 ** (sum([math.log2(m['wwp']) for m in matches]) / len(matches)):.2%}")
# Out:
# 2025-03-28: -0.80 ± 1.03 (18 games)
# 2025-04-06: -0.28 ± 0.88 (10 games)
# 2025-04-11: 0.08 ± 0.70 (16 games)
# 2025-04-12: 0.11 ± 0.63 (10 games)
# 2025-04-14: 0.26 ± 0.62 (3 games)
# 2025-04-15: 0.23 ± 0.58 (8 games)
# 2025-04-17: 0.24 ± 0.55 (8 games)
# 2025-04-19: 0.18 ± 0.51 (11 games)
# 2025-05-02: 0.23 ± 0.49 (13 games)
# 2025-05-07: 0.24 ± 0.49 (3 games)
# 2025-05-14: 0.35 ± 0.46 (16 games)
# 2025-05-15: 0.27 ± 0.44 (11 games)
# 2025-05-17: 0.27 ± 0.44 (4 games)
# 2025-05-18: 0.28 ± 0.43 (4 games)
# 2025-05-22: 0.30 ± 0.43 (4 games)
# 2025-05-23: 0.29 ± 0.43 (1 games)
# 2025-05-30: 0.25 ± 0.43 (6 games)
# 2025-05-31: 0.27 ± 0.43 (3 games)
# 2025-06-01: 0.31 ± 0.42 (4 games)
# 2025-06-03: 0.34 ± 0.42 (6 games)
# 2025-06-04: 0.33 ± 0.42 (1 games)
# 2025-06-05: 0.30 ± 0.42 (2 games)
# 2025-06-06: 0.34 ± 0.42 (1 games)
# 2025-06-08: 0.36 ± 0.42 (1 games)
# 2025-06-09: 0.36 ± 0.42 (1 games)
# 2025-06-14: 0.28 ± 0.42 (5 games)
# 2025-06-15: 0.32 ± 0.40 (12 games)
# 2025-06-18: 0.39 ± 0.41 (3 games)
# 2025-06-19: 0.37 ± 0.41 (2 games)
# 2025-06-21: 0.32 ± 0.40 (4 games)
# 2025-06-22: 0.45 ± 0.39 (11 games)
# 2025-06-27: 0.37 ± 0.40 (4 games)
# 2025-06-29: 0.29 ± 0.37 (20 games)
# 2025-07-01: 0.32 ± 0.37 (5 games)
# 2025-07-06: 0.26 ± 0.38 (6 games)
# 2025-07-09: 0.27 ± 0.38 (2 games)
# 2025-07-10: 0.27 ± 0.38 (4 games)
# 2025-07-11: 0.28 ± 0.37 (8 games)
# 2025-07-12: 0.26 ± 0.37 (4 games)
# 2025-07-13: 0.31 ± 0.37 (4 games)
# 2025-07-14: 0.32 ± 0.36 (5 games)
# 2025-07-18: 0.35 ± 0.37 (6 games)
# 2025-07-19: 0.24 ± 0.36 (9 games)
# 2025-07-20: 0.24 ± 0.36 (1 games)
# 2025-07-24: 0.27 ± 0.36 (5 games)
# 2025-08-12: 0.31 ± 0.40 (6 games)
# 2025-08-20: 0.36 ± 0.42 (2 games)
# 2025-08-24: 0.32 ± 0.42 (4 games)
# 2025-08-25: 0.26 ± 0.41 (8 games)
# 2025-08-30: 0.14 ± 0.40 (8 games)
# 2025-09-01: 0.11 ± 0.40 (6 games)
# 2025-09-04: 0.04 ± 0.40 (4 games)
# 2025-09-07: 0.07 ± 0.40 (4 games)
# 2025-09-10: 0.06 ± 0.41 (1 games)
# 2025-09-14: 0.08 ± 0.41 (1 games)
# 2025-09-17: 0.04 ± 0.41 (4 games)
# 2025-09-21: 0.11 ± 0.41 (8 games)
# 2025-09-23: 0.08 ± 0.41 (1 games)
# 2025-09-24: -0.03 ± 0.41 (5 games)
# 2025-09-25: -0.00 ± 0.40 (6 games)
# 2025-09-26: 0.02 ± 0.39 (5 games)
# 2025-09-27: 0.01 ± 0.39 (1 games)
# 2025-09-28: 0.03 ± 0.39 (3 games)
# 2025-10-05: 0.03 ± 0.41 (1 games)
# 2025-10-06: 0.02 ± 0.40 (6 games)
# 2025-10-19: 0.10 ± 0.42 (6 games)
# 2025-10-20: 0.19 ± 0.42 (3 games)
# 2025-10-26: 0.20 ± 0.43 (1 games)
# 2025-11-06: 0.21 ± 0.45 (1 games)
# 2025-11-10: 0.20 ± 0.45 (5 games)
# 2025-11-15: 0.16 ± 0.44 (8 games)
# 2025-11-16: 0.17 ± 0.43 (4 games)
# 2025-11-22: 0.23 ± 0.44 (2 games)
# 2025-11-25: 0.29 ± 0.44 (4 games)
# 2025-11-27: 0.33 ± 0.43 (8 games)
# 2025-11-29: 0.30 ± 0.42 (8 games)
# 2025-12-01: 0.34 ± 0.41 (7 games)
# 2025-12-07: 0.38 ± 0.41 (6 games)
# 2025-12-08: 0.38 ± 0.41 (3 games)
# 2025-12-15: 0.36 ± 0.41 (2 games)
# 2025-12-17: 0.43 ± 0.41 (6 games)
# 2025-12-20: 0.51 ± 0.40 (10 games)
# 2025-12-22: 0.62 ± 0.39 (7 games)
# 2025-12-25: 0.69 ± 0.39 (5 games)
# 2025-12-27: 0.72 ± 0.40 (2 games)
# 2025-12-28: 0.75 ± 0.38 (10 games)
# 2025-12-29: 0.75 ± 0.38 (2 games)
# 2025-12-30: 0.81 ± 0.38 (8 games)
# 2025-12-31: 0.81 ± 0.37 (4 games)
# 2026-01-02: 0.83 ± 0.38 (1 games)
# 2026-01-04: 0.78 ± 0.37 (8 games)
# 2026-01-05: 0.77 ± 0.36 (10 games)
# MAE: 2.4096    RMS: 2.9190
# COR: 60.58%    WWP: 53.61%
# BRI: 51.83%    LOG: 51.93%
# MAE: 2.3773    RMS: 2.8778
# COR: 61.54%    WWP: 53.91%
# BRI: 52.21%    LOG: 52.35%

# %%
leaderboard = sorted([
    p for p in players.values() if p.variance <= MAX_VARIANCE_TO_COUNT_AS_KNOWN
], key=lambda p: p.elo, reverse=True)
for i, p in enumerate(leaderboard):
    print(f"{i + 1:>3}.  {p.name:<12}  {p.elo:5.2f} ± {1.96 * p.variance ** 0.5:.2f}")
# Out:
#   1.  tng.           3.29 ± 0.32
#   2.  DT             3.29 ± 0.40
#   3.  Junoon         3.21 ± 0.34
#   4.  okthen         3.16 ± 0.51
#   5.  chizu_mizu     3.07 ± 0.32
#   6.  toasty         2.99 ± 0.59
#   7.  Alphachurro    2.80 ± 0.41
#   8.  Xx360NoSwagx   2.78 ± 0.59
#   9.  meowza         2.74 ± 0.30
#  10.  Vorhees        2.64 ± 0.28
#  11.  mex            2.64 ± 0.31
#  12.  Jester101      2.63 ± 0.89
#  13.  Mileena        2.59 ± 0.27
#  14.  bright         2.58 ± 0.48
#  15.  BALLDON'TLIE   2.54 ± 0.32
#  16.  ?              2.50 ± 0.31
#  17.  bitter heart   2.47 ± 0.75
#  18.  Suchit         2.45 ± 0.33
#  19.  phreak         2.43 ± 0.40
#  20.  Ritual         2.41 ± 0.48
#  21.  jig            2.39 ± 0.33
#  22.  fender         2.38 ± 0.36
#  23.  frieren        2.37 ± 0.75
#  24.  Galvatron      2.35 ± 0.78
#  25.  realtea        2.32 ± 0.30
#  26.  Madoka         2.31 ± 0.66
#  27.  OuchMyBalls    2.30 ± 0.29
#  28.  HelloI'mGurt   2.20 ± 0.89
#  29.  Crippy         2.18 ± 0.40
#  30.  1deag          2.18 ± 0.44
#  31.  flaccid trip   2.18 ± 0.34
#  32.  First          2.15 ± 0.90
#  33.  Arbybear       2.15 ± 0.66
#  34.  ASAP           2.15 ± 0.43
#  35.  simp.          2.12 ± 0.32
#  36.  Thrust         2.11 ± 0.85
#  37.  grunt          2.11 ± 0.39
#  38.  kool aid       2.11 ± 0.52
#  39.  Cape           2.09 ± 0.74
#  40.  Ty             2.09 ± 0.50
#  41.  black orchid   2.07 ± 0.32
#  42.  Doris          2.07 ± 0.50
#  43.  Messi          2.06 ± 0.29
#  44.  Mr awesome:)   2.05 ± 0.54
#  45.  Sugar          2.04 ± 0.64
#  46.  bbb            2.01 ± 0.34
#  47.  i love HD      2.01 ± 0.80
#  48.  swerve         2.01 ± 0.88
#  49.  Ball-E         2.01 ± 0.66
#  50.  2Nutz          1.99 ± 0.32
#  51.  rina           1.98 ± 0.47
#  52.  eee            1.97 ± 0.50
#  53.  ~              1.96 ± 0.57
#  54.  Vader          1.96 ± 0.48
#  55.  tits           1.95 ± 0.59
#  56.  BallsToYou.    1.95 ± 0.38
#  57.  jazzz          1.92 ± 0.44
#  58.  Button         1.92 ± 0.36
#  59.  grumpy         1.85 ± 0.45
#  60.  known          1.84 ± 0.40
#  61.  SleepyBoi      1.83 ± 0.36
#  62.  popsic         1.80 ± 0.35
#  63.  Carrrrrl       1.79 ± 0.37
#  64.  SakuUta        1.79 ± 0.47
#  65.  Abe Lincoln    1.78 ± 0.60
#  66.  tears          1.77 ± 0.44
#  67.  Cheetosrule    1.77 ± 0.44
#  68.  Taurus         1.77 ± 0.34
#  69.  vanitas        1.76 ± 0.86
#  70.  NEUhusky       1.75 ± 0.80
#  71.  yawn           1.75 ± 0.35
#  72.  NameLEss       1.74 ± 0.38
#  73.  karma          1.74 ± 0.28
#  74.  Homie          1.73 ± 0.45
#  75.  kelvin         1.73 ± 0.96
#  76.  tha king       1.72 ± 0.29
#  77.  KING KRULE     1.70 ± 0.32
#  78.  BallSaget      1.70 ± 0.28
#  79.  dodsfall       1.69 ± 0.37
#  80.  Russ           1.68 ± 0.30
#  81.  Spjork         1.67 ± 0.32
#  82.  helen keller   1.66 ± 0.39
#  83.  churt chimi    1.65 ± 0.63
#  84.  MarcusYallow   1.64 ± 0.51
#  85.  Wanye          1.64 ± 0.36
#  86.  anti-re        1.60 ± 0.34
#  87.  360broscope    1.60 ± 0.55
#  88.  ||||||||||||   1.60 ± 0.73
#  89.  Mista Feeneh   1.59 ± 0.44
#  90.  Cheezedoodle   1.57 ± 0.39
#  91.  keithstoned1   1.56 ± 0.84
#  92.  AdmaniaYT      1.55 ± 0.39
#  93.  Curry          1.52 ± 0.40
#  94.  omar           1.52 ± 0.79
#  95.  yep            1.49 ± 0.50
#  96.  mactheroni     1.48 ± 0.32
#  97.  DAD.           1.48 ± 0.34
#  98.  SoulCake       1.48 ± 0.67
#  99.  Jinjo          1.48 ± 0.74
# 100.  zo2            1.47 ± 0.31
# 101.  Bomberguy      1.46 ± 1.02
# 102.  Kep            1.46 ± 0.34
# 103.  autumn heart   1.45 ± 0.89
# 104.  anduin         1.45 ± 0.38
# 105.  Niya           1.45 ± 0.93
# 106.  caprae         1.45 ± 0.30
# 107.  Stronk         1.44 ± 0.66
# 108.  omni           1.44 ± 0.32
# 109.  DudeMcGuy      1.44 ± 0.78
# 110.  blah-zay       1.42 ± 0.55
# 111.  Boat           1.42 ± 0.71
# 112.  Reze20         1.41 ± 0.61
# 113.  aaron          1.41 ± 0.46
# 114.  Niplepotamus   1.40 ± 0.73
# 115.  meaL           1.40 ± 1.06
# 116.  d0pe           1.40 ± 0.38
# 117.  tune           1.40 ± 0.65
# 118.  TheG           1.39 ± 0.38
# 119.  kasli          1.39 ± 0.68
# 120.  Frank          1.39 ± 0.81
# 121.  Magnolia       1.39 ± 0.37
# 122.  womp womp      1.38 ± 0.28
# 123.  Jer32          1.38 ± 0.65
# 124.  JKooter        1.37 ± 0.32
# 125.  St. Bernard    1.36 ± 0.65
# 126.  Sphear         1.36 ± 0.88
# 127.  Irony          1.36 ± 0.39
# 128.  DingusDongus   1.35 ± 0.73
# 129.  wasserstein    1.35 ± 0.62
# 130.  Thanos Ball    1.35 ± 0.34
# 131.  Light          1.35 ± 0.39
# 132.  Ball of Fame   1.33 ± 0.85
# 133.  Butter         1.33 ± 0.55
# 134.  StaIin         1.32 ± 0.52
# 135.  Gamepad God    1.30 ± 0.57
# 136.  DiNgBaT        1.30 ± 0.36
# 137.  Shaolin        1.29 ± 0.70
# 138.  Mos Def        1.28 ± 0.43
# 139.  snuffed        1.28 ± 0.76
# 140.  Prime          1.28 ± 0.34
# 141.  Wraith         1.27 ± 0.37
# 142.  hz             1.26 ± 0.26
# 143.  magicmuffin8   1.26 ± 0.47
# 144.  JBaay          1.26 ± 0.76
# 145.  Nas            1.26 ± 0.53
# 146.  Corbeh         1.25 ± 0.43
# 147.  Bam            1.25 ± 0.40
# 148.  clew3          1.24 ± 0.78
# 149.  a virgin dad   1.24 ± 1.00
# 150.  jkxs           1.23 ± 0.32
# 151.  Kei Yonagi     1.23 ± 0.60
# 152.  DEAD NAN       1.22 ± 0.62
# 153.  MarkBallis     1.22 ± 0.71
# 154.  beef           1.22 ± 0.61
# 155.  not lazy       1.20 ± 1.03
# 156.  rake           1.20 ± 0.79
# 157.  .__.           1.20 ± 0.39
# 158.  Tinderfella    1.19 ± 0.37
# 159.  Snowball       1.19 ± 0.53
# 160.  LewBird        1.19 ± 0.33
# 161.  #SelfySyntax   1.18 ± 0.31
# 162.  Recap          1.18 ± 0.55
# 163.  Niku           1.18 ± 0.57
# 164.  Sadness        1.18 ± 0.32
# 165.  vic            1.15 ± 0.36
# 166.  George         1.15 ± 0.75
# 167.  BallAnka       1.14 ± 0.49
# 168.  Baay           1.14 ± 0.55
# 169.  Ballzilla      1.14 ± 0.71
# 170.  PTF            1.14 ± 0.37
# 171.  ObliqueOwl     1.13 ± 0.66
# 172.  yiss           1.13 ± 0.37
# 173.  Jason Bourne   1.12 ± 0.86
# 174.  Borgus         1.11 ± 0.36
# 175.  q42            1.10 ± 0.48
# 176.  Adamn          1.10 ± 0.54
# 177.  broseph        1.10 ± 0.28
# 178.  t h C          1.08 ± 0.39
# 179.  RedBull        1.08 ± 0.45
# 180.  Magikarp       1.08 ± 0.38
# 181.  Porps          1.08 ± 0.36
# 182.  arksoldier     1.08 ± 0.77
# 183.  Poeticalto     1.07 ± 0.49
# 184.  EpicBlob       1.07 ± 0.42
# 185.  Kamikaze       1.07 ± 0.55
# 186.  Trapsin        1.07 ± 0.38
# 187.  yippie         1.07 ± 0.81
# 188.  Rick G. #853   1.05 ± 0.44
# 189.  goji           1.05 ± 0.56
# 190.  Jump Ball      1.05 ± 0.97
# 191.  mc             1.05 ± 0.32
# 192.  D Rek          1.04 ± 0.47
# 193.  Toidi          1.04 ± 0.20
# 194.  CA$H.          1.04 ± 0.35
# 195.  Squeeb         1.03 ± 0.59
# 196.  Threeflower    1.02 ± 0.38
# 197.  heribo69       1.01 ± 0.42
# 198.  bleast         1.01 ± 0.90
# 199.  bumballbee     1.01 ± 0.84
# 200.  jjpoole        1.00 ± 0.33
# 201.  P-d0g          1.00 ± 0.73
# 202.  Misery         1.00 ± 0.47
# 203.  Rudey          0.99 ± 0.40
# 204.  TNT            0.99 ± 1.01
# 205.  lizzey         0.99 ± 0.64
# 206.  C_T            0.98 ± 0.27
# 207.  Armbranch      0.98 ± 0.72
# 208.  tnevlos        0.98 ± 0.41
# 209.  Crees          0.96 ± 1.05
# 210.  Ted            0.96 ± 0.86
# 211.  BreadBall      0.95 ± 0.76
# 212.  trippi         0.95 ± 0.50
# 213.  Big D          0.95 ± 0.84
# 214.  K O            0.94 ± 0.41
# 215.  Iodized Salt   0.94 ± 0.27
# 216.  rebel fox      0.94 ± 0.47
# 217.  Xylene         0.93 ± 0.41
# 218.  snaxolotl      0.93 ± 0.36
# 219.  Chill Will     0.92 ± 0.90
# 220.  Tumblewood     0.92 ± 0.36
# 221.  ALEX JONES     0.91 ± 0.59
# 222.  aardvark       0.91 ± 0.35
# 223.  miata*man      0.91 ± 0.98
# 224.  amadeo         0.91 ± 0.63
# 225.  alchemist      0.91 ± 0.65
# 226.  LogisticMap    0.91 ± 0.34
# 227.  RASCAL         0.90 ± 0.84
# 228.  Gman8181       0.90 ± 0.46
# 229.  lmfao          0.90 ± 0.67
# 230.  J24gordon      0.90 ± 0.80
# 231.  narumii        0.89 ± 0.72
# 232.  Pnaoxt         0.89 ± 0.39
# 233.  MostToxic420   0.89 ± 0.77
# 234.  deku           0.88 ± 0.35
# 235.  Chalksy        0.88 ± 1.03
# 236.  perl           0.88 ± 0.39
# 237.  JSwan          0.88 ± 0.64
# 238.  tragic         0.87 ± 0.60
# 239.  Baby_Shark     0.87 ± 0.46
# 240.  John Brown     0.87 ± 0.74
# 241.  Grommit        0.87 ± 0.45
# 242.  toppy          0.86 ± 0.40
# 243.  poobie         0.85 ± 0.63
# 244.  RAIN           0.85 ± 0.29
# 245.  RacgiMan       0.85 ± 0.90
# 246.  caroline :3    0.84 ± 0.47
# 247.  Balled Eagle   0.84 ± 1.01
# 248.  Dr. Toboggan   0.83 ± 0.34
# 249.  MAGNlTUDE      0.83 ± 0.78
# 250.  iiiiiiiiii     0.82 ± 0.71
# 251.  cudi           0.82 ± 1.04
# 252.  bergieberg     0.82 ± 0.57
# 253.  BLOWFISH       0.81 ± 1.05
# 254.  Enthymeme      0.79 ± 0.60
# 255.  j0sh           0.79 ± 0.34
# 256.  Spheroid.      0.78 ± 0.44
# 257.  goosehonk      0.78 ± 0.91
# 258.  toogood        0.78 ± 0.71
# 259.  Sanik          0.78 ± 0.41
# 260.  FK             0.78 ± 0.46
# 261.  Kenobi         0.77 ± 0.38
# 262.  white          0.77 ± 0.44
# 263.  Batman.        0.75 ± 0.41
# 264.  Gleg           0.75 ± 0.83
# 265.  sun chips      0.74 ± 0.41
# 266.  adawg          0.74 ± 0.68
# 267.  Jukester       0.74 ± 0.51
# 268.  TaylorWhiff    0.74 ± 0.36
# 269.  Gato           0.73 ± 0.84
# 270.  RandyB0Bandy   0.73 ± 0.39
# 271.  Airmigo        0.73 ± 0.34
# 272.  gingerdg       0.72 ± 0.44
# 273.  firehawkv      0.72 ± 0.92
# 274.  xcv            0.72 ± 0.28
# 275.  sss            0.71 ± 0.37
# 276.  CRYCHIC        0.70 ± 0.38
# 277.  Witcher        0.70 ± 0.41
# 278.  knight_        0.69 ± 0.43
# 279.  12384          0.69 ± 0.94
# 280.  Able           0.69 ± 0.68
# 281.  cannibal       0.68 ± 0.65
# 282.  Serenity       0.68 ± 0.80
# 283.  Cel            0.67 ± 0.48
# 284.  Rick O'Shea    0.67 ± 0.78
# 285.  archedrapier   0.67 ± 0.49
# 286.  Flail          0.66 ± 0.97
# 287.  crees          0.65 ± 1.04
# 288.  Anti_Social    0.65 ± 0.42
# 289.  Klox           0.65 ± 0.65
# 290.  o3             0.64 ± 0.68
# 291.  jmu            0.64 ± 0.48
# 292.  Pouya          0.63 ± 1.07
# 293.  Punster        0.62 ± 0.76
# 294.  Dew1234        0.62 ± 0.69
# 295.  Ball-Is-Life   0.62 ± 0.49
# 296.  flopphone      0.62 ± 0.63
# 297.  bequerel       0.61 ± 0.73
# 298.  Fingsb         0.61 ± 0.94
# 299.  pho queue      0.61 ± 0.43
# 300.  ez             0.60 ± 0.29
# 301.  an             0.60 ± 0.76
# 302.  FortuneCooki   0.58 ± 0.46
# 303.  Dabo           0.58 ± 1.04
# 304.  hero-cat       0.58 ± 0.36
# 305.  FirebaII       0.57 ± 1.02
# 306.  Optical Juke   0.57 ± 0.68
# 307.  Feels Like     0.57 ± 0.43
# 308.  clamp          0.56 ± 0.95
# 309.  CatPro         0.56 ± 1.01
# 310.  Diencash       0.56 ± 0.62
# 311.  Gavi           0.56 ± 0.62
# 312.  Ivanchuk       0.56 ± 0.38
# 313.  o o l e r      0.55 ± 0.31
# 314.  snakes         0.55 ± 0.36
# 315.  Roxas          0.55 ± 0.50
# 316.  Old Cob        0.55 ± 0.52
# 317.  Player X       0.54 ± 0.61
# 318.  ankr           0.54 ± 0.93
# 319.  kmichael       0.54 ± 0.26
# 320.  OD GOD         0.54 ± 0.40
# 321.  cowboy         0.54 ± 0.30
# 322.  U Good         0.53 ± 0.46
# 323.  Nevermind      0.53 ± 0.46
# 324.  JARVISLANDRY   0.53 ± 0.43
# 325.  GillyBall      0.53 ± 0.65
# 326.  boogie         0.53 ± 0.50
# 327.  nlfn           0.52 ± 0.60
# 328.  g r e g        0.52 ± 0.69
# 329.  Billy          0.52 ± 0.68
# 330.  isaballa       0.52 ± 0.26
# 331.  Catalyst       0.51 ± 0.98
# 332.  the buttons    0.51 ± 0.25
# 333.  Thermostat     0.50 ± 0.67
# 334.  Moto Moto      0.49 ± 0.55
# 335.  Bluefoot       0.49 ± 0.98
# 336.  Booya Ball     0.49 ± 0.43
# 337.  bubblez        0.48 ± 0.40
# 338.  Gvendolino     0.48 ± 0.42
# 339.  kutrebar       0.48 ± 0.37
# 340.  DibuMartinez   0.47 ± 0.77
# 341.  TheNerve       0.46 ± 0.56
# 342.  Chritt         0.46 ± 0.31
# 343.  Penis Wings    0.46 ± 0.55
# 344.  AtomicStorm    0.45 ± 0.93
# 345.  Nilus          0.45 ± 0.56
# 346.  Bootymine      0.44 ± 0.74
# 347.  SmallyBigs     0.44 ± 0.44
# 348.  Barry Lakin    0.44 ± 0.46
# 349.  Eat Tofu       0.43 ± 0.40
# 350.  perpendcular   0.42 ± 0.61
# 351.  Champagne      0.42 ± 0.34
# 352.  Some Ball 64   0.42 ± 0.72
# 353.  BaullGoodman   0.42 ± 0.79
# 354.  TheBob18       0.42 ± 0.66
# 355.  might dino     0.42 ± 0.47
# 356.  Phiip          0.42 ± 0.74
# 357.  8-)            0.41 ± 0.50
# 358.  BertAndBort    0.41 ± 0.62
# 359.  jerm           0.41 ± 0.45
# 360.  DaBall 07      0.40 ± 0.93
# 361.  KnicksFanTV    0.39 ± 0.49
# 362.  Fap            0.39 ± 0.85
# 363.  garet          0.39 ± 0.46
# 364.  Wilma          0.39 ± 0.46
# 365.  timo_tay       0.38 ± 0.36
# 366.  Green          0.38 ± 0.54
# 367.  KahnMan        0.37 ± 0.31
# 368.  cantstop       0.36 ± 0.39
# 369.  protag         0.36 ± 0.52
# 370.  GtR            0.36 ± 0.45
# 371.  box            0.35 ± 1.00
# 372.  Kemba Walker   0.34 ± 0.73
# 373.  coos :)        0.34 ± 0.63
# 374.  CatPuke        0.34 ± 0.69
# 375.  skibbity       0.34 ± 0.33
# 376.  Sambal 1       0.33 ± 0.34
# 377.  F7             0.33 ± 0.57
# 378.  ballinout      0.32 ± 0.71
# 379.  gghob          0.32 ± 0.99
# 380.  KungFuKenny    0.32 ± 0.78
# 381.  sieh           0.31 ± 0.33
# 382.  McDavid        0.31 ± 0.72
# 383.  penguinharem   0.31 ± 0.69
# 384.  Doku           0.30 ± 0.30
# 385.  Rexer          0.30 ± 0.43
# 386.  Tyler Durden   0.29 ± 0.40
# 387.  KonTiki        0.29 ± 0.70
# 388.  Guaderno       0.29 ± 0.65
# 389.  ROBOPOP_       0.29 ± 0.45
# 390.  AlysBrangwin   0.29 ± 0.80
# 391.  note           0.28 ± 0.61
# 392.  T/\GPRO        0.28 ± 0.42
# 393.  anom           0.28 ± 0.66
# 394.  Vedic D        0.28 ± 0.67
# 395.  1tbsp          0.27 ± 0.67
# 396.  first slime    0.27 ± 0.95
# 397.  welp           0.27 ± 0.77
# 398.  N()()B         0.26 ± 0.34
# 399.  windowlicker   0.26 ± 0.56
# 400.  UNlTY          0.26 ± 0.29
# 401.  doodleball     0.25 ± 0.66
# 402.  AgnusFortis    0.25 ± 0.98
# 403.  Ganbalf        0.25 ± 0.56
# 404.  T.Bomballdil   0.25 ± 0.32
# 405.  rc             0.24 ± 0.65
# 406.  Ball&Oates     0.24 ± 1.01
# 407.  WhiteBallker   0.23 ± 0.90
# 408.  2P1S           0.23 ± 0.51
# 409.  Acuraun        0.23 ± 0.68
# 410.  kink ball      0.23 ± 0.79
# 411.  cw             0.23 ± 0.56
# 412.  VapingPigeon   0.22 ± 0.99
# 413.  Kosmo          0.21 ± 0.48
# 414.  LucilleBall    0.20 ± 0.87
# 415.  ffgr           0.20 ± 0.43
# 416.  swiss          0.20 ± 0.59
# 417.  gl hf :)       0.20 ± 0.43
# 418.  Makhachev      0.19 ± 0.55
# 419.  Oink Oink      0.19 ± 0.58
# 420.  Trans Rights   0.18 ± 1.00
# 421.  RUFUS DU SOL   0.18 ± 0.46
# 422.  Grandiosity    0.18 ± 0.94
# 423.  Jed Bartlet    0.17 ± 0.32
# 424.  Sir Cle Jerk   0.17 ± 0.37
# 425.  GOBLlN         0.17 ± 1.01
# 426.  Snowflaek      0.16 ± 0.54
# 427.  Subglacious    0.16 ± 0.90
# 428.  CappinFalcon   0.16 ± 0.38
# 429.  MrDMoney       0.16 ± 0.34
# 430.  Zig!           0.15 ± 0.52
# 431.  LiddiLidd      0.15 ± 0.61
# 432.  Some Ball 1    0.14 ± 0.75
# 433.  kwib           0.14 ± 0.33
# 434.  razgriz        0.13 ± 0.89
# 435.  Matt           0.13 ± 0.91
# 436.  solongloser    0.12 ± 0.40
# 437.  cantab         0.12 ± 0.51
# 438.  ~zion~         0.12 ± 0.61
# 439.  Waluigi        0.12 ± 0.71
# 440.  NevaPopAgain   0.12 ± 0.92
# 441.  Karasu         0.11 ± 0.39
# 442.  Chucho         0.11 ± 0.56
# 443.  MaxW           0.11 ± 0.78
# 444.  Werth          0.11 ± 0.65
# 445.  Crowman        0.11 ± 0.69
# 446.  sholmes        0.11 ± 0.38
# 447.  For The Win    0.10 ± 0.80
# 448.  Food 4 Thots   0.10 ± 0.59
# 449.  Pingu          0.10 ± 0.84
# 450.  FL             0.09 ± 0.39
# 451.  Ralph Wiggum   0.09 ± 0.51
# 452.  bronny james   0.09 ± 0.39
# 453.  cereballsy     0.08 ± 0.37
# 454.  babyTron       0.07 ± 0.28
# 455.  Bonobo         0.06 ± 0.80
# 456.  Pickle Ball    0.06 ± 0.64
# 457.  SomeKen        0.06 ± 0.88
# 458.  2k             0.05 ± 0.39
# 459.  Atticus        0.05 ± 0.41
# 460.  smoji_         0.05 ± 0.41
# 461.  Gyara          0.05 ± 0.75
# 462.  kika           0.04 ± 0.60
# 463.  ADVICE MAN     0.04 ± 0.69
# 464.  BaII           0.04 ± 0.35
# 465.  long ball      0.03 ± 0.48
# 466.  snackpack      0.03 ± 0.34
# 467.  Wegon Windis   0.02 ± 0.55
# 468.  ThePace        0.01 ± 0.57
# 469.  Korgmonkey     0.01 ± 0.31
# 470.  kyri swirvin   0.00 ± 0.45
# 471.  ocd            0.00 ± 0.56
# 472.  tRiP           0.00 ± 0.92
# 473.  Yo YoYo       -0.01 ± 0.34
# 474.  Jackals       -0.01 ± 0.69
# 475.  JuiceWRLD999  -0.01 ± 0.58
# 476.  Sloppy        -0.01 ± 0.97
# 477.  poodIe        -0.02 ± 0.78
# 478.  Dragon  Ball  -0.02 ± 0.55
# 479.  Roll Player   -0.02 ± 0.77
# 480.  phlasid       -0.02 ± 0.34
# 481.  G.O.A.T.      -0.02 ± 0.40
# 482.  gamja         -0.03 ± 0.88
# 483.  Better Mamba  -0.03 ± 0.37
# 484.  drewfa        -0.03 ± 0.42
# 485.  LethalSquirt  -0.03 ± 0.37
# 486.  pulpo         -0.04 ± 0.49
# 487.  Euler         -0.04 ± 0.80
# 488.  Comakip       -0.04 ± 0.96
# 489.  The Bhutan    -0.04 ± 0.48
# 490.  suicidebypop  -0.05 ± 0.34
# 491.  Therapist     -0.05 ± 0.69
# 492.  beez          -0.05 ± 0.70
# 493.  WRIG          -0.05 ± 0.82
# 494.  Sam-          -0.06 ± 0.43
# 495.  Some Boat 1   -0.06 ± 0.94
# 496.  RAZGRIZ       -0.06 ± 0.60
# 497.  SumtimesGood  -0.06 ± 0.37
# 498.  BalIgod       -0.06 ± 0.98
# 499.  ToucanSam     -0.07 ± 1.00
# 500.  W.E.B DuBall  -0.07 ± 0.96
# 501.  Funky Spud    -0.07 ± 0.52
# 502.  tweedle-dee   -0.08 ± 0.36
# 503.  Some Ball 11  -0.08 ± 0.53
# 504.  imaginary     -0.08 ± 0.57
# 505.  Nawse         -0.09 ± 1.06
# 506.  BoJack        -0.09 ± 0.66
# 507.  benks         -0.09 ± 0.81
# 508.  twelvefive    -0.09 ± 0.42
# 509.  SilentOne     -0.09 ± 0.40
# 510.  some ball 1   -0.09 ± 0.57
# 511.  easily juked  -0.09 ± 0.77
# 512.  BITW          -0.09 ± 0.57
# 513.  El Sacko      -0.09 ± 0.92
# 514.  No one        -0.09 ± 0.43
# 515.  Eballs        -0.09 ± 0.72
# 516.  Hangman       -0.09 ± 0.91
# 517.  TheYoungWolf  -0.10 ± 0.43
# 518.  Hjalpa        -0.10 ± 0.30
# 519.  Singularity   -0.10 ± 0.95
# 520.  Messy         -0.10 ± 0.33
# 521.  EpicJuker     -0.11 ± 0.68
# 522.  Shrimpster    -0.11 ± 0.82
# 523.  Grass1        -0.11 ± 0.67
# 524.  praoprao      -0.11 ± 0.52
# 525.  Pup Daddy     -0.12 ± 0.83
# 526.  Splatacus     -0.12 ± 0.81
# 527.  Dad <|        -0.12 ± 0.51
# 528.  Off Constant  -0.12 ± 0.56
# 529.  dyd           -0.12 ± 0.60
# 530.  AnthonyDavis  -0.13 ± 0.43
# 531.  helprefugees  -0.13 ± 0.32
# 532.  TriP          -0.14 ± 0.59
# 533.  Mystic        -0.14 ± 0.30
# 534.  rai           -0.14 ± 0.33
# 535.  Taddy Mason   -0.14 ± 0.36
# 536.  oldAlt        -0.15 ± 0.36
# 537.  megapoop22    -0.16 ± 0.33
# 538.  Vancouver     -0.16 ± 0.59
# 539.  HammerTime    -0.16 ± 0.40
# 540.  lvy           -0.16 ± 0.55
# 541.  GnomeChomsky  -0.17 ± 0.87
# 542.  Darth         -0.17 ± 0.61
# 543.  cherryrammer  -0.17 ± 0.56
# 544.  TheGovernor   -0.18 ± 0.51
# 545.  JukeOfEarl    -0.18 ± 0.39
# 546.  JGibbs        -0.18 ± 0.78
# 547.  C-3P0         -0.18 ± 0.81
# 548.  @//|@         -0.18 ± 0.98
# 549.  PrettyLights  -0.19 ± 0.53
# 550.  Montoorn      -0.19 ± 1.05
# 551.  blue          -0.19 ± 0.49
# 552.  Osy           -0.19 ± 0.41
# 553.  Pimp          -0.19 ± 0.57
# 554.  Fusion        -0.20 ± 0.81
# 555.  SWAGSTEIN2.0  -0.20 ± 0.64
# 556.  Trip          -0.20 ± 0.82
# 557.  wallsquirrel  -0.20 ± 0.39
# 558.  \m\=^_^=/m/   -0.20 ± 0.74
# 559.  philconnors   -0.20 ± 0.66
# 560.  Ducky         -0.21 ± 0.43
# 561.  Dogmatic      -0.21 ± 0.36
# 562.  kick ankles   -0.21 ± 0.71
# 563.  Oddball       -0.21 ± 0.50
# 564.  Some Ball     -0.22 ± 0.78
# 565.  KALX          -0.22 ± 0.37
# 566.  laserpig      -0.23 ± 0.33
# 567.  my fault      -0.23 ± 0.48
# 568.  CreedBratton  -0.24 ± 0.75
# 569.  TOP CAT       -0.24 ± 0.88
# 570.  Blip          -0.24 ± 0.87
# 571.  GregPopabish  -0.24 ± 0.99
# 572.  Jelly Rat     -0.25 ± 0.51
# 573.  CBad          -0.25 ± 0.29
# 574.  Anvil         -0.26 ± 1.05
# 575.  Wavy~Gravy    -0.26 ± 0.99
# 576.  bennyclub     -0.26 ± 0.76
# 577.  TheProdigy    -0.27 ± 0.99
# 578.  Dante Ball    -0.27 ± 0.94
# 579.  Marijuana     -0.27 ± 0.38
# 580.  #4 Meerkat    -0.27 ± 0.52
# 581.  PenFifteen    -0.28 ± 0.31
# 582.  tbiol         -0.28 ± 0.34
# 583.  Tagger Woods  -0.29 ± 0.44
# 584.  Cupid         -0.29 ± 0.63
# 585.  I_mess_up     -0.29 ± 0.54
# 586.  let me cook   -0.30 ± 0.70
# 587.  Jamyr Gibbs   -0.30 ± 1.00
# 588.  Sgt Ducky     -0.30 ± 0.57
# 589.  skee lo       -0.30 ± 0.51
# 590.  FragrantFowl  -0.31 ± 0.71
# 591.  jl            -0.31 ± 0.76
# 592.  choder        -0.31 ± 0.85
# 593.  Sussy Blocka  -0.31 ± 0.65
# 594.  shirt         -0.31 ± 1.07
# 595.  Jarek         -0.32 ± 0.36
# 596.  marbleous     -0.32 ± 0.95
# 597.  Belacqua      -0.32 ± 0.52
# 598.  CoolHandJuke  -0.32 ± 0.30
# 599.  hihi!         -0.32 ± 0.42
# 600.  Battletoad    -0.32 ± 0.72
# 601.  Beach         -0.33 ± 0.46
# 602.  `AppleKane    -0.33 ± 0.49
# 603.  ninja         -0.33 ± 0.48
# 604.  DuckDuckJuke  -0.33 ± 0.57
# 605.  pontoon boat  -0.33 ± 0.53
# 606.  VerniSanders  -0.33 ± 0.46
# 607.  Cashews       -0.33 ± 0.43
# 608.  yumad2.0      -0.33 ± 0.72
# 609.  baked F       -0.33 ± 0.85
# 610.  Salmond Milk  -0.34 ± 0.86
# 611.  gspoon        -0.34 ± 0.31
# 612.  JukeBerallta  -0.34 ± 0.32
# 613.  drinks?       -0.34 ± 0.39
# 614.  I <3 Emacs    -0.35 ± 0.56
# 615.  SpiritTagger  -0.36 ± 0.46
# 616.  JimBobCooter  -0.36 ± 0.40
# 617.  `ArryKane     -0.36 ± 0.38
# 618.  DF            -0.36 ± 0.37
# 619.  Snekster      -0.37 ± 0.50
# 620.  Zoltan Mesko  -0.37 ± 0.57
# 621.  Monte.        -0.37 ± 0.53
# 622.  Schweddys     -0.37 ± 0.39
# 623.  ZipZop        -0.38 ± 0.46
# 624.  om            -0.38 ± 0.37
# 625.  TigertheLion  -0.38 ± 0.46
# 626.  MickTagger    -0.38 ± 0.83
# 627.  MollyScully   -0.39 ± 0.77
# 628.  smalls        -0.39 ± 0.57
# 629.  NateH         -0.39 ± 0.41
# 630.  EvTheSmev     -0.39 ± 0.46
# 631.  SpeedyOwnt    -0.40 ± 0.67
# 632.  Neph          -0.40 ± 0.69
# 633.  lemonate      -0.40 ± 0.74
# 634.  ballparts     -0.40 ± 0.91
# 635.  Mr. Boop      -0.41 ± 0.93
# 636.  S. Strasball  -0.41 ± 0.47
# 637.  Keyser Soze   -0.41 ± 0.52
# 638.  gc            -0.42 ± 0.90
# 639.  bones         -0.43 ± 0.72
# 640.  DiegoOnMac    -0.43 ± 0.42
# 641.  infinity.     -0.44 ± 1.07
# 642.  /~            -0.44 ± 0.81
# 643.  ><><><><><><  -0.44 ± 0.47
# 644.  SphinctrSlyr  -0.44 ± 0.75
# 645.  gueromoon     -0.44 ± 0.31
# 646.  havok         -0.45 ± 0.39
# 647.  13 volcanos   -0.45 ± 0.94
# 648.  thiery        -0.45 ± 0.90
# 649.  RoughJustice  -0.46 ± 0.90
# 650.  ish           -0.46 ± 0.27
# 651.  urkel         -0.46 ± 0.79
# 652.  Ken Blocks    -0.46 ± 0.84
# 653.  Crumble2      -0.46 ± 0.95
# 654.  CoffeeSnoot   -0.47 ± 0.39
# 655.  Om Vril       -0.47 ± 0.47
# 656.  Homer Jay     -0.47 ± 0.36
# 657.  astor         -0.47 ± 0.97
# 658.  timeboy       -0.48 ± 0.29
# 659.  THESLIGHTEST  -0.48 ± 0.44
# 660.  mrme          -0.48 ± 0.98
# 661.  Palps         -0.48 ± 0.87
# 662.  Larry Fish    -0.49 ± 0.51
# 663.  oatz_mgoatz   -0.49 ± 0.35
# 664.  PBN           -0.49 ± 0.43
# 665.  NUTSNUTSNUTS  -0.50 ± 0.60
# 666.  Secondskin    -0.50 ± 0.96
# 667.  KOB           -0.50 ± 0.92
# 668.  Barbara Bush  -0.50 ± 0.35
# 669.  thierryonre   -0.50 ± 0.70
# 670.  fronk         -0.50 ± 0.61
# 671.  Castrator     -0.50 ± 0.39
# 672.  barrel roll   -0.51 ± 0.79
# 673.  Snot Boogie   -0.51 ± 0.30
# 674.  Vini Jr       -0.51 ± 1.05
# 675.  1 Pixel Juke  -0.52 ± 0.70
# 676.  Fenek         -0.52 ± 0.85
# 677.  JimmyRed      -0.53 ± 0.91
# 678.  sicky         -0.53 ± 0.45
# 679.  Puggins       -0.53 ± 0.56
# 680.  sminitrious   -0.53 ± 0.83
# 681.  profquibb     -0.54 ± 0.87
# 682.  jacenj1       -0.54 ± 0.95
# 683.  ScreamCheese  -0.54 ± 0.45
# 684.  whiff         -0.55 ± 0.31
# 685.  Rayn          -0.55 ± 0.54
# 686.  KoaIa Beast   -0.55 ± 0.37
# 687.  I suck at tp  -0.55 ± 0.58
# 688.  umad          -0.55 ± 0.65
# 689.  Lube          -0.55 ± 0.75
# 690.  wonsu         -0.55 ± 0.39
# 691.  Oscillator    -0.55 ± 0.77
# 692.  RageQuit      -0.56 ± 0.52
# 693.  Quickdraw     -0.56 ± 0.51
# 694.  MDK           -0.57 ± 0.40
# 695.  Phil Ballins  -0.58 ± 0.55
# 696.  Fuck          -0.58 ± 0.72
# 697.  gutenTag      -0.58 ± 0.70
# 698.  Bow Down      -0.59 ± 0.52
# 699.  3.1 Thor      -0.59 ± 0.84
# 700.  taskforce     -0.59 ± 0.78
# 701.  Glimmer       -0.59 ± 0.64
# 702.  WinCtrlShftB  -0.60 ± 0.89
# 703.  Makin Bacon   -0.60 ± 0.51
# 704.  Camel         -0.60 ± 0.75
# 705.  Hurri         -0.61 ± 0.86
# 706.  Headhunter    -0.61 ± 0.71
# 707.  MoGGee        -0.62 ± 0.36
# 708.  Sommeballier  -0.62 ± 0.42
# 709.  Ebhawk        -0.62 ± 0.48
# 710.  B)            -0.62 ± 0.45
# 711.  ANDYKANSAS    -0.63 ± 0.43
# 712.  RUMPSKl       -0.64 ± 0.98
# 713.  Lysdexic      -0.65 ± 0.77
# 714.  portimao      -0.65 ± 0.57
# 715.  Gubbles       -0.65 ± 0.47
# 716.  being         -0.66 ± 0.71
# 717.  SaladRT       -0.66 ± 0.88
# 718.  Black Mamba   -0.67 ± 0.82
# 719.  yioSh         -0.67 ± 0.35
# 720.  State Champ   -0.67 ± 0.42
# 721.  AmishVacuum   -0.67 ± 0.40
# 722.  TheDr34m      -0.67 ± 0.59
# 723.  555555555555  -0.68 ± 0.48
# 724.  Moth-Ball     -0.68 ± 0.56
# 725.  spills        -0.68 ± 0.60
# 726.  TeaForYou&Me  -0.69 ± 0.45
# 727.  greenfish     -0.69 ± 0.73
# 728.  what!?!?      -0.69 ± 1.00
# 729.  Soccertanker  -0.70 ± 0.72
# 730.  hola          -0.70 ± 0.89
# 731.  Double A      -0.70 ± 0.79
# 732.  Khepri        -0.71 ± 0.76
# 733.  Mystery Box   -0.71 ± 0.86
# 734.  Glizzy        -0.71 ± 0.81
# 735.  Mueller       -0.72 ± 0.52
# 736.  Arctic_Tern   -0.72 ± 0.77
# 737.  ATXcloud      -0.72 ± 0.99
# 738.  Poppenheimer  -0.72 ± 0.44
# 739.  nej           -0.73 ± 0.30
# 740.  Quacky        -0.73 ± 0.80
# 741.  Hockeypuck    -0.73 ± 0.40
# 742.  name a fish   -0.73 ± 0.52
# 743.  karthvader    -0.74 ± 1.02
# 744.  fl33t         -0.74 ± 0.34
# 745.  GeeGee        -0.75 ± 0.73
# 746.  Howard        -0.75 ± 0.76
# 747.  Robiny        -0.75 ± 0.46
# 748.  McQueen       -0.77 ± 0.83
# 749.  gregster1     -0.77 ± 1.02
# 750.  Dad Jokes!    -0.77 ± 0.40
# 751.  Ragnar        -0.78 ± 0.42
# 752.  Shit          -0.79 ± 0.54
# 753.  BarryBerkman  -0.79 ± 0.68
# 754.  trash panda   -0.79 ± 0.37
# 755.  JIMBOBCOOTER  -0.79 ± 0.79
# 756.  Garry Lakin   -0.80 ± 0.58
# 757.  Squish        -0.80 ± 0.41
# 758.  Way Maker     -0.80 ± 0.67
# 759.  SomeBall41    -0.80 ± 0.75
# 760.  Yandex        -0.80 ± 0.36
# 761.  ChuckNastii   -0.81 ± 0.84
# 762.  Sinatra       -0.82 ± 0.34
# 763.  rolf          -0.85 ± 0.75
# 764.  Lirath        -0.85 ± 0.61
# 765.  Flat Earth    -0.86 ± 0.36
# 766.  I'mFromKY     -0.86 ± 1.04
# 767.  TheNippIe     -0.87 ± 0.45
# 768.  dryfus        -0.87 ± 0.73
# 769.  N1GHT5TA1KER  -0.87 ± 0.77
# 770.  Locomotive    -0.88 ± 0.45
# 771.  Swully        -0.88 ± 0.31
# 772.  ALLCAP        -0.88 ± 0.96
# 773.  Optimal Taco  -0.89 ± 0.66
# 774.  11th Cmndmnt  -0.89 ± 0.45
# 775.  Duckquack     -0.90 ± 0.74
# 776.  Solo Dolo     -0.90 ± 0.94
# 777.  Inception     -0.90 ± 0.55
# 778.  TERROR NUGS   -0.90 ± 0.62
# 779.  NeYo          -0.91 ± 0.68
# 780.  nutbutt       -0.91 ± 0.79
# 781.  regicide      -0.91 ± 0.75
# 782.  ALCAEUS       -0.92 ± 0.75
# 783.  FlyingV       -0.92 ± 0.34
# 784.  Chungo        -0.92 ± 0.88
# 785.  TheWorst      -0.93 ± 0.39
# 786.  Nutty18       -0.93 ± 0.97
# 787.  MyLittlePony  -0.94 ± 0.30
# 788.  MURF          -0.96 ± 0.35
# 789.  Ace93         -0.96 ± 0.91
# 790.  bash#         -0.97 ± 0.50
# 791.  Rabz          -0.97 ± 0.43
# 792.  buttcheeks    -0.97 ± 1.01
# 793.  Riley_2025    -0.97 ± 0.92
# 794.  Tunabomber    -0.98 ± 0.82
# 795.  Bidet->Wipe   -0.98 ± 0.79
# 796.  BadTrash      -0.98 ± 0.58
# 797.  JUKELELE      -0.99 ± 0.59
# 798.  A Straw Hat   -1.00 ± 0.46
# 799.  Ann with a E  -1.00 ± 0.62
# 800.  PuyoPuyo      -1.02 ± 0.28
# 801.  tomatoo       -1.02 ± 0.92
# 802.  Dayman        -1.02 ± 0.28
# 803.  GetPupsDeep   -1.02 ± 0.58
# 804.  Glass Marble  -1.03 ± 0.83
# 805.  Bambi         -1.04 ± 0.42
# 806.  Sphero Agnew  -1.04 ± 0.40
# 807.  whosagoodboy  -1.04 ± 0.83
# 808.  PotatoPotato  -1.05 ± 0.59
# 809.  RoVo          -1.05 ± 0.58
# 810.  SIGKILL       -1.06 ± 0.74
# 811.  coos          -1.06 ± 0.90
# 812.  Hodor2        -1.06 ± 0.97
# 813.  fah q         -1.06 ± 0.46
# 814.  bryte         -1.06 ± 0.85
# 815.  hail santa    -1.06 ± 0.40
# 816.  MacbookProM4  -1.06 ± 0.63
# 817.  TicklMeElmo   -1.07 ± 0.76
# 818.  MOOOOOOOOOOO  -1.07 ± 0.53
# 819.  icancountto3  -1.07 ± 0.39
# 820.  alan ball     -1.07 ± 1.04
# 821.  pliny         -1.08 ± 0.56
# 822.  ARoseOTGrey   -1.08 ± 0.91
# 823.  ^_^           -1.08 ± 0.72
# 824.  Princess*     -1.09 ± 1.03
# 825.  brx           -1.09 ± 0.68
# 826.  BUTT          -1.10 ± 0.44
# 827.  Sick Fuck     -1.10 ± 0.70
# 828.  slime666      -1.10 ± 0.66
# 829.  Hairy Nuts    -1.10 ± 0.37
# 830.  T_Y           -1.11 ± 0.68
# 831.  Goofy Goober  -1.12 ± 0.47
# 832.  Sminitrious   -1.12 ± 0.66
# 833.  notsosober    -1.12 ± 0.67
# 834.  dadman        -1.12 ± 0.53
# 835.  aeps002       -1.12 ± 0.62
# 836.  Rat King      -1.13 ± 0.84
# 837.  Horizon       -1.13 ± 0.35
# 838.  13.5 inches   -1.13 ± 0.75
# 839.  KnightKnight  -1.14 ± 0.90
# 840.  LilB:BallGod  -1.15 ± 0.47
# 841.  SuperPoopman  -1.16 ± 0.74
# 842.  supergremlin  -1.16 ± 0.48
# 843.  @pro          -1.16 ± 0.51
# 844.  Umpaqua       -1.16 ± 0.94
# 845.  armed walrus  -1.17 ± 0.56
# 846.  Crasher       -1.18 ± 0.42
# 847.  Sawney        -1.18 ± 0.68
# 848.  DMT           -1.18 ± 0.86
# 849.  Photonic S    -1.18 ± 0.67
# 850.  JareksMom     -1.19 ± 0.84
# 851.  OFFENSE OWEN  -1.19 ± 0.90
# 852.  ColtCobra     -1.20 ± 1.02
# 853.  Modric        -1.20 ± 0.55
# 854.  PairOfDice    -1.21 ± 1.04
# 855.  bhawks4life1  -1.21 ± 0.59
# 856.  TestTickle    -1.22 ± 0.96
# 857.  Tiffany       -1.23 ± 0.59
# 858.  Pythagoras    -1.23 ± 0.49
# 859.  Darth JarJar  -1.24 ± 0.64
# 860.  treyk47       -1.25 ± 0.77
# 861.  Ibrahimovic   -1.27 ± 0.88
# 862.  swaglord      -1.27 ± 0.96
# 863.  !__!          -1.27 ± 1.02
# 864.  itagpro       -1.28 ± 0.90
# 865.  Swift         -1.28 ± 0.63
# 866.  Chuggles      -1.29 ± 0.76
# 867.  Ifrit         -1.29 ± 0.99
# 868.  Blaatina      -1.30 ± 0.42
# 869.  openseance    -1.31 ± 0.77
# 870.  Unaballer     -1.31 ± 0.66
# 871.  lowermywin%   -1.32 ± 0.61
# 872.  ShadoWolves   -1.33 ± 0.82
# 873.  EBITDA        -1.34 ± 0.68
# 874.  Hellball2079  -1.34 ± 0.37
# 875.  Exsufflicate  -1.36 ± 0.62
# 876.  JJIIZGOD      -1.36 ± 0.93
# 877.  BasedBall     -1.36 ± 0.80
# 878.  Fatback slim  -1.36 ± 0.38
# 879.  Umph          -1.37 ± 1.01
# 880.  GooeyS7       -1.37 ± 0.53
# 881.  gprimoff      -1.37 ± 0.58
# 882.  metalhead     -1.38 ± 0.32
# 883.  OwMyBalls     -1.39 ± 1.07
# 884.  Dank Blocks   -1.39 ± 0.96
# 885.  dabang khan   -1.39 ± 0.49
# 886.  Valerian      -1.40 ± 0.84
# 887.  SoulSauce     -1.41 ± 0.45
# 888.  Ethan         -1.41 ± 0.95
# 889.  kojiro        -1.41 ± 0.76
# 890.  Jurj          -1.41 ± 0.94
# 891.  Soupy         -1.42 ± 1.04
# 892.  Thorfinn      -1.43 ± 0.47
# 893.  emuwarvet     -1.43 ± 0.63
# 894.  Jessa         -1.44 ± 0.83
# 895.  Daniel        -1.45 ± 0.57
# 896.  DadFane       -1.45 ± 0.60
# 897.  ZippyDoodah   -1.46 ± 1.06
# 898.  drk35         -1.48 ± 0.99
# 899.  Hugo Ball     -1.48 ± 0.68
# 900.  Phenomenal    -1.50 ± 0.60
# 901.  MRCOW         -1.51 ± 0.57
# 902.  Zeke          -1.51 ± 0.58
# 903.  Sway          -1.52 ± 0.53
# 904.  Don Garyoni   -1.52 ± 0.43
# 905.  UmamiThurman  -1.53 ± 0.79
# 906.  Fej           -1.53 ± 1.02
# 907.  nightball     -1.55 ± 0.65
# 908.  Damian        -1.55 ± 0.39
# 909.  glyyyde       -1.55 ± 1.06
# 910.  BOFA          -1.57 ± 0.53
# 911.  Some Ball X   -1.58 ± 0.72
# 912.  Macbuckets    -1.60 ± 0.93
# 913.  SunBall       -1.62 ± 0.95
# 914.  Sweg'         -1.63 ± 0.84
# 915.  Regicide      -1.64 ± 0.35
# 916.  dewgazi       -1.64 ± 0.74
# 917.  Rasta Mon     -1.65 ± 1.03
# 918.  wherdeyatdoe  -1.66 ± 0.58
# 919.  Quaky20       -1.73 ± 0.47
# 920.  fone          -1.73 ± 0.89
# 921.  BertaLovejoy  -1.74 ± 0.66
# 922.  memnite       -1.75 ± 0.72
# 923.  *ball pun*    -1.79 ± 1.01
# 924.  free advice   -1.79 ± 0.40
# 925.  ipopu         -1.80 ± 0.58
# 926.  SeymourButts  -1.80 ± 0.88
# 927.  Gemini        -1.81 ± 0.62
# 928.  I SHOUT       -1.82 ± 0.80
# 929.  TitMouse      -1.83 ± 0.80
# 930.  chaiwala      -1.83 ± 0.76
# 931.  Thanksman     -1.86 ± 0.40
# 932.  Wonk          -1.88 ± 0.94
# 933.  `~`           -1.89 ± 0.42
# 934.  McPenis       -1.93 ± 0.99
# 935.  Pins&Needles  -1.94 ± 0.90
# 936.  eikoflier     -1.95 ± 0.99
# 937.  Color Blind   -1.95 ± 0.45
# 938.  MOTU          -1.95 ± 0.65
# 939.  proera        -1.96 ± 1.06
# 940.  glizzy23      -1.99 ± 0.40
# 941.  SphereTrauma  -2.00 ± 1.02
# 942.  FFFlier       -2.00 ± 0.86
# 943.  Liddi         -2.03 ± 0.73
# 944.  So Cool       -2.05 ± 0.86
# 945.  twirly        -2.05 ± 0.45
# 946.  Notgreat      -2.05 ± 0.88
# 947.  Some Baloney  -2.08 ± 0.82
# 948.  a frog        -2.10 ± 0.69
# 949.  Youareyou     -2.10 ± 0.49
# 950.  Toaster       -2.11 ± 0.83
# 951.  Terry         -2.13 ± 0.65
# 952.  sbxxvi        -2.14 ± 0.71
# 953.  rizzmaster    -2.14 ± 0.57
# 954.  sinagot       -2.16 ± 0.48
# 955.  Israel Lives  -2.19 ± 0.55
# 956.  phyllis       -2.20 ± 0.42
# 957.  RoyaltyKeyz   -2.33 ± 1.00
# 958.  Rascasse      -2.34 ± 0.70
# 959.  terrrrriball  -2.35 ± 0.56
# 960.  Avsy26        -2.39 ± 0.63
# 961.  Orinoco Flow  -2.40 ± 0.64
# 962.  Marblmadness  -2.43 ± 0.43
# 963.  Doc           -2.43 ± 0.80
# 964.  Celery        -2.45 ± 1.07
# 965.  MrBeaver      -2.46 ± 0.82
# 966.  TrustJesus69  -2.47 ± 0.53
# 967.  Sodyn33       -2.47 ± 0.67
# 968.  I AM          -2.51 ± 1.03
# 969.  JukeofFrance  -2.52 ± 0.75
# 970.  RodandoAndo   -2.57 ± 0.79
# 971.  stall2hammer  -2.58 ± 0.34
# 972.  rollingstone  -2.63 ± 0.66
# 973.  OlliePoppi    -2.64 ± 0.73
# 974.  Skip          -2.66 ± 0.85
# 975.  erl           -2.66 ± 1.02
# 976.  AVP           -2.68 ± 0.43
# 977.  I'mBoutDat    -2.75 ± 0.46
# 978.  TheBadBall    -2.76 ± 1.01
# 979.  8ananaman     -2.84 ± 1.06
# 980.  Rizz          -2.85 ± 0.77
# 981.  chgtus        -2.87 ± 0.50
# 982.  Argo4444      -2.94 ± 0.85
# 983.  Relax         -2.95 ± 0.84
# 984.  tutorial_wiz  -3.09 ± 0.68
# 985.  G lander!     -3.10 ± 0.91
# 986.  whateveritis  -3.11 ± 0.98
# 987.  BobTheBob     -3.14 ± 0.74
# 988.  uglander      -3.25 ± 0.99
# 989.  Dxebec        -3.28 ± 0.77
# 990.  sawfds        -3.28 ± 1.07

# %%
for m in matches:
    for p in m['players']:
        p['updates']['final_elo'] = players[p['name']].elo
        p['updates']['final_var'] = players[p['name']].variance
    red_elo = sum(players[p['name']].elo for p in m['players'][:4])
    blue_elo = sum(players[p['name']].elo for p in m['players'][4:])
    retro_pred = red_elo - blue_elo + RED_ADVANTAGE[
        match['map_name'] if match['map_name'] in RED_ADVANTAGE else 'default'
    ]
    retro_var = BASE_VARIANCE + sum(players[p['name']].variance for p in m['players'])
    retro_wp = 1 / (1 + CAP_TO_WP_EXPONENT ** -retro_pred)
    m['retro_red_elo'] = red_elo
    m['retro_blue_elo'] = blue_elo
    m['retro_pred'] = retro_pred
    m['retro_residual'] = m['cap_diff'] - m['retro_pred']
    m['retro_sd'] = retro_var ** 0.5
    m['retro_wp'] = retro_wp
    m['retro_wwp'] = retro_wp if m['cap_diff'] > 0 else 1 - retro_wp

print(f"MAE: {sum([abs(m['retro_residual']) for m in matches]) / len(matches):.4f}    RMS: {(sum([m['retro_residual'] ** 2 for m in matches]) / len(matches)) ** 0.5:.4f}")
print(f"COR: {sum([(1 if m['retro_wwp'] > 0.5 else 0.5 if m['retro_wwp'] == 0.5 else 0) for m in matches]) / len(matches):.2%}    WWP: {sum(m['retro_wwp'] for m in matches) / len(matches):.2%}")
print(f"BRI: {1 - (sum([(1 - m['retro_wwp']) ** 2 for m in matches]) / len(matches)) ** 0.5:.2%}    LOG: {2 ** (sum([math.log2(m['retro_wwp']) for m in matches]) / len(matches)):.2%}")
# Out:
# MAE: 2.3568    RMS: 2.8640
# COR: 62.08%    WWP: 54.76%
# BRI: 52.39%    LOG: 52.55%

# %% [markdown]
# ### Forensics

# %%
def player_stat_averages(player_name):
    total_caps = 0
    total_returns = 0
    total_hold = 0
    total_prevent = 0
    player_pups = 0
    total_games = 0
    pups_spawned = 0
    for m in matches:
        player_in_game = False
        pups_in_game = 0
        for p in m['players']:
            pups_in_game += p['stats']['pups']
            if p['name'] == player_name:
                player_in_game = True
                player_pups += p['stats']['pups']
                total_caps += p['stats']['caps']
                total_returns += p['stats']['returns']
                total_hold += p['stats']['hold']
                total_prevent += p['stats']['prevent']
                total_games += 1
        if player_in_game:
            pups_spawned += pups_in_game
    if pups_spawned == 0:
        return {
            'cpg': 0,
            'hpg': 0,
            'rpg': 0,
            'ppg': 0,
            'pup%': 0,
        }
    return {
        'cpg': total_caps / total_games,
        'hpg': total_hold / total_games / 60,
        'rpg': total_returns / total_games,
        'ppg': total_prevent / total_games / 60,
        'pup%': player_pups / pups_spawned,
    }

# %%
s0_only_leaderboard = sorted([
    p for p in players.values()
    if p.variance <= MAX_VARIANCE_TO_COUNT_AS_KNOWN and
    p.elo > 1 and
    all(m['match_id'] < 4148840 for m in matches if any(pl['name'] == p.name for pl in m['players']))
], key=lambda p: p.elo, reverse=True)

# %%
for i, p in enumerate(s0_only_leaderboard):
    player_stats = player_stat_averages(p.name)
    print(f"{i + 1:>3}.  {p.name:<12}  {p.elo:5.2f} ± {1.96 * p.variance ** 0.5:.2f}  {player_stats['cpg']:>4.2f} cpg  {player_stats['rpg']:>4.1f} rpg  {player_stats['hpg']:>3.0f} hpg  {player_stats['ppg']:>3.0f} ppg  {player_stats['pup%']:>5.1%} pup%")
# Out:
#   1.  Junoon         3.21 ± 0.34  1.11 cpg  10.8 rpg   73 hpg   51 ppg  17.2% pup%
#   2.  okthen         3.16 ± 0.51  1.23 cpg   8.9 rpg   79 hpg   44 ppg  15.0% pup%
#   3.  Xx360NoSwagx   2.78 ± 0.59  0.88 cpg  12.8 rpg   47 hpg   84 ppg  16.3% pup%
#   4.  Jester101      2.63 ± 0.89  1.64 cpg  10.2 rpg   98 hpg   19 ppg  16.7% pup%
#   5.  bright         2.58 ± 0.48  1.07 cpg   9.2 rpg   74 hpg   45 ppg  20.8% pup%
#   6.  bitter heart   2.47 ± 0.75  0.71 cpg  13.9 rpg   45 hpg   85 ppg  15.0% pup%
#   7.  Ritual         2.41 ± 0.48  0.92 cpg  10.9 rpg   59 hpg   70 ppg  14.2% pup%
#   8.  frieren        2.37 ± 0.75  1.09 cpg  10.8 rpg   66 hpg   52 ppg  17.9% pup%
#   9.  Galvatron      2.35 ± 0.78  0.83 cpg  13.6 rpg   44 hpg   92 ppg   4.0% pup%
#  10.  Madoka         2.31 ± 0.66  0.85 cpg  10.6 rpg   60 hpg   58 ppg  16.9% pup%
#  11.  HelloI'mGurt   2.20 ± 0.89  0.55 cpg  17.3 rpg   43 hpg   84 ppg  22.5% pup%
#  12.  1deag          2.18 ± 0.44  0.82 cpg  10.7 rpg   52 hpg   62 ppg  19.9% pup%
#  13.  Doris          2.07 ± 0.50  0.97 cpg   9.6 rpg   65 hpg   58 ppg  15.2% pup%
#  14.  Sugar          2.04 ± 0.64  1.09 cpg   9.7 rpg   78 hpg   55 ppg  16.3% pup%
#  15.  i love HD      2.01 ± 0.80  0.70 cpg  13.9 rpg   32 hpg   72 ppg  20.9% pup%
#  16.  swerve         2.01 ± 0.88  1.50 cpg   8.1 rpg   86 hpg   27 ppg  17.2% pup%
#  17.  Ball-E         2.01 ± 0.66  1.25 cpg   8.0 rpg   79 hpg   43 ppg  10.8% pup%
#  18.  eee            1.97 ± 0.50  1.04 cpg   8.3 rpg   80 hpg   34 ppg  13.9% pup%
#  19.  tits           1.95 ± 0.59  1.21 cpg  11.2 rpg   71 hpg   63 ppg  16.2% pup%
#  20.  SakuUta        1.79 ± 0.47  0.76 cpg  10.4 rpg   61 hpg   62 ppg  11.8% pup%
#  21.  tears          1.77 ± 0.44  1.25 cpg   8.8 rpg   85 hpg   42 ppg  15.2% pup%
#  22.  vanitas        1.76 ± 0.86  1.43 cpg   8.6 rpg  105 hpg   13 ppg  11.6% pup%
#  23.  NEUhusky       1.75 ± 0.80  1.31 cpg   9.7 rpg   68 hpg   55 ppg  14.7% pup%
#  24.  Homie          1.73 ± 0.45  1.14 cpg   8.0 rpg   86 hpg   43 ppg  13.7% pup%
#  25.  kelvin         1.73 ± 0.96  0.74 cpg  13.3 rpg   35 hpg   98 ppg  13.4% pup%
#  26.  ||||||||||||   1.60 ± 0.73  1.40 cpg   7.9 rpg   94 hpg   13 ppg  10.2% pup%
#  27.  keithstoned1   1.56 ± 0.84  0.80 cpg  10.7 rpg   68 hpg   67 ppg  13.5% pup%
#  28.  yep            1.49 ± 0.50  1.01 cpg  11.3 rpg   63 hpg   61 ppg  17.4% pup%
#  29.  SoulCake       1.48 ± 0.67  0.83 cpg   9.8 rpg   53 hpg   69 ppg  11.5% pup%
#  30.  Jinjo          1.48 ± 0.74  1.22 cpg   8.5 rpg   76 hpg   43 ppg  10.1% pup%
#  31.  Bomberguy      1.46 ± 1.02  0.68 cpg  12.3 rpg   50 hpg   77 ppg  12.0% pup%
#  32.  Stronk         1.44 ± 0.66  0.64 cpg  10.5 rpg   45 hpg   81 ppg  14.4% pup%
#  33.  DudeMcGuy      1.44 ± 0.78  0.73 cpg   9.8 rpg   51 hpg   70 ppg  12.3% pup%
#  34.  Boat           1.42 ± 0.71  1.06 cpg   9.6 rpg   72 hpg   53 ppg  12.1% pup%
#  35.  Niplepotamus   1.40 ± 0.73  0.76 cpg   9.1 rpg   56 hpg   65 ppg  16.3% pup%
#  36.  meaL           1.40 ± 1.06  0.87 cpg  10.2 rpg   70 hpg   51 ppg  17.9% pup%
#  37.  tune           1.40 ± 0.65  1.31 cpg   8.1 rpg   92 hpg   17 ppg  11.1% pup%
#  38.  TheG           1.39 ± 0.38  0.85 cpg  10.0 rpg   66 hpg   58 ppg   7.3% pup%
#  39.  kasli          1.39 ± 0.68  0.64 cpg  10.4 rpg   48 hpg   75 ppg  19.4% pup%
#  40.  Frank          1.39 ± 0.81  0.98 cpg   9.5 rpg   69 hpg   67 ppg  11.9% pup%
#  41.  Jer32          1.38 ± 0.65  0.99 cpg   7.7 rpg   71 hpg   48 ppg  15.9% pup%
#  42.  St. Bernard    1.36 ± 0.65  0.56 cpg  13.0 rpg   64 hpg   72 ppg  18.4% pup%
#  43.  Sphear         1.36 ± 0.88  0.67 cpg  11.9 rpg   55 hpg   73 ppg  11.2% pup%
#  44.  Irony          1.36 ± 0.39  0.95 cpg   8.9 rpg   67 hpg   57 ppg  14.5% pup%
#  45.  DingusDongus   1.35 ± 0.73  0.80 cpg   8.7 rpg   59 hpg   51 ppg  15.2% pup%
#  46.  Light          1.35 ± 0.39  0.99 cpg   7.7 rpg   73 hpg   31 ppg  11.9% pup%
#  47.  Ball of Fame   1.33 ± 0.85  0.45 cpg  11.7 rpg   39 hpg   87 ppg  10.4% pup%
#  48.  StaIin         1.32 ± 0.52  0.63 cpg  10.6 rpg   54 hpg   64 ppg   7.8% pup%
#  49.  Gamepad God    1.30 ± 0.57  1.03 cpg   9.7 rpg   77 hpg   42 ppg  12.8% pup%
#  50.  Shaolin        1.29 ± 0.70  1.07 cpg  10.6 rpg   64 hpg   60 ppg   8.7% pup%
#  51.  Mos Def        1.28 ± 0.43  0.66 cpg  12.0 rpg   47 hpg   81 ppg  10.0% pup%
#  52.  snuffed        1.28 ± 0.76  0.61 cpg  13.4 rpg   41 hpg  111 ppg  13.3% pup%
#  53.  JBaay          1.26 ± 0.76  1.15 cpg   9.0 rpg   71 hpg   25 ppg  18.2% pup%
#  54.  clew3          1.24 ± 0.78  0.48 cpg  11.1 rpg   39 hpg   86 ppg  17.5% pup%
#  55.  a virgin dad   1.24 ± 1.00  1.23 cpg   7.5 rpg   74 hpg   31 ppg  16.2% pup%
#  56.  Kei Yonagi     1.23 ± 0.60  1.00 cpg   7.1 rpg   73 hpg   28 ppg  12.2% pup%
#  57.  DEAD NAN       1.22 ± 0.62  1.17 cpg   7.9 rpg   89 hpg   43 ppg  16.2% pup%
#  58.  MarkBallis     1.22 ± 0.71  1.21 cpg   8.4 rpg   62 hpg   45 ppg  13.0% pup%
#  59.  not lazy       1.20 ± 1.03  1.46 cpg   7.8 rpg   80 hpg   30 ppg  16.8% pup%
#  60.  rake           1.20 ± 0.79  0.87 cpg  10.7 rpg   56 hpg   70 ppg  12.7% pup%
#  61.  Snowball       1.19 ± 0.53  0.72 cpg  11.6 rpg   46 hpg   80 ppg  11.9% pup%
#  62.  George         1.15 ± 0.75  0.95 cpg   7.5 rpg   68 hpg   29 ppg  14.8% pup%
#  63.  Ballzilla      1.14 ± 0.71  0.82 cpg   9.7 rpg   57 hpg   58 ppg  12.0% pup%
#  64.  Jason Bourne   1.12 ± 0.86  1.15 cpg   8.8 rpg  103 hpg   28 ppg  16.9% pup%
#  65.  arksoldier     1.08 ± 0.77  1.15 cpg   7.8 rpg   73 hpg   30 ppg  13.5% pup%
#  66.  Kamikaze       1.07 ± 0.55  1.08 cpg   9.8 rpg   82 hpg   36 ppg  13.9% pup%
#  67.  yippie         1.07 ± 0.81  1.25 cpg   7.9 rpg   85 hpg   29 ppg  10.0% pup%
#  68.  Jump Ball      1.05 ± 0.97  0.50 cpg  10.5 rpg   41 hpg   67 ppg  13.0% pup%
#  69.  bleast         1.01 ± 0.90  1.49 cpg   6.7 rpg   85 hpg   25 ppg  12.2% pup%
#  70.  bumballbee     1.01 ± 0.84  1.18 cpg   8.1 rpg   81 hpg   35 ppg  17.2% pup%

# %%
s1_only_leaderboard = sorted([
    p for p in players.values()
    if p.variance <= MAX_VARIANCE_TO_COUNT_AS_KNOWN and
    p.elo > 0.5 and
    all(m['match_id'] >= 4148840 for m in matches if any(pl['name'] == p.name for pl in m['players']))
], key=lambda p: p.elo, reverse=True)

# %%
for i, p in enumerate(s1_only_leaderboard):
    player_stats = player_stat_averages(p.name)
    print(f"{i + 1:>3}.  {p.name:<12}  {p.elo:5.2f} ± {1.96 * p.variance ** 0.5:.2f}  {player_stats['cpg']:>4.2f} cpg  {player_stats['rpg']:>4.1f} rpg  {player_stats['hpg']:>3.0f} hpg  {player_stats['ppg']:>3.0f} ppg  {player_stats['pup%']:>5.1%} pup%")
# Out:
#   1.  Thrust         2.11 ± 0.85  1.11 cpg  11.4 rpg   69 hpg   56 ppg  16.1% pup%
#   2.  Cape           2.09 ± 0.74  1.15 cpg  11.7 rpg   73 hpg   50 ppg  19.7% pup%
#   3.  known          1.84 ± 0.40  1.07 cpg  10.6 rpg   70 hpg   66 ppg  14.5% pup%
#   4.  churt chimi    1.65 ± 0.63  1.22 cpg   9.6 rpg   99 hpg   36 ppg  15.6% pup%
#   5.  autumn heart   1.45 ± 0.89  1.12 cpg   9.1 rpg   89 hpg   47 ppg  20.8% pup%
#   6.  Niya           1.45 ± 0.93  0.71 cpg  10.2 rpg   52 hpg   67 ppg  16.9% pup%
#   7.  blah-zay       1.42 ± 0.55  1.02 cpg   9.0 rpg   74 hpg   35 ppg  13.4% pup%
#   8.  Reze20         1.41 ± 0.61  0.89 cpg   9.1 rpg   57 hpg   78 ppg  14.5% pup%
#   9.  wasserstein    1.35 ± 0.62  1.21 cpg   9.0 rpg   66 hpg   51 ppg  12.4% pup%
#  10.  magicmuffin8   1.26 ± 0.47  1.11 cpg   8.0 rpg   81 hpg   30 ppg  15.8% pup%
#  11.  Nas            1.26 ± 0.53  0.59 cpg  11.4 rpg   49 hpg   76 ppg   8.8% pup%
#  12.  goji           1.05 ± 0.56  0.55 cpg  11.6 rpg   53 hpg   68 ppg  13.7% pup%
#  13.  Xylene         0.93 ± 0.41  0.97 cpg   9.7 rpg   56 hpg   56 ppg  15.1% pup%
#  14.  amadeo         0.91 ± 0.63  0.78 cpg  10.0 rpg   59 hpg   55 ppg  14.5% pup%
#  15.  narumii        0.89 ± 0.72  1.58 cpg   6.5 rpg  107 hpg   16 ppg  10.7% pup%
#  16.  Kenobi         0.77 ± 0.38  0.70 cpg   9.0 rpg   66 hpg   76 ppg  16.9% pup%
#  17.  sss            0.71 ± 0.37  0.87 cpg   8.0 rpg   70 hpg   31 ppg  14.3% pup%
#  18.  bequerel       0.61 ± 0.73  0.44 cpg  12.3 rpg   43 hpg   67 ppg  12.3% pup%
#  19.  pho queue      0.61 ± 0.43  0.93 cpg   6.5 rpg   70 hpg   32 ppg  11.9% pup%
#  20.  FirebaII       0.57 ± 1.02  1.09 cpg   7.2 rpg  120 hpg   22 ppg  22.7% pup%

# %% [markdown]
# ### Records

# %%
def pretty_print_match(m, player=None):
    player_names = sorted([p['name'] for p in m['players'][:4]], key=lambda p: players[p].elo, reverse=True) + sorted([p['name'] for p in m['players'][4:]], key=lambda p: players[p].elo, reverse=True)
    player_caps = [p['stats']['caps'] for p in m['players']]
    minutes = int(m['duration'] / 3600)
    seconds = int(m['duration'] / 60) - 60 * minutes
    result = f"""Match {m['match_id']}: {', '.join(player_names[:4])} vs. {', '.join(player_names[4:])}
Expected: {m['retro_pred']:+.1f} ({m['retro_wp']:.0%}). Actual: {sum(player_caps[:4])}-{sum(player_caps[4:])} in {minutes}:{seconds:02}."""
    for p in m['players']:
        if p['name'] == player:
            result += f" Update: {p['updates']['elo_update']:+.2f}."
    return result + f" Map: {m['map_name']}\n"

def unfairness(m):
    return abs(m['retro_pred'])

def carry_required(m):
    return max(
        m['retro_blue_elo'] - m['retro_red_elo'] + max(players[p['name']].elo for p in m['players'][:4]),
        m['retro_red_elo'] - m['retro_blue_elo'] + max(players[p['name']].elo for p in m['players'][4:]),
    )

def matches_with_player(name):
    return [m for m in matches if name in [p['name'] for p in m['players']]]

# Biggest carries
for m in sorted([m for m in matches if m['retro_wwp'] < 0.5], key=unfairness, reverse=True)[:10]:
    print(pretty_print_match(m))
# Out:
# Match 4128373: `ArryKane, nej, Toaster, sinagot vs. Alisa, kika, S. Strasball, DiegoOnMac
# Expected: -5.6 (5%). Actual: 4-3 in 8:03. Map: Basenji
#
# Match 4151893: ?, Curry, fl33t, Robiny vs. o o l e r, KahnMan, DiegoOnMac, chgtus
# Expected: +5.1 (94%). Actual: 1-6 in 3:21. Map: Basenji
#
# Match 4052597: Junoon, State Champ, TheNippIe, Marblmadness vs. PuyoPuyo, Crasher, Hooblagoo, `~`
# Expected: +5.0 (93%). Actual: 3-4 in 8:00. Map: Combine
#
# Match 3941266: phreak, 1deag, NameLEss, Messy vs. helen keller, tnevlos, Keyser Soze, MoGGee
# Expected: +4.8 (93%). Actual: 3-5 in 8:00. Map: Combine
#
# Match 3934918: meowza, grumpy, Borgus, Euler vs. KING KRULE, Vancouver, TheGovernor, hihi!
# Expected: +4.8 (93%). Actual: 1-2 in 8:00. Map: Oak
#
# Match 3943911: Vorhees, Toidi, JSwan, Valerian vs. Messy, HammerTime, DuckDuckJuke, spills
# Expected: +4.6 (92%). Actual: 2-3 in 8:10. Map: Moon Base 2024
#
# Match 3935900: Anti_Social, Chucho, Jarek, Bambi vs. Sugar, KING KRULE, Old Cob, helprefugees
# Expected: -4.6 (8%). Actual: 8-3 in 7:30. Map: Asida
#
# Match 3981927: BUTT, Wonk, Terry, EyeInTheSky vs. Messy, BadTrash, supergremlin, Kohnago
# Expected: -4.4 (9%). Actual: 4-3 in 9:34. Map: Centenaria
#
# Match 3939705: meowza, grumpy, Jukester, bubblez vs. Magnolia, CRYCHIC, Anti_Social, Goofy Goober
# Expected: +4.4 (91%). Actual: 2-4 in 8:00. Map: Moon Base 2024
#
# Match 4159522: AdmaniaYT, Doku, Mystic, Sinatra vs. LethalSquirt, `AppleKane, Squish, sbxxvi
# Expected: +4.4 (91%). Actual: 1-2 in 8:01. Map: Asida

# %%
player_recent_matches = matches_with_player("Tumblewood")
player_recent_matches.reverse()
for m in player_recent_matches[:10]:
    print(pretty_print_match(m, player="Tumblewood"))
# Out:
# Match 4170531: flaccid trip, Magnolia, Tumblewood, timeboy vs. Wanye, perl, Doku, blue
# Expected: +1.6 (70%). Actual: 7-2 in 7:04. Update: +0.02. Map: Asida
#
# Match 4170527: 2Nutz, Magnolia, blue, timeboy vs. flaccid trip, Tumblewood, perl, Doku
# Expected: -1.4 (33%). Actual: 0-5 in 2:20. Update: +0.03. Map: Asida
#
# Match 4170516: 2Nutz, Toidi, Doku, Bonobo vs. Vader, Wraith, Tumblewood, isaballa
# Expected: -1.1 (36%). Actual: 1-6 in 6:14. Update: +0.03. Map: Moon Base 2024
#
# Match 4170510: Vader, Tumblewood, isaballa, Bonobo vs. Wraith, Toidi, Doku, B)
# Expected: +1.7 (71%). Actual: 1-2 in 8:08. Update: -0.01. Map: Crawfish Boil
#
# Match 4170502: Toidi, Tumblewood, isaballa, Bonobo vs. Wraith, Doku, Dad <|, B)
# Expected: +1.9 (73%). Actual: 6-1 in 6:23. Update: +0.02. Map: Moon Base 2024
#
# Match 4170490: BallsToYou., boogie, isaballa, Doku vs. jazzz, Tumblewood, Bonobo, Some Boat 1
# Expected: +0.6 (58%). Actual: 1-3 in 8:00. Update: +0.01. Map: Milano 2
#
# Match 4170473: ASAP, jazzz, Wraith, Tumblewood vs. flaccid trip, NameLEss, pho queue, isaballa
# Expected: +1.4 (68%). Actual: 1-3 in 8:00. Update: -0.01. Map: Sardonica
#
# Match 4170465: Quercus, pho queue, isaballa, Sinatra vs. jazzz, Tumblewood, boogie, Chuggles
# Expected: -0.9 (38%). Actual: 0-5 in 5:36. Update: +0.03. Map: Sardonica
#
# Match 4170250: Wraith, jkxs, LethalSquirt, nej vs. Spjork, Prime, Tumblewood, Dad <|
# Expected: -1.8 (28%). Actual: 1-6 in 3:09. Update: +0.03. Map: Basenji
#
# Match 4170237: DT, jkxs, Tumblewood, gueromoon vs. mex, Wraith, Adamn, Xylene
# Expected: -0.7 (40%). Actual: 3-6 in 8:00. Update: -0.01. Map: Combine

# %% [markdown]
# ### Analysis

# %%
def player_results_by_map(player):
    map_results = {}
    baseline = [0, 0]
    for m in matches_with_player(player):
        player_names = [p['name'] for p in m['players']]
        map_name = m['map_name']
        if map_name not in map_results:
            map_results[map_name] = [0, 0]
        map_results[map_name][0] += 1
        map_results[map_name][1] += m['retro_residual'] if player in player_names[:4] else -m['retro_residual']
        baseline[0] += 1
        baseline[1] += m['retro_residual'] if player in player_names[:4] else -m['retro_residual']
    for map_name, [gp, avg_resid] in sorted(map_results.items(), key=lambda x: x[1][0], reverse=True):
        print(f"{map_name:>28}: {avg_resid / gp - baseline[1] / baseline[0]:+.2f} ({gp:>2} games)")

player_results_by_map("Tumblewood")
# Out:
#           A Flaccid Type Map: +0.50 (59 games)
#                   Audacity 2: -0.46 (52 games)
#                        Asida: -0.17 (46 games)
#                     Milano 2: +0.09 (39 games)
#               Moon Base 2024: -0.19 (38 games)
#                   Centenaria: +0.17 (37 games)
#                      Combine: -0.83 (27 games)
#                    Sardonica: +0.50 (26 games)
#                   OTI Jardim: -0.69 (26 games)
#                     Willow 2: +0.36 (24 games)
#                   OTI MERALD: -0.41 (19 games)
#                          Oak: -0.09 (19 games)
#                    Thicket 2: -0.55 (18 games)
#              Sugar Free Hill: +0.77 ( 9 games)
#               Transilio 2024: -1.72 ( 8 games)
#                     Catch-24: +0.51 ( 7 games)
#              Apparition 2023: +0.14 ( 7 games)
#                      Pilot 3: +0.52 ( 7 games)
#                      Basenji: +1.55 ( 7 games)
#                          GFY: +0.96 ( 6 games)
#                         Nuke: -1.72 ( 6 games)
#                        PRush: +1.97 ( 6 games)
#                        Haste: -1.29 ( 5 games)
#                Crawfish Boil: +0.42 ( 5 games)
#                    Pukebox 2: +0.49 ( 4 games)
#                         Pine: +1.36 ( 3 games)
#                    Pretzel 2: +1.06 ( 3 games)
#  Waterbed [MM23 West Winner]: +0.52 ( 3 games)
#                Professor Oak: +0.55 ( 2 games)
#              Tetanic 3.1 4x4: +5.69 ( 1 games)
#                        Flume: +4.85 ( 1 games)

# %%
for i in range(0, 16):
    i *= 0.4
    total = [m for m in matches if i < abs(m['retro_pred']) < i + 0.4]
    wins = [m for m in total if m['retro_wwp'] > 0.5]
    print(f"{i:.1f}-{i + 0.4:.1f}: "
          f"{len(wins):>5} / "
          f"{len(total):>5} "
          f"({len(wins) / len(total):.1%})"
          f"  {1 / (1 + 1.7 ** -(i + 0.2)):.1%}")
# Out:
# 0.0-0.4:  6277 / 11932 (52.6%)  52.7%
# 0.4-0.8:  5953 / 10423 (57.1%)  57.9%
# 0.8-1.2:  5013 /  8139 (61.6%)  63.0%
# 1.2-1.6:  3935 /  5927 (66.4%)  67.8%
# 1.6-2.0:  2724 /  3954 (68.9%)  72.2%
# 2.0-2.4:  1813 /  2410 (75.2%)  76.3%
# 2.4-2.8:  1168 /  1497 (78.0%)  79.9%
# 2.8-3.2:   744 /   930 (80.0%)  83.1%
# 3.2-3.6:   449 /   528 (85.0%)  85.9%
# 3.6-4.0:   312 /   347 (89.9%)  88.3%
# 4.0-4.4:   213 /   239 (89.1%)  90.3%
# 4.4-4.8:   136 /   149 (91.3%)  92.0%
# 4.8-5.2:   100 /   104 (96.2%)  93.4%
# 5.2-5.6:    55 /    58 (94.8%)  94.6%
# 5.6-6.0:    43 /    44 (97.7%)  95.6%
# 6.0-6.4:    25 /    25 (100.0%)  96.4%

# %%
maps = {}
for m in matches:
    if m['map_name'] not in maps:
        maps[m['map_name']] = [0, 0, 0, 0, 0, 0]
    maps[m['map_name']][0] += 1
    maps[m['map_name']][3] += m['retro_residual']
    maps[m['map_name']][1] += math.log2(0.5 + abs(m['retro_wp'] - 0.5))
    maps[m['map_name']][2] += math.log2(m['retro_wwp'])
    maps[m['map_name']][4] += abs(m['retro_residual'])
    maps[m['map_name']][5] += m['retro_residual'] ** 2
for m in maps.values():
    if m[0] == 0:
        continue
    m[1] /= m[0]
    m[2] /= m[0]
    m[3] /= m[0]
    m[4] /= m[0]
    m[5] /= m[0]

for m, p in sorted(maps.items(), key=lambda x: x[1][0], reverse=True):
    print(f"{m:>27}  {p[0]:>4}  {2 ** p[1]:.1%}  {2 ** p[2]:.1%}  {p[3] + RED_ADVANTAGE[m if m in RED_ADVANTAGE else 'default']:+.2f}  {p[4]:.2f}  {p[5]:.2f}")
# Out:
#          A Flaccid Type Map  5416  61.3%  52.0%  -0.20  2.27  7.75
#                  Audacity 2  4885  62.5%  52.5%  +0.22  2.27  7.80
#                       Asida  4515  63.0%  52.8%  +0.18  2.55  9.43
#              Moon Base 2024  4213  62.5%  52.6%  +0.23  2.39  8.39
#                  Centenaria  3523  62.5%  52.8%  -0.17  2.41  8.58
#                    Milano 2  3472  62.2%  52.3%  +0.27  2.43  8.76
#                     Combine  3283  62.8%  52.8%  -0.17  2.39  8.33
#                   Sardonica  2427  61.8%  52.1%  -0.22  2.53  9.25
#                  OTI MERALD  1872  63.3%  53.3%  -0.20  2.36  8.33
#                   Thicket 2  1787  61.6%  51.8%  -0.08  2.30  7.83
#                  OTI Jardim  1747  61.7%  52.6%  +0.15  2.44  8.65
#                         Oak  1727  63.1%  53.0%  -0.01  2.19  7.32
#                    Willow 2  1604  62.4%  51.8%  -0.21  2.34  8.07
#             Sugar Free Hill  1002  61.5%  51.8%  -0.40  2.27  7.77
#                     Pilot 3   947  61.5%  51.8%  +0.04  2.17  7.02
#             Apparition 2023   912  60.9%  51.6%  -0.04  2.26  7.55
#              Transilio 2024   798  61.1%  53.0%  +0.12  2.19  7.33
#                     Basenji   474  61.9%  53.3%  +0.17  2.31  8.11
#                        Nuke   340  62.3%  52.2%  +0.02  2.39  8.80
#                    Catch-24   316  64.4%  53.7%  +0.12  2.14  7.01
#                        Pine   314  66.4%  53.7%  -0.45  2.35  8.48
#                       Haste   290  61.0%  51.7%  +0.14  2.23  7.68
#                   Pukebox 2   157  61.9%  51.7%  -0.07  2.49  8.51
#                   Pretzel 2   135  61.6%  53.1%  +0.17  1.99  6.02
#                         GFY   131  65.3%  56.2%  -0.00  2.12  6.49
# Waterbed [MM23 West Winner]   106  63.2%  52.2%  -0.02  1.97  5.92
#               Professor Oak   106  66.4%  58.5%  -0.12  2.00  5.87
#                       PRush    72  66.3%  56.2%  -0.03  2.47  8.67
#             Tetanic 3.1 4x4    69  61.5%  50.9%  -0.07  2.46  8.86
#                       Flume    69  70.9%  65.5%  +0.01  2.08  6.26
#               Crawfish Boil    61  63.3%  53.9%  +0.00  2.51  9.25
#                     Tetanic     6  57.4%  47.4%  +1.24  2.29  8.18

# %% [markdown]
# ### Results

# %% [markdown]
# Guessing 0:
#
# ```
# MAE: 2.6057    RMS: 3.0680
# COR: 50.00%    WWP: 50.00%
# BRI: 50.00%    LOG: 50.00%
# ```
#
# Current system:
#
# ```
# MAE: 2.4039    RMS: 2.9133
# COR: 60.56%    WWP: 53.64%
# BRI: 51.86%    LOG: 51.97%
# ```
#
# With hindsight:
#
# ```
# MAE: 2.3589    RMS: 2.8734
# COR: 62.05%    WWP: 54.93%
# BRI: 52.36%    LOG: 52.51%
# ```
